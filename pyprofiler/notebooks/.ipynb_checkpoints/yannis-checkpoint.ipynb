# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../..')
#sys.path.append( '/home/cactuskid13/miniconda3/pkgs/')
print(sys.path)
# Out:
# ['/home/cactuskid13/pyprofiler/pyprofiler/notebooks', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python37.zip', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/lib-dynload', '', '/home/cactuskid13/.local/lib/python3.7/site-packages', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages', '/home/cactuskid13/pyham', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/IPython/extensions', '/home/cactuskid13/.ipython', '../..']

# %% [markdown]
# # Loading libraries and data
#
# + Precomputed OMA database
# + Go annotation file

# %%
#using the profiler. It's easy!
#lets import the profiler, configuration file and some tools for GO analysis to look at our returned results
from pyprofiler.utils import config_utils
import pyprofiler.utils.goatools_utils as goa
import pyprofiler.profiler as profiler
import pandas as pd
import numpy as np
# Out:
# {'dir': {'datadir': '/home/cactuskid13/pyprofiler/pyprofiler/all/all/', 'omadir': '/home/cactuskid13/mntpt/OMA/latest/'}, 'orthoxmltar': '', 'email': 'dmoi@unil.ch'}

# %%
#lets also create a go annotation enrichment study object to describe functional enrichment in our profiling results
gaf = goa.buildGAF( '/home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/oma-go.txt' )
study = goa.return_enrichment_study_obj( gaf , obo = '/home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/go.obo')
# Out:
# /home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/go.obo: fmt(1.2) rel(2019-11-02) 47,242 GO Terms
#
# Load GOEA Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 100% 9,897,212 of 9,897,212 population items found in association

# %%
#lets load a compiled db containing the OMA root HOGs into a profiler oject 
p = profiler.Profiler(lshforestpath = '../all/all/jun_all_512/newlshforest.pkl' , mastertree=  '../all/all/jun_all_512_master_tree.pkl', hashes_h5= '../all/all/jun_all_512/hashes.h5' , mat_path= None, oma = '/home/cactuskid13/mntpt/OMA/jun//OmaServer.h5', tar= None , nsamples = 512)
# Out:
# loading lsh
# indexing lsh
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/Protein/_i_Entries/OmaHOG/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# 3115
# DONE

# %% [markdown]
# # Find HOGs for auery genes
#
# Here the gene are ciliary genes:
#
# + BBS7
# + IFT88
# + MCIDAS
# /home/cactuskid13/mntpt/OMA/latest/

# %%
#load the kinetochore data and map it to OMA HOGs
#these are blast results against oma since they had their own adhoc IDs

import pandas as pd

queries = pd.read_csv( '/home/cactuskid13/zp2/uniqueries.tab' , sep='\t')
print(queries)
# Out:
#    yourlist:M20200412DA437993067D6F64326E5E763500BDED113540K   Entry  \
# 0                                              P10323         P10323
# 1                                              P21754         P21754
# 2                                              Q12836         Q12836
# 3                                              Q8TCW7         Q8TCW7
# 4                                              P60852         P60852
# 5                                              Q05996         Q05996
# 6                                              Q1ZYL8         Q1ZYL8
# 7                                              Q5VZ72         Q5VZ72
# 8                                              A6ND01         A6ND01
# 9                                              Q8IYV9         Q8IYV9
# 10                                             Q6UXV1         Q6UXV1
#
#      Entry name    Status                                      Protein names  \
# 0    ACRO_HUMAN  reviewed  Acrosin (EC 3.4.21.10) [Cleaved into: Acrosin ...
# 1     ZP3_HUMAN  reviewed  Zona pellucida sperm-binding protein 3 (Sperm ...
# 2     ZP4_HUMAN  reviewed  Zona pellucida sperm-binding protein 4 (Zona p...
# 3   ZPLD1_HUMAN  reviewed  Zona pellucida-like domain-containing protein ...
# 4     ZP1_HUMAN  reviewed  Zona pellucida sperm-binding protein 1 (Zona p...
# 5     ZP2_HUMAN  reviewed  Zona pellucida sperm-binding protein 2 (Zona p...
# 6   IZUM4_HUMAN  reviewed  Izumo sperm-egg fusion protein 4 (Sperm 22 kDa...
# 7   IZUM3_HUMAN  reviewed                   Izumo sperm-egg fusion protein 3
# 8    JUNO_HUMAN  reviewed  Sperm-egg fusion protein Juno (Folate receptor...
# 9   IZUM1_HUMAN  reviewed  Izumo sperm-egg fusion protein 1 (Oocyte bindi...
# 10  IZUM2_HUMAN  reviewed                   Izumo sperm-egg fusion protein 2
#
#                                Gene names              Organism  Length  \
# 0                                ACR ACRS  Homo sapiens (Human)     421
# 1                       ZP3 ZP3A ZP3B ZPC  Homo sapiens (Human)     424
# 2                                 ZP4 ZPB  Homo sapiens (Human)     540
# 3                                   ZPLD1  Homo sapiens (Human)     415
# 4                                     ZP1  Homo sapiens (Human)     638
# 5                                 ZP2 ZPA  Homo sapiens (Human)     745
# 6          IZUMO4 C19orf36 UNQ831/PRO1758  Homo sapiens (Human)     232
# 7                         IZUMO3 C9orf134  Homo sapiens (Human)     239
# 8                      IZUMO1R FOLR4 JUNO  Homo sapiens (Human)     250
# 9                                  IZUMO1  Homo sapiens (Human)     350
# 10  IZUMO2 C19orf41 SCRL UNQ6978/PRO21961  Homo sapiens (Human)     221
#
#    Cross-reference (OMA) Cross-reference (Bgee)  \
# 0               SRRYHAC;       ENSG00000100312;
# 1               PENCEPL;       ENSG00000188372;
# 2               GCYVTEW;       ENSG00000116996;
# 3               RADDCPL;       ENSG00000170044;
# 4               IHLAYAP;       ENSG00000149506;
# 5               AICAPDP;       ENSG00000103310;
# 6               RGCLHCH;       ENSG00000099840;
# 7               SEDCIVT;       ENSG00000205442;
# 8               NAPLCQE;       ENSG00000183560;
# 9               PATIINF;       ENSG00000182264;
# 10              KEEVWDC;       ENSG00000161652;
#
#                   Cross-reference (PDB)
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8   5F4E;5F4Q;5JKA;5JKB;5JKC;5JKD;5JKE;
# 9   5F4E;5F4T;5F4V;5JK9;5JKC;5JKD;5JKE;
# 10                                  NaN

# %%
def grabHog(ID):
    try:
        return p.db_obj.entry_by_entry_nr(p.db_obj.id_resolver.resolve(ID))[4].decode()
    except:
        return np.nan
Hogs = dict( zip ( queries.Entry , [ grabHog(i) for i in queries.Entry ]))
print(Hogs)
# Out:
# {'P10323': 'HOG:0363288.1d.3a', 'P21754': 'HOG:0363809.1b.1a.1c.1a', 'Q12836': 'HOG:0364421.1a', 'Q8TCW7': 'HOG:0370353', 'P60852': 'HOG:0358404.1a', 'Q05996': 'HOG:0370707.2b.1b', 'Q1ZYL8': 'HOG:0356526', 'Q5VZ72': 'HOG:0356234', 'A6ND01': 'HOG:0396255.6b', 'Q8IYV9': 'HOG:0369948.1a.1a', 'Q6UXV1': 'HOG:0360948.3a'}

# %%
from pyprofiler.utils.hashutils import hogid2fam 
HogDF = pd.DataFrame.from_dict( Hogs , orient = 'index' )
HogDF = HogDF[ HogDF[0].str.len() > 0 ] 
HogDF['fam'] = HogDF[0].map( hogid2fam)


print(HogDF)

queries['fam'] = queries.Entry.map( dict(zip( HogDF.index ,HogDF.fam  )) )
print(queries)
names = dict(zip(queries.fam, queries['Protein names']))
print(names)
# Out:
#                               0     fam
# P10323        HOG:0363288.1d.3a  363288
# P21754  HOG:0363809.1b.1a.1c.1a  363809
# Q12836           HOG:0364421.1a  364421
# Q8TCW7              HOG:0370353  370353
# P60852           HOG:0358404.1a  358404
# Q05996        HOG:0370707.2b.1b  370707
# Q1ZYL8              HOG:0356526  356526
# Q5VZ72              HOG:0356234  356234
# A6ND01           HOG:0396255.6b  396255
# Q8IYV9        HOG:0369948.1a.1a  369948
# Q6UXV1           HOG:0360948.3a  360948
#    yourlist:M20200412DA437993067D6F64326E5E763500BDED113540K   Entry  \
# 0                                              P10323         P10323
# 1                                              P21754         P21754
# 2                                              Q12836         Q12836
# 3                                              Q8TCW7         Q8TCW7
# 4                                              P60852         P60852
# 5                                              Q05996         Q05996
# 6                                              Q1ZYL8         Q1ZYL8
# 7                                              Q5VZ72         Q5VZ72
# 8                                              A6ND01         A6ND01
# 9                                              Q8IYV9         Q8IYV9
# 10                                             Q6UXV1         Q6UXV1
#
#      Entry name    Status                                      Protein names  \
# 0    ACRO_HUMAN  reviewed  Acrosin (EC 3.4.21.10) [Cleaved into: Acrosin ...
# 1     ZP3_HUMAN  reviewed  Zona pellucida sperm-binding protein 3 (Sperm ...
# 2     ZP4_HUMAN  reviewed  Zona pellucida sperm-binding protein 4 (Zona p...
# 3   ZPLD1_HUMAN  reviewed  Zona pellucida-like domain-containing protein ...
# 4     ZP1_HUMAN  reviewed  Zona pellucida sperm-binding protein 1 (Zona p...
# 5     ZP2_HUMAN  reviewed  Zona pellucida sperm-binding protein 2 (Zona p...
# 6   IZUM4_HUMAN  reviewed  Izumo sperm-egg fusion protein 4 (Sperm 22 kDa...
# 7   IZUM3_HUMAN  reviewed                   Izumo sperm-egg fusion protein 3
# 8    JUNO_HUMAN  reviewed  Sperm-egg fusion protein Juno (Folate receptor...
# 9   IZUM1_HUMAN  reviewed  Izumo sperm-egg fusion protein 1 (Oocyte bindi...
# 10  IZUM2_HUMAN  reviewed                   Izumo sperm-egg fusion protein 2
#
#                                Gene names              Organism  Length  \
# 0                                ACR ACRS  Homo sapiens (Human)     421
# 1                       ZP3 ZP3A ZP3B ZPC  Homo sapiens (Human)     424
# 2                                 ZP4 ZPB  Homo sapiens (Human)     540
# 3                                   ZPLD1  Homo sapiens (Human)     415
# 4                                     ZP1  Homo sapiens (Human)     638
# 5                                 ZP2 ZPA  Homo sapiens (Human)     745
# 6          IZUMO4 C19orf36 UNQ831/PRO1758  Homo sapiens (Human)     232
# 7                         IZUMO3 C9orf134  Homo sapiens (Human)     239
# 8                      IZUMO1R FOLR4 JUNO  Homo sapiens (Human)     250
# 9                                  IZUMO1  Homo sapiens (Human)     350
# 10  IZUMO2 C19orf41 SCRL UNQ6978/PRO21961  Homo sapiens (Human)     221
#
#    Cross-reference (OMA) Cross-reference (Bgee)  \
# 0               SRRYHAC;       ENSG00000100312;
# 1               PENCEPL;       ENSG00000188372;
# 2               GCYVTEW;       ENSG00000116996;
# 3               RADDCPL;       ENSG00000170044;
# 4               IHLAYAP;       ENSG00000149506;
# 5               AICAPDP;       ENSG00000103310;
# 6               RGCLHCH;       ENSG00000099840;
# 7               SEDCIVT;       ENSG00000205442;
# 8               NAPLCQE;       ENSG00000183560;
# 9               PATIINF;       ENSG00000182264;
# 10              KEEVWDC;       ENSG00000161652;
#
#                   Cross-reference (PDB)     fam
# 0                                   NaN  363288
# 1                                   NaN  363809
# 2                                   NaN  364421
# 3                                   NaN  370353
# 4                                   NaN  358404
# 5                                   NaN  370707
# 6                                   NaN  356526
# 7                                   NaN  356234
# 8   5F4E;5F4Q;5JKA;5JKB;5JKC;5JKD;5JKE;  396255
# 9   5F4E;5F4T;5F4V;5JK9;5JKC;5JKD;5JKE;  369948
# 10                                  NaN  360948
# {363288: 'Acrosin (EC 3.4.21.10) [Cleaved into: Acrosin light chain; Acrosin heavy chain]', 363809: 'Zona pellucida sperm-binding protein 3 (Sperm receptor) (ZP3A/ZP3B) (Zona pellucida glycoprotein 3) (Zp-3) (Zona pellucida protein C) [Cleaved into: Processed zona pellucida sperm-binding protein 3]', 364421: 'Zona pellucida sperm-binding protein 4 (Zona pellucida glycoprotein 4) (Zp-4) (Zona pellucida protein B) [Cleaved into: Processed zona pellucida sperm-binding protein 4]', 370353: 'Zona pellucida-like domain-containing protein 1 (ZP domain-containing protein 1) (Cupulin) [Cleaved into: Zona pellucida-like domain-containing protein 1, secreted form]', 358404: 'Zona pellucida sperm-binding protein 1 (Zona pellucida glycoprotein 1) (Zp-1) [Cleaved into: Processed zona pellucida sperm-binding protein 1]', 370707: 'Zona pellucida sperm-binding protein 2 (Zona pellucida glycoprotein 2) (Zp-2) (Zona pellucida protein A) [Cleaved into: Processed zona pellucida sperm-binding protein 2]', 356526: 'Izumo sperm-egg fusion protein 4 (Sperm 22 kDa protein c113)', 356234: 'Izumo sperm-egg fusion protein 3', 396255: 'Sperm-egg fusion protein Juno (Folate receptor 4) (Folate receptor delta) (FR-delta) (IZUMO1 receptor protein JUNO)', 369948: 'Izumo sperm-egg fusion protein 1 (Oocyte binding/fusion factor) (OBF) (Sperm-specific protein izumo)', 360948: 'Izumo sperm-egg fusion protein 2'}

# %% [markdown]
# # Get similar gene family and cluster these

# %%
res =  { f: p.hog_query( fam_id= f  , k = 15 ) for f in HogDF.fam.unique() if f }
print(res)
HogDF['res'] = HogDF.fam.map(res)
# Out:
# {363288: ['357911', '363274', '358598', '363102', '363288', '362868', '358814', '358377', '362521', '360713', '362864', '357960', '358393', '362361', '362890'], 363809: ['363567', '363712', '387243', '361320', '373706', '363809', '364253', '363069', '362623', '380094', '364163', '363926', '360797', '363365', '369329'], 364421: ['359237', '363865', '364492', '363400', '360004', '364421', '368813', '363801', '360942', '358374', '364276', '362949', '359428', '363645', '358897'], 370353: ['370353', '369580', '369758', '372366', '365540', '373671', '365322', '365776', '373013', '371908', '368385', '368240', '370381', '365644', '368326'], 358404: ['359013', '358832', '359769', '359754', '358592', '358686', '358404', '359524', '359018', '358376', '358961', '359164', '359412', '358514', '359903'], 370707: ['363635', '364288', '364321', '368162', '370707', '366089', '364289', '366353', '367372', '364489', '364411', '364531', '363636', '366563', '364199'], 356526: ['355492', '356206', '357306', '355698', '356526', '361722', '357331', '357269', '353246', '354951', '355752', '356061', '355458', '354707', '353859'], 356234: ['358261', '357064', '363112', '363472', '356234', '355275', '355554', '353444', '357946', '356565', '356278', '355708', '358961', '355696', '355572'], 396255: ['397603', '383502', '394410', '404850', '401010', '390511', '396985', '395084', '398141', '396133', '394736', '396255', '394281', '395702', '394534'], 369948: ['360257', '364234', '369948', '359625', '369065', '371864', '359032', '370109', '357796', '357670', '371884', '365490', '369221', '368964', '371161'], 360948: ['358261', '362940', '358445', '360948', '359141', '359219', '362008', '358331', '358673', '363029', '359070', '361397', '363058', '360379', '358232']}

# %%
import seaborn as sns
hogs = [ h  for q in res for h in res[q]]

hashes = p.pull_hashes( set(hogs+ list(res.keys()) ) )

jkern = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(hashes.values()) ] for i,h1 in enumerate(hashes.values())]
jkern = np.asarray(jkern)
jkern+=jkern.T
np.fill_diagonal( jkern , 1 )

# %%
g = sns.clustermap( jkern , xticklabels=hashes.keys()  , yticklabels=hashes.keys(), figsize = (20,20) )


labels = []
for tick_label in g.ax_heatmap.axes.get_yticklabels():
    l = tick_label.get_text()
    if int(l) in res:
        c ='#3003fc'
        labels.append(l + ' '+names[int(l)])

    else:
        c = '#000000'
        labels.append(l)
    tick_label.set_color(c)

for tick_label in g.ax_heatmap.axes.get_xticklabels():
    l = tick_label.get_text()
    if int(l) in res:
        c ='#3003fc'

    else:
        c = '#000000'

    tick_label.set_color(c)

# %% [markdown]
# # Cluster analysis
#
# Here, gene ontology enrichment of the whole matrixes.
#
# More precise analyses are available...

# %%
for r in res:
    try:
        res[r].remove( str(r) )
    except:
        pass

goares = goa.run_GOEA_onresults( res , p.db_obj, study )
#output the results
goea_results_sig = [r for r in goares[0] if r.p_fdr_bh < 0.1]
# Out:
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 673 IDs ...
# 100%    595 of    595 study items found in association
#  88%    595 of    673 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      185 GO terms are associated with    595 of    673 study items
#   METHOD fdr_bh:
#      142 GO terms found significant (< 0.15=alpha) (102 enriched +  40 purified): statsmodels fdr_bh
#      590 study items associated with significant GO IDs (enriched)
#       33 study items associated with significant GO IDs (purified)
# done
# DONE!

# %%
[ print(r ) for r in goea_results_sig]

goea_results_sig.
# Out:
# GO:0035036	BP	e	sperm-egg recognition         	113/595	404/9897212	0	4	113	0	AILME01203, AILME14185, ASTMX04343, ASTMX15938, BOVIN04646, BOVIN06922, CALJA03190, CALJA03360, CALJA13139, CANLF00839, CANLF08167, CANLF08306, CAVPO04933, CAVPO07697, CHILA03661, CHLSB00777, CHLSB00907, CHLSB15998, CHOHO02945, DASNO09194, DASNO18357, DASNO22377, DIPOR00503, DIPOR07289, ECHTE00315, FELCA11457, FELCA11584, FELCA15996, FUKDA03992, GADMO15806, GORGO03925, GORGO04066, GORGO10294, HORSE02069, HORSE17705, HORSE17838, HORSE17840, HUMAN05127, HUMAN05129, HUMAN05351, HUMAN15947, ICTTR04852, ICTTR05978, JACJA13371, JACJA24381, LATCH10313, LOXAF04212, LOXAF08872, LOXAF18113, MACEU02382, MACMU07616, MACMU12368, MICMU00271, MONDO07476, MONDO16060, MOUSE44256, MOUSE45326, MOUSE50165, MUSPF06688, MUSPF12643, MYOLU07593, MYOLU08608, MYOLU17442, NANGA12382, NANGA17442, NOMLE00699, NOMLE01389, NOMLE09903, NOTFU10710, NOTFU28035, OCHPR03159, OCHPR10183, OCTDE23293, ORENI01453, ORNAN15318, OTOGA02152, OTOGA18898, OTOGA19032, PANPA07428, PANPA07747, PANPA20958, PANTR03736, PANTR03741, PANTR04100, PANTR18849, PAPAN09725, POEFO12471, POEFO12870, PONAB01629, PROCA00230, PROCA01303, PROCA05394, PTEVA01306, PTEVA13552, PTEVA15024, RABIT00711, RABIT00844, RABIT18056, RATNO01138, RATNO01506, RATNO19269, SARHA04062, SHEEP05637, SHEEP05984, SHEEP06472, SORAR00416, SORAR00840, TETNG17804, TUPBE04551, TUPBE12130, TURTR00695, TURTR00953, XIPMA12493
# GO:0003677	MF	p	DNA binding                   	2/595	851245/9897212	2.15e-20	4	2	7.16e-18	HUMAN20403, PIGXX14657
# GO:0003824	MF	p	catalytic activity            	0/595	651621/9897212	6.25e-18	1	0	2.01e-15
# GO:0016491	MF	p	oxidoreductase activity       	0/595	600559/9897212	1.03e-16	2	0	3.27e-14
# GO:0003676	MF	p	nucleic acid binding          	0/595	371785/9897212	2.07e-10	3	0	5.89e-08
# GO:0003723	MF	p	RNA binding                   	0/595	373976/9897212	2.1e-10	4	0	5.92e-08
# GO:0016301	MF	p	kinase activity               	0/595	330216/9897212	3.34e-09	4	0	9.22e-07
# GO:0003700	MF	p	DNA-binding transcription factor activity	0/595	291778/9897212	3.46e-08	2	0	9.3e-06
# GO:0008270	MF	p	zinc ion binding              	1/595	320546/9897212	1.54e-07	6	1	3.95e-05	     HUMAN20403
# GO:0016829	MF	p	lyase activity                	0/595	223301/9897212	2.52e-06	2	0	0.000617
# GO:0016874	MF	p	ligase activity               	0/595	190017/9897212	1.7e-05	2	0	0.00397
# GO:0003735	MF	p	structural constituent of ribosome	0/595	190395/9897212	1.7e-05	2	0	0.00397
# GO:0004672	MF	p	protein kinase activity       	0/595	193670/9897212	1.81e-05	5	0	0.0041
# GO:0016887	MF	p	ATPase activity               	0/595	193922/9897212	1.82e-05	7	0	0.0041
# GO:0008168	MF	p	methyltransferase activity    	0/595	177800/9897212	3.68e-05	4	0	0.00816
# GO:0022857	MF	p	transmembrane transporter activity	0/595	173026/9897212	5.52e-05	2	0	0.0121
# GO:0016853	MF	p	isomerase activity            	0/595	173956/9897212	5.62e-05	2	0	0.0122
# GO:0005525	MF	p	GTP binding                   	0/595	160577/9897212	0.000119	8	0	0.0254
# GO:0000287	MF	p	magnesium ion binding         	0/595	150829/9897212	0.000276	5	0	0.0567
# GO:0005509	MF	p	calcium ion binding           	0/595	143261/9897212	0.000391	5	0	0.0785
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
with open( '/home/cactuskid13/mntpt/CATH/cath-names.txt') as cathin:
    cathnames  = { i:{  j : w.strip()   for j,w in enumerate(l.split('    ')) } for i,l in enumerate(cathin)  if l[0] != '#'}
cathdf = pd.DataFrame.from_dict(cathnames, orient= 'index')
mapper = dict(zip(cathdf[0], cathdf[2]))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-b85c3fb70265> in <module>
# ----> 1 with open( '/home/cactuskid13/mntpt/CATH/cath-names.txt') as cathin:
#       2     cathnames  = { i:{  j : w.strip()   for j,w in enumerate(l.split('    ')) } for i,l in enumerate(cathin)  if l[0] != '#'}
#       3 cathdf = pd.DataFrame.from_dict(cathnames, orient= 'index')
#       4 mapper = dict(zip(cathdf[0], cathdf[2]))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cactuskid13/mntpt/CATH/cath-names.txt'

# %%
def hog_arch(fam):
    try:
        return p.db_obj.get_representative_entry_of_hog(fam)
    except:
        return None

def annotate_domain( domainlist ):
    if domainlist is not None:
        return [ mapper[ x[1].decode() ] if x[1].decode() in mapper else None for x in domainlist ]
    else:
        return None

# %%
result_domains = { h : { 'rep_entry': hog_arch(h)} for h in set(hogs+ list(res.keys()) )}
print(result_domains)
result_domains = pd.DataFrame.from_dict( result_domains, orient = 'index')
result_domains['domains'] =  result_domains.rep_entry.map( lambda x : x['domains'] if x else None )
result_domains['cath'] = result_domains['domains'].map( annotate_domain)

# %%
def hog_arch(fam):
    try:
        return p.db_obj.get_representative_entry_of_hog(fam)
    except:
        return None
explicit_profiles['prots'] = explicit_profiles.index.map( hog_arch )
explicit_profiles['domains'] = explicit_profiles.prots.map( lambda x : x['domains'] if x else None )

# %%
with open( '/home/cactuskid13/mntpt/CATH/cath-names.txt') as cathin:
    cathnames  = { i:{  j : w.strip()   for j,w in enumerate(l.split('    ')) } for i,l in enumerate(cathin)  if l[0] != '#'}
cathdf = pd.DataFrame.from_dict(cathnames, orient= 'index')
mapper = dict(zip(cathdf[0], cathdf[2]))

# %%
#we can enrich for functionality in each cluster
goares = {}

for c in np.unique(clusters):
    sub = profiles.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        study.wr_txt(namestr + "_v2_kinetocluster_enrich.txt", goea_results_sig)
        print(len(goea_results_sig))
# Out:
# ['' 'CenpQ' 'CenpW']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 315 IDs ...
# 100%    247 of    247 study items found in association
#  78%    247 of    315 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      160 GO terms are associated with    247 of    315 study items
#   METHOD fdr_bh:
#      106 GO terms found significant (< 0.15=alpha) ( 91 enriched +  15 purified): statsmodels fdr_bh
#      227 study items associated with significant GO IDs (enriched)
#       70 study items associated with significant GO IDs (purified)
# done
# DONE!
#     102 GOEA results for   241 study items. WROTE: CenpQ_CenpW__v2_kinetocluster_enrich.txt
# 102
# ['' 'CenpC']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 222 IDs ...
# 100%    188 of    188 study items found in association
#  85%    188 of    222 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       50 GO terms are associated with    188 of    222 study items
#   METHOD fdr_bh:
#       39 GO terms found significant (< 0.15=alpha) ( 29 enriched +  10 purified): statsmodels fdr_bh
#      186 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
# done
# DONE!
#      38 GOEA results for   186 study items. WROTE: CenpC__v2_kinetocluster_enrich.txt
# 38
# ['' 'CenpS']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 194 IDs ...
# 100%    132 of    132 study items found in association
#  68%    132 of    194 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       94 GO terms are associated with    132 of    194 study items
#   METHOD fdr_bh:
#       64 GO terms found significant (< 0.15=alpha) ( 54 enriched +  10 purified): statsmodels fdr_bh
#      129 study items associated with significant GO IDs (enriched)
#       28 study items associated with significant GO IDs (purified)
# done
# DONE!
#      62 GOEA results for   129 study items. WROTE: CenpS__v2_kinetocluster_enrich.txt
# 62
# ['' 'Apc13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 278 IDs ...
# 100%    265 of    265 study items found in association
#  95%    265 of    278 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      105 GO terms are associated with    265 of    278 study items
#   METHOD fdr_bh:
#       88 GO terms found significant (< 0.15=alpha) ( 70 enriched +  18 purified): statsmodels fdr_bh
#      257 study items associated with significant GO IDs (enriched)
#       20 study items associated with significant GO IDs (purified)
# done
# DONE!
#      86 GOEA results for   260 study items. WROTE: Apc13__v2_kinetocluster_enrich.txt
# 86
# ['' 'RINT1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 439 IDs ...
# 100%    364 of    364 study items found in association
#  83%    364 of    439 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       39 GO terms are associated with    364 of    439 study items
#   METHOD fdr_bh:
#       25 GO terms found significant (< 0.15=alpha) (  4 enriched +  21 purified): statsmodels fdr_bh
#      355 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
# done
# DONE!
#      23 GOEA results for   360 study items. WROTE: RINT1__v2_kinetocluster_enrich.txt
# 23
# ['' 'Nnf1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 80 IDs ...
# 100%     61 of     61 study items found in association
#  76%     61 of     80 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       22 GO terms are associated with     61 of     80 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.15=alpha) (  5 enriched +   2 purified): statsmodels fdr_bh
#       57 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#       7 GOEA results for    57 study items. WROTE: Nnf1__v2_kinetocluster_enrich.txt
# 7
# ['' 'CenpC']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 71 IDs ...
# 100%     33 of     33 study items found in association
#  46%     33 of     71 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       22 GO terms are associated with     33 of     71 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.15=alpha) (  8 enriched +   1 purified): statsmodels fdr_bh
#       30 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       9 GOEA results for    30 study items. WROTE: CenpC__v2_kinetocluster_enrich.txt
# 9
# ['' 'CenpP']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 101 IDs ...
# 100%     72 of     72 study items found in association
#  71%     72 of    101 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       22 GO terms are associated with     72 of    101 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.15=alpha) (  7 enriched +   2 purified): statsmodels fdr_bh
#       66 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
# done
# DONE!
#       9 GOEA results for    70 study items. WROTE: CenpP__v2_kinetocluster_enrich.txt
# 9
# ['' 'SKAP']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 313 IDs ...
# 100%    229 of    229 study items found in association
#  73%    229 of    313 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       56 GO terms are associated with    229 of    313 study items
#   METHOD fdr_bh:
#       40 GO terms found significant (< 0.15=alpha) ( 29 enriched +  11 purified): statsmodels fdr_bh
#      224 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
# done
# DONE!
#      38 GOEA results for   224 study items. WROTE: SKAP__v2_kinetocluster_enrich.txt
# 38
# ['' 'Nup107']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1043 IDs ...
# 100%    939 of    939 study items found in association
#  90%    939 of  1,043 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      119 GO terms are associated with    939 of  1,043 study items
#   METHOD fdr_bh:
#      127 GO terms found significant (< 0.15=alpha) ( 62 enriched +  65 purified): statsmodels fdr_bh
#      929 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
# done
# DONE!
#     125 GOEA results for   935 study items. WROTE: Nup107__v2_kinetocluster_enrich.txt
# 125
# ['' 'CenpI']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 23 IDs ...
# 100%      3 of      3 study items found in association
#  13%      3 of     23 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        7 GO terms are associated with      3 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 GOEA results. NOT WRITING CenpI__v2_kinetocluster_enrich.txt
# 0
# ['' 'Spc25']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 365 IDs ...
# 100%    281 of    281 study items found in association
#  77%    281 of    365 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       55 GO terms are associated with    281 of    365 study items
#   METHOD fdr_bh:
#       40 GO terms found significant (< 0.15=alpha) ( 18 enriched +  22 purified): statsmodels fdr_bh
#      270 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
# done
# DONE!
#      39 GOEA results for   275 study items. WROTE: Spc25__v2_kinetocluster_enrich.txt
# 39
# ['' 'Spc19']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 60 IDs ...
# 100%     40 of     40 study items found in association
#  67%     40 of     60 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       53 GO terms are associated with     40 of     60 study items
#   METHOD fdr_bh:
#       18 GO terms found significant (< 0.15=alpha) ( 18 enriched +   0 purified): statsmodels fdr_bh
#       38 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      16 GOEA results for    38 study items. WROTE: Spc19__v2_kinetocluster_enrich.txt
# 16
# ['' 'Apc9' 'Dad3' 'Dad2']
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 233 IDs ...
# 100%    202 of    202 study items found in association
#  87%    202 of    233 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       92 GO terms are associated with    202 of    233 study items
#   METHOD fdr_bh:
#       66 GO terms found significant (< 0.15=alpha) ( 56 enriched +  10 purified): statsmodels fdr_bh
#      194 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
# done
# DONE!
#      66 GOEA results for   198 study items. WROTE: Apc9_Dad3_Dad2__v2_kinetocluster_enrich.txt
# 66
# ['' 'Dam1' 'Spc34']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 101 IDs ...
# 100%     68 of     68 study items found in association
#  67%     68 of    101 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       68 GO terms are associated with     68 of    101 study items
#   METHOD fdr_bh:
#       36 GO terms found significant (< 0.15=alpha) ( 36 enriched +   0 purified): statsmodels fdr_bh
#       68 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      35 GOEA results for    66 study items. WROTE: Dam1_Spc34__v2_kinetocluster_enrich.txt
# 35
# ['' 'Cep3' 'Ctf13']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 373 IDs ...
# 100%    236 of    236 study items found in association
#  63%    236 of    373 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      174 GO terms are associated with    236 of    373 study items
#   METHOD fdr_bh:
#       80 GO terms found significant (< 0.15=alpha) ( 67 enriched +  13 purified): statsmodels fdr_bh
#      174 study items associated with significant GO IDs (enriched)
#       81 study items associated with significant GO IDs (purified)
# done
# DONE!
#      78 GOEA results for   217 study items. WROTE: Cep3_Ctf13__v2_kinetocluster_enrich.txt
# 78
# ['' 'Hsk3' 'Duo1' 'Ndc10']
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 124 IDs ...
# 100%     84 of     84 study items found in association
#  68%     84 of    124 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       68 GO terms are associated with     84 of    124 study items
#   METHOD fdr_bh:
#       18 GO terms found significant (< 0.15=alpha) ( 17 enriched +   1 purified): statsmodels fdr_bh
#       36 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      17 GOEA results for    36 study items. WROTE: Hsk3_Duo1_Ndc10__v2_kinetocluster_enrich.txt
# 17
# ['' 'Zwint-1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 152 IDs ...
# 100%    145 of    145 study items found in association
#  95%    145 of    152 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       58 GO terms are associated with    145 of    152 study items
#   METHOD fdr_bh:
#       32 GO terms found significant (< 0.15=alpha) ( 25 enriched +   7 purified): statsmodels fdr_bh
#      138 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      31 GOEA results for   139 study items. WROTE: Zwint-1__v2_kinetocluster_enrich.txt
# 31
# ['' 'CenpA']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 88 IDs ...
# 100%     49 of     49 study items found in association
#  56%     49 of     88 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       21 GO terms are associated with     49 of     88 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.15=alpha) (  6 enriched +   2 purified): statsmodels fdr_bh
#       49 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       8 GOEA results for    49 study items. WROTE: CenpA__v2_kinetocluster_enrich.txt
# 8
# ['' 'Mps1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 366 IDs ...
# 100%    350 of    350 study items found in association
#  96%    350 of    366 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      135 GO terms are associated with    350 of    366 study items
#   METHOD fdr_bh:
#       90 GO terms found significant (< 0.15=alpha) ( 70 enriched +  20 purified): statsmodels fdr_bh
#      294 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
# done
# DONE!
#      89 GOEA results for   294 study items. WROTE: Mps1__v2_kinetocluster_enrich.txt
# 89
# ['' 'TRIP13']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 62 IDs ...
# 100%     35 of     35 study items found in association
#  56%     35 of     62 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       32 GO terms are associated with     35 of     62 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.15=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
#       21 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      10 GOEA results for    21 study items. WROTE: TRIP13__v2_kinetocluster_enrich.txt
# 10
# ['' 'Nuf2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 21 IDs ...
# 100%      6 of      6 study items found in association
#  29%      6 of     21 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        3 GO terms are associated with      6 of     21 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 GOEA results. NOT WRITING Nuf2__v2_kinetocluster_enrich.txt
# 0
# ['' 'Apc7']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 238 IDs ...
# 100%    156 of    156 study items found in association
#  66%    156 of    238 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       43 GO terms are associated with    156 of    238 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.15=alpha) (  9 enriched +  12 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#      20 GOEA results for   152 study items. WROTE: Apc7__v2_kinetocluster_enrich.txt
# 20
# ['' 'Apc8']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 69 IDs ...
# 100%     43 of     43 study items found in association
#  62%     43 of     69 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       30 GO terms are associated with     43 of     69 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.15=alpha) (  7 enriched +   1 purified): statsmodels fdr_bh
#       32 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#       7 GOEA results for    32 study items. WROTE: Apc8__v2_kinetocluster_enrich.txt
# 7
# ['' 'Zwilch']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING Zwilch__v2_kinetocluster_enrich.txt
# 0
# ['' 'p31comet']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 118 IDs ...
# 100%     90 of     90 study items found in association
#  76%     90 of    118 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       16 GO terms are associated with     90 of    118 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  2 enriched +   1 purified): statsmodels fdr_bh
#       75 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       3 GOEA results for    75 study items. WROTE: p31comet__v2_kinetocluster_enrich.txt
# 3
# ['' 'CenpN']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 274 IDs ...
# 100%    220 of    220 study items found in association
#  80%    220 of    274 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       30 GO terms are associated with    220 of    274 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 14 enriched +  14 purified): statsmodels fdr_bh
#      217 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      28 GOEA results for   219 study items. WROTE: CenpN__v2_kinetocluster_enrich.txt
# 28
# ['' 'Apc13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 525 IDs ...
# 100%    342 of    342 study items found in association
#  65%    342 of    525 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      109 GO terms are associated with    342 of    525 study items
#   METHOD fdr_bh:
#       84 GO terms found significant (< 0.15=alpha) ( 64 enriched +  20 purified): statsmodels fdr_bh
#      324 study items associated with significant GO IDs (enriched)
#       35 study items associated with significant GO IDs (purified)
# done
# DONE!
#      83 GOEA results for   333 study items. WROTE: Apc13__v2_kinetocluster_enrich.txt
# 83
# ['' 'Nup160']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 185 IDs ...
# 100%    127 of    127 study items found in association
#  69%    127 of    185 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       31 GO terms are associated with    127 of    185 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.15=alpha) ( 10 enriched +   7 purified): statsmodels fdr_bh
#      120 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 GOEA results for   122 study items. WROTE: Nup160__v2_kinetocluster_enrich.txt
# 15
# ['' 'Knl1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 371 IDs ...
# 100%    264 of    264 study items found in association
#  71%    264 of    371 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      118 GO terms are associated with    264 of    371 study items
#   METHOD fdr_bh:
#      100 GO terms found significant (< 0.15=alpha) ( 83 enriched +  17 purified): statsmodels fdr_bh
#      224 study items associated with significant GO IDs (enriched)
#       51 study items associated with significant GO IDs (purified)
# done
# DONE!
#     100 GOEA results for   263 study items. WROTE: Knl1__v2_kinetocluster_enrich.txt
# 100
# ['' 'CenpK']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 111 IDs ...
# 100%     76 of     76 study items found in association
#  68%     76 of    111 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       13 GO terms are associated with     76 of    111 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.15=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#       73 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 GOEA results for    73 study items. WROTE: CenpK__v2_kinetocluster_enrich.txt
# 4
# ['' 'Astrin']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 207 IDs ...
# 100%    182 of    182 study items found in association
#  88%    182 of    207 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       72 GO terms are associated with    182 of    207 study items
#   METHOD fdr_bh:
#       53 GO terms found significant (< 0.15=alpha) ( 41 enriched +  12 purified): statsmodels fdr_bh
#      181 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      51 GOEA results for   180 study items. WROTE: Astrin__v2_kinetocluster_enrich.txt
# 51
# ['' 'CenpF']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 316 IDs ...
# 100%    288 of    288 study items found in association
#  91%    288 of    316 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      111 GO terms are associated with    288 of    316 study items
#   METHOD fdr_bh:
#      104 GO terms found significant (< 0.15=alpha) ( 85 enriched +  19 purified): statsmodels fdr_bh
#      271 study items associated with significant GO IDs (enriched)
#       27 study items associated with significant GO IDs (purified)
# done
# DONE!
#     102 GOEA results for   282 study items. WROTE: CenpF__v2_kinetocluster_enrich.txt
# 102
# ['' 'Apc16' 'Nsl1' 'Ska2']
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 468 IDs ...
# 100%    350 of    350 study items found in association
#  75%    350 of    468 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      164 GO terms are associated with    350 of    468 study items
#   METHOD fdr_bh:
#      136 GO terms found significant (< 0.15=alpha) (118 enriched +  18 purified): statsmodels fdr_bh
#      336 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#     134 GOEA results for   338 study items. WROTE: Apc16_Nsl1_Ska2__v2_kinetocluster_enrich.txt
# 134
# ['' 'CenpT']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 207 IDs ...
# 100%    189 of    189 study items found in association
#  91%    189 of    207 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       79 GO terms are associated with    189 of    207 study items
#   METHOD fdr_bh:
#       61 GO terms found significant (< 0.15=alpha) ( 49 enriched +  12 purified): statsmodels fdr_bh
#      179 study items associated with significant GO IDs (enriched)
#       29 study items associated with significant GO IDs (purified)
# done
# DONE!
#      61 GOEA results for   187 study items. WROTE: CenpT__v2_kinetocluster_enrich.txt
# 61
# ['' 'HORMAD']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 275 IDs ...
# 100%    238 of    238 study items found in association
#  87%    238 of    275 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       94 GO terms are associated with    238 of    275 study items
#   METHOD fdr_bh:
#       81 GO terms found significant (< 0.15=alpha) ( 66 enriched +  15 purified): statsmodels fdr_bh
#      233 study items associated with significant GO IDs (enriched)
#       46 study items associated with significant GO IDs (purified)
# done
# DONE!
#      80 GOEA results for   235 study items. WROTE: HORMAD__v2_kinetocluster_enrich.txt
# 80
# ['' 'Ska3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 384 IDs ...
# 100%    226 of    226 study items found in association
#  59%    226 of    384 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      146 GO terms are associated with    226 of    384 study items
#   METHOD fdr_bh:
#      118 GO terms found significant (< 0.15=alpha) (104 enriched +  14 purified): statsmodels fdr_bh
#      221 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#     116 GOEA results for   221 study items. WROTE: Ska3__v2_kinetocluster_enrich.txt
# 116
# ['' 'CenpR']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 303 IDs ...
# 100%    294 of    294 study items found in association
#  97%    294 of    303 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      119 GO terms are associated with    294 of    303 study items
#   METHOD fdr_bh:
#       82 GO terms found significant (< 0.15=alpha) ( 62 enriched +  20 purified): statsmodels fdr_bh
#      288 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      81 GOEA results for   288 study items. WROTE: CenpR__v2_kinetocluster_enrich.txt
# 81
# ['' 'Apc1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 224 IDs ...
# 100%    186 of    186 study items found in association
#  83%    186 of    224 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       70 GO terms are associated with    186 of    224 study items
#   METHOD fdr_bh:
#       55 GO terms found significant (< 0.15=alpha) ( 45 enriched +  10 purified): statsmodels fdr_bh
#      184 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      54 GOEA results for   185 study items. WROTE: Apc1__v2_kinetocluster_enrich.txt
# 54
# ['' 'CenpH']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 446 IDs ...
# 100%    394 of    394 study items found in association
#  88%    394 of    446 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       86 GO terms are associated with    394 of    446 study items
#   METHOD fdr_bh:
#       81 GO terms found significant (< 0.15=alpha) ( 60 enriched +  21 purified): statsmodels fdr_bh
#      315 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      79 GOEA results for   315 study items. WROTE: CenpH__v2_kinetocluster_enrich.txt
# 79
# ['' 'Cep57']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 12 IDs ...
#   0%      0 of      0 study items found in association
#   0%      0 of     12 study items found in population(8270255)
# done
# DONE!
#       0 GOEA results. NOT WRITING Cep57__v2_kinetocluster_enrich.txt
# 0
# ['' 'MadBub' 'Spindly']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 152 IDs ...
# 100%     62 of     62 study items found in association
#  41%     62 of    152 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       25 GO terms are associated with     62 of    152 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.15=alpha) (  8 enriched +   3 purified): statsmodels fdr_bh
#       48 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      10 GOEA results for    48 study items. WROTE: MadBub_Spindly__v2_kinetocluster_enrich.txt
# 10
# ['' 'Ndc80']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 225 IDs ...
# 100%    182 of    182 study items found in association
#  81%    182 of    225 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       51 GO terms are associated with    182 of    225 study items
#   METHOD fdr_bh:
#       41 GO terms found significant (< 0.15=alpha) ( 26 enriched +  15 purified): statsmodels fdr_bh
#      110 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
# done
# DONE!
#      41 GOEA results for   117 study items. WROTE: Ndc80__v2_kinetocluster_enrich.txt
# 41
# ['' 'Dsn1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 60 IDs ...
# 100%     26 of     26 study items found in association
#  43%     26 of     60 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        6 GO terms are associated with     26 of     60 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  2 enriched +   1 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       2 GOEA results for    25 study items. WROTE: Dsn1__v2_kinetocluster_enrich.txt
# 2
# ['' 'ZW10' 'Incenp' 'Survivin' 'Spc24']
# compiling hogs
# 0
# 10
# 20
# 30
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1014 IDs ...
# 100%    776 of    776 study items found in association
#  77%    776 of  1,014 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      243 GO terms are associated with    776 of  1,014 study items
#   METHOD fdr_bh:
#      212 GO terms found significant (< 0.15=alpha) (161 enriched +  51 purified): statsmodels fdr_bh
#      770 study items associated with significant GO IDs (enriched)
#       40 study items associated with significant GO IDs (purified)
# done
# DONE!
#     208 GOEA results for   772 study items. WROTE: ZW10_Incenp_Survivin_Spc24__v2_kinetocluster_enrich.txt
# 208
# ['' 'CenpO' 'Nup133' 'Apc5']
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 317 IDs ...
# 100%    237 of    237 study items found in association
#  75%    237 of    317 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       73 GO terms are associated with    237 of    317 study items
#   METHOD fdr_bh:
#       48 GO terms found significant (< 0.15=alpha) ( 30 enriched +  18 purified): statsmodels fdr_bh
#      223 study items associated with significant GO IDs (enriched)
#       22 study items associated with significant GO IDs (purified)
# done
# DONE!
#      48 GOEA results for   226 study items. WROTE: CenpO_Nup133_Apc5__v2_kinetocluster_enrich.txt
# 48
# ['' 'Apc12' 'ZW10']
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 659 IDs ...
# 100%    460 of    460 study items found in association
#  70%    460 of    659 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      108 GO terms are associated with    460 of    659 study items
#   METHOD fdr_bh:
#       73 GO terms found significant (< 0.15=alpha) ( 41 enriched +  32 purified): statsmodels fdr_bh
#      411 study items associated with significant GO IDs (enriched)
#       78 study items associated with significant GO IDs (purified)
# done
# DONE!
#      72 GOEA results for   446 study items. WROTE: Apc12_ZW10__v2_kinetocluster_enrich.txt
# 72
# ['' 'Sgo' 'Bub3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 89 IDs ...
# 100%     70 of     70 study items found in association
#  79%     70 of     89 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      155 GO terms are associated with     70 of     89 study items
#   METHOD fdr_bh:
#      140 GO terms found significant (< 0.15=alpha) (138 enriched +   2 purified): statsmodels fdr_bh
#       70 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#     139 GOEA results for    70 study items. WROTE: Sgo_Bub3__v2_kinetocluster_enrich.txt
# 139
# ['' 'ARHGEF17']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 454 IDs ...
# 100%    427 of    427 study items found in association
#  94%    427 of    454 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      138 GO terms are associated with    427 of    454 study items
#   METHOD fdr_bh:
#      130 GO terms found significant (< 0.15=alpha) (104 enriched +  26 purified): statsmodels fdr_bh
#      426 study items associated with significant GO IDs (enriched)
#       68 study items associated with significant GO IDs (purified)
# done
# DONE!
#     126 GOEA results for   426 study items. WROTE: ARHGEF17__v2_kinetocluster_enrich.txt
# 126
# ['' 'Apc15']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 119 IDs ...
# 100%    101 of    101 study items found in association
#  85%    101 of    119 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       36 GO terms are associated with    101 of    119 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.15=alpha) (  8 enriched +   2 purified): statsmodels fdr_bh
#       88 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      10 GOEA results for    88 study items. WROTE: Apc15__v2_kinetocluster_enrich.txt
# 10
# ['' 'CenpL']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2 IDs ...
#   0%      0 of      0 study items found in association
#   0%      0 of      2 study items found in population(8270255)
# done
# DONE!
#       0 GOEA results. NOT WRITING CenpL__v2_kinetocluster_enrich.txt
# 0
# ['' 'Apc11']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 41 IDs ...
# 100%     10 of     10 study items found in association
#  24%     10 of     41 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       14 GO terms are associated with     10 of     41 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 GOEA results. NOT WRITING Apc11__v2_kinetocluster_enrich.txt
# 0
# ['' 'CenpM']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 91 IDs ...
# 100%     85 of     85 study items found in association
#  93%     85 of     91 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       15 GO terms are associated with     85 of     91 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.15=alpha) ( 12 enriched +   4 purified): statsmodels fdr_bh
#       85 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 GOEA results for    85 study items. WROTE: CenpM__v2_kinetocluster_enrich.txt
# 15
# ['' 'Apc10']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING Apc10__v2_kinetocluster_enrich.txt
# 0
# ['' 'Mis12']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 267 IDs ...
# 100%    146 of    146 study items found in association
#  55%    146 of    267 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with    146 of    267 study items
#   METHOD fdr_bh:
#       33 GO terms found significant (< 0.15=alpha) ( 21 enriched +  12 purified): statsmodels fdr_bh
#      136 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      32 GOEA results for   142 study items. WROTE: Mis12__v2_kinetocluster_enrich.txt
# 32
# ['' 'Mad2' 'Apc2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 353 IDs ...
# 100%    258 of    258 study items found in association
#  73%    258 of    353 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       91 GO terms are associated with    258 of    353 study items
#   METHOD fdr_bh:
#       79 GO terms found significant (< 0.15=alpha) ( 61 enriched +  18 purified): statsmodels fdr_bh
#      253 study items associated with significant GO IDs (enriched)
#       20 study items associated with significant GO IDs (purified)
# done
# DONE!
#      79 GOEA results for   255 study items. WROTE: Mad2_Apc2__v2_kinetocluster_enrich.txt
# 79
# ['' 'Rod']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 97 IDs ...
# 100%     92 of     92 study items found in association
#  95%     92 of     97 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       19 GO terms are associated with     92 of     97 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.15=alpha) (  2 enriched +   5 purified): statsmodels fdr_bh
#       89 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#       6 GOEA results for    90 study items. WROTE: Rod__v2_kinetocluster_enrich.txt
# 6
# ['' 'Spindly']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING Spindly__v2_kinetocluster_enrich.txt
# 0
# ['' 'Apc4']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING Apc4__v2_kinetocluster_enrich.txt
# 0
# ['' 'NAG']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 520 IDs ...
# 100%    323 of    323 study items found in association
#  62%    323 of    520 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       57 GO terms are associated with    323 of    520 study items
#   METHOD fdr_bh:
#       49 GO terms found significant (< 0.15=alpha) ( 28 enriched +  21 purified): statsmodels fdr_bh
#      312 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
# done
# DONE!
#      49 GOEA results for   315 study items. WROTE: NAG__v2_kinetocluster_enrich.txt
# 49
# ['' 'Ndc80']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 4 IDs ...
# 100%      3 of      3 study items found in association
#  75%      3 of      4 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        7 GO terms are associated with      3 of      4 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 GOEA results. NOT WRITING Ndc80__v2_kinetocluster_enrich.txt
# 0
# ['' 'Ska1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 330 IDs ...
# 100%    261 of    261 study items found in association
#  79%    261 of    330 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       24 GO terms are associated with    261 of    330 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.15=alpha) ( 14 enriched +  21 purified): statsmodels fdr_bh
#      256 study items associated with significant GO IDs (enriched)
#       11 study items associated with significant GO IDs (purified)
# done
# DONE!
#      34 GOEA results for   261 study items. WROTE: Ska1__v2_kinetocluster_enrich.txt
# 34
# ['' 'Skp1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 598 IDs ...
# 100%    463 of    463 study items found in association
#  77%    463 of    598 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       73 GO terms are associated with    463 of    598 study items
#   METHOD fdr_bh:
#       80 GO terms found significant (< 0.15=alpha) ( 47 enriched +  33 purified): statsmodels fdr_bh
#      462 study items associated with significant GO IDs (enriched)
#       32 study items associated with significant GO IDs (purified)
# done
# DONE!
#      80 GOEA results for   463 study items. WROTE: Skp1__v2_kinetocluster_enrich.txt
# 80
# ['' 'Dad4']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 383 IDs ...
# 100%    259 of    259 study items found in association
#  68%    259 of    383 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with    259 of    383 study items
#   METHOD fdr_bh:
#       33 GO terms found significant (< 0.15=alpha) ( 14 enriched +  19 purified): statsmodels fdr_bh
#      231 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      32 GOEA results for   233 study items. WROTE: Dad4__v2_kinetocluster_enrich.txt
# 32
# ['' 'Dad3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 161 IDs ...
# 100%    128 of    128 study items found in association
#  80%    128 of    161 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       23 GO terms are associated with    128 of    161 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.15=alpha) (  7 enriched +   5 purified): statsmodels fdr_bh
#      126 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      12 GOEA results for   126 study items. WROTE: Dad3__v2_kinetocluster_enrich.txt
# 12

# %%
def donuts_GO( filename , allprots ):
    #this function will read the GO enrichment output and show the proportion of each HOGs annotation for the top 5 GO terms
    #as well as the proportion of each of the top 5 GO terms contributed by each HOG
    #If the HOGs share GO annotations and coevolved but contain non homologous sequences, they are probably involved in the same network
    with open( filename , 'r') as filein:
        vals = np.zeros( (5,40))
        GOterms = []
        pvals = []
        depths = []
        for i,line in enumerate(filein):
            words = line.split(',')
            if i < 5:
                prots = words[1:]
                prots += words[0].split()[-1]
                GOterms.append(words[0].split()[0])
                description= ''.join( [ word + ' ' for word in words[0].split()[0:-1] ] )
                print(description)
                for prot in prots:
                    try:
                        counts[allprots[prot.strip()]]+=1
                    except:
                        pass
                for col,hog in enumerate(counts):
                    vals[i,col] = counts[hog]
            if int(words[0].split()[3].split('/')[0])>0 and float(words[0].split()[2]) <1:
                pvals.append(float(words[0].split()[2]))
        fig, ax = plt.subplots()
        size = 0.3
        cmap = plt.get_cmap("tab20c")
        outer_colors = cmap(np.arange(len(GOterms))*4)
        inner_colors = cmap(np.array([1, 2, 5, 6, 9]))

        ax.pie(vals.sum(axis=1),  labels=GOterms ,radius=1, colors=outer_colors,
               wedgeprops=dict(width=size, edgecolor='w'))
        ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
               wedgeprops=dict(width=size, edgecolor='w'))
        ax.set(aspect="equal", title= 'query w/ '+ hog)

        #### do the inverse
        fig, ax = plt.subplots()
        size = 0.3
        cmap = plt.get_cmap("tab20c")
        inner_colors = cmap(np.arange(len(GOterms))*4)
        outer_colors = cmap(np.array([1, 2, 5, 6, 9]))
        labels = [ c  if counts[c]>50 else ''  for c in counts.keys() ]
        ax.pie(vals.sum(axis=0),  labels=list(counts.keys()) ,radius=1, colors=outer_colors,
               wedgeprops=dict(width=size, edgecolor='w'))
        ax.pie(vals.T.flatten(), radius=1-size, colors=inner_colors,
               wedgeprops=dict(width=size, edgecolor='w'))
        ax.set(aspect="equal", title= 'query w/ '+ hog)
        plt.show()
        fig, ax = plt.subplots()
        size = 0.3
        ax.hist( np.log(1-np.asarray(pvals)), bins = 10)
        ax.set( title= 'pvals for query w/ '+ hog)
        plt.show()

# %%
#now lets look at a completely unknown network: sexual reproduction
#lets star with 3 queries of known proteins

# %%
#search Hap2 SPo11 Gex1
#mapping Hap2's uniprot ID to its OMA entry and querying with the OMA HOG
#we can use a pretty broad search to get the 200 closest profiles since we're only considering one HOG at a time
hap2= p.db_obj.id_resolver.resolve('f4jp36')
entry = p.db_obj.entry_by_entry_nr(hap2)
print(entry)
hap2hogs = p.hog_query(hog_id= str(entry[4]) ,  k=50)

#same for gex1
gex1= p.db_obj.id_resolver.resolve('A0A1P8B9F7')
entry = p.db_obj.entry_by_entry_nr(gex1)
print(entry)
gexhogs = p.hog_query(hog_id= str(entry[4]) , k=50)

#and spo11
spo11= p.db_obj.id_resolver.resolve('Q9M4A2')
entry = p.db_obj.entry_by_entry_nr(spo11)
print(entry)
spohogs = p.hog_query(hog_id= str(entry[4]) , k=50 )
# Out:
# (12398377, 4765549562, 706, 668654, b'HOG:0406399.2a.10b', b'4', 7063291, 7066784, 1, 0, b'HAP2_ARATH', 14309047062, 2119, b'64dcfddd880e7d4265a77286668f7be9', 630450286, 25, b'', -1, -1)
# (12410572, 4770822388, 516, 489288, b'HOG:0416115.3a', b'5', 22479153, 22481071, -1, 12410572, b'A0A1P8B9F7', 14324877735, 1549, b'c9c8e5d3b55063acdc397a5f1cd18710', 630755194, 25, b'', -1, -1)
# (12390911, 4762429318, 363, 831713, b'HOG:0605395.4b.6b', b'3', 4231560, 4234192, -1, 12390911, b'SPO11_ARATH', 14299678864, 1090, b'620e28803b4c72fae834a355cd77b6f3', 630263631, 25, b'', -1, -1)

# %%
#reading in the sequence identifiers for all HOGs pulled down in a search from the HDF5 can take some time
goares = {}
searches = {'hap':hap2hogs, 'gex':gexhogs, 'spo':spohogs}
for res in searches:
    goares[res] = goa.run_GOEA_onresults( searches[res], p.db_obj, study)
# Out:
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1024 IDs ...
# 100%    696 of    696 study items found in association
#  68%    696 of  1,024 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      159 GO terms are associated with    696 of  1,024 study items
#   METHOD fdr_bh:
#       92 GO terms found significant (< 0.15=alpha) ( 52 enriched +  40 purified): statsmodels fdr_bh
#      490 study items associated with significant GO IDs (enriched)
#      243 study items associated with significant GO IDs (purified)
# done
# DONE!
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 487 IDs ...
# 100%    339 of    339 study items found in association
#  70%    339 of    487 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       93 GO terms are associated with    339 of    487 study items
#   METHOD fdr_bh:
#       51 GO terms found significant (< 0.15=alpha) ( 34 enriched +  17 purified): statsmodels fdr_bh
#      318 study items associated with significant GO IDs (enriched)
#       32 study items associated with significant GO IDs (purified)
# done
# DONE!
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2371 IDs ...
# 100%  1,404 of  1,404 study items found in association
#  59%  1,404 of  2,371 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      138 GO terms are associated with  1,404 of  2,371 study items
#   METHOD fdr_bh:
#      176 GO terms found significant (< 0.15=alpha) ( 72 enriched + 104 purified): statsmodels fdr_bh
#    1,025 study items associated with significant GO IDs (enriched)
#      452 study items associated with significant GO IDs (purified)
# done
# DONE!

# %%
for res in goares:
    goea_results_sig = [r for r in goares[res][0] if r.p_fdr_bh < 0.05]
    study.wr_txt(res + "enrich.txt", goea_results_sig)
    print(len(goea_results_sig))
# Out:
#      84 GOEA results for   686 study items. WROTE: hapenrich.txt
# 84
#      46 GOEA results for   326 study items. WROTE: gexenrich.txt
# 46
#     159 GOEA results for  1387 study items. WROTE: spoenrich.txt
# 159

# %%
#And now let's try the same thing with a bigger list of candidate genes
#load reproduction pathway hogs. These were downloaded from the SGD database as tsv files by selecting salient go terms. I added a few non yeast entries manually
hogdf = pd.DataFrame.from_csv('./repro_hogs.csv')
hogdf['HOG'] = hogdf['1'].map( grabHog )
hogdf = hogdf[ ~hogdf.HOG.isna() ]
hashes = p.pull_hashes( [h for h in hogdf.HOG if len(h)>0] )
hogdf['hashsig'] = hogdf.HOG.map(hashes)
hogdf = hogdf[ ~hogdf.hashsig.isnull() ]
hogdf = hogdf.drop_duplicates('3')

names = dict(zip( hogdf.HOG, hogdf['3']))
print(hogdf.head())
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   This is separate from the ipykernel package so we can avoid doing imports until
#               0        1              2     3  \
# 0.0  S000001692  YKL209C  S. cerevisiae  STE6
# 1.0  S000002248  YDL090C  S. cerevisiae  RAM1
# 2.0  S000006326  YPR122W  S. cerevisiae  AXL1
# 0.0  S000000951  YER149C  S. cerevisiae  PEA2
# 1.0  S000003944  YLL021W  S. cerevisiae  SPA2
#
#                                        4  \
# 0.0                              STErile
# 1.0  RAS protein and A-factor Maturation
# 2.0                        AXiaL budding
# 0.0                  PEAnut shmoo mutant
# 1.0                 Spindle Pole Antigen
#
#                                           path      OMAID             HOG  \
# 0.0  ./yeastmating/results_signal_strength.tsv  6844990.0     HOG:0259166
# 1.0  ./yeastmating/results_signal_strength.tsv  6842368.0  HOG:0405589.7a
# 2.0  ./yeastmating/results_signal_strength.tsv  6847757.0     HOG:0219055
# 0.0       ./yeastmating/results_polarisome.tsv  6843538.0     HOG:0217913
# 1.0       ./yeastmating/results_polarisome.tsv  6845359.0     HOG:0220110
#
#                                                hashsig
# 0.0  <datasketch.weighted_minhash.WeightedMinHash o...
# 1.0  <datasketch.weighted_minhash.WeightedMinHash o...
# 2.0  <datasketch.weighted_minhash.WeightedMinHash o...
# 0.0  <datasketch.weighted_minhash.WeightedMinHash o...
# 1.0  <datasketch.weighted_minhash.WeightedMinHash o...

# %%
#lets take a look at the clustering of our queries to see if some are coevolving and we can already notice some organisation
jkern = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(hogdf.hashsig) ] for i,h1 in enumerate(hogdf.hashsig)]
jkern = np.asarray(jkern)
jkern+=jkern.T
np.fill_diagonal(jkern , 1 )
g = sns.clustermap( jkern , xticklabels= hogdf['3'] , yticklabels= hogdf['3'] , figsize = (25,25) )

# %%
#now lets fill in our network with some putative interactors
res = { h: p.hog_query( hog_id=str(h) , k = 20 ) for h in hogdf.HOG}
Hogs = [ h for results in res.values() for h in results ] + list(res.keys())

# %%
profiles = profiles = p.pull_hashes( set(Hogs) )
profiles = { h: {'hashsig': profiles[h] , 'name': names[h]  } if h in names else {'hashsig': profiles[h] , 'name': ''  }   for h in profiles }
profiles = pd.DataFrame.from_dict( profiles , orient='index' )

print(profiles.name.unique())
print(len(profiles.name.unique()))

print(len(profiles))
# Out:
# ['' 'SPO21' 'SPO12' 'PFS1' 'SPO13' 'SPO74' 'SPO19' 'SHC1' 'SPO77' 'PRM3'
#  'SPO20' 'SPS18' 'STE7' 'SPO71' 'AGA2' 'PEA2' 'SPS1' 'ISC10' 'MPS3'
#  'SPO16' 'NUD1' 'AGA1' 'SAG1' 'MLH2' 'MPC54' 'HOP1' 'SSP1' 'SPS100' 'KAR9'
#  'SPO1' 'SPO23' 'SSP2' 'CIK1' 'REC8' 'STE12' 'SPO24' 'FUS1' 'FUS2' 'PRM2'
#  'KAR1' 'FAR1' 'STE5' 'MUM3' 'SPC72' 'AMA1' 'SPS4' 'AXL1' 'KAR5' 'RSC1'
#  'HOP2' 'STE20' 'PMD1' 'SPR3' 'SPO75' 'STE18' 'FIG1' 'BIK1' 'SPS2' 'SPS22'
#  'SPO73' 'SPA2' 'LDS1' 'SPO7' 'STE3' 'SEC66' 'SPO11' 'HFM1' 'STE6' 'UFE1'
#  'CDC24' 'OSH3' 'BNI1' 'PRM1' 'SPO22' 'JEM1' 'RAD50' 'FUS3' 'STE11' 'MYO2'
#  'SPO14' 'MSH4' 'CDC10' 'SPR28' 'SPS19' 'RAD52' 'SPR1' 'MLH1' 'KAR2'
#  'MSH6' 'MSH5' 'MSH2' 'RAM1' 'HAP2' 'MRE11' 'KAR4' 'RAD18' 'BIM1' 'SHP1'
#  'GPA1' 'CDC42' 'RSR1' 'MLH3' 'PMS1' 'RAD1' 'SMC5' 'RAD51' 'DMC1' 'CDC48'
#  'ERG6' 'MND1' 'SEC63' 'PDS5' 'STE4' 'SMC2' 'MCK1' 'SMC1' 'MYO5' 'SMC4'
#  'KAR3' 'EMI2' 'SMC3']
# 121
# 2065

# %%
#lets calculate a new jaccard kernel for all of our search results and queries 
#again we can divide our results into clusters and try to see if each has a functional signature using GO enrichment
jkern = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(profiles.hashsig) ] for i,h1 in enumerate(profiles.hashsig)]
jkern = np.asarray(jkern)
jkern+=jkern.T
np.fill_diagonal(jkern , 1 )

# %%
z = scipy.cluster.hierarchy.linkage(jkern, method='single', metric='euclidean')
clusters = scipy.cluster.hierarchy.fcluster(z, t=0.995, criterion='distance')
colors = [ c.hex_l for c in red.range_to( blue , len(set(clusters)) ) ]
colordict2 = dict( zip( list(set(clusters)) , list(colors)))
rowcolors = [ colordict2[c] for c in clusters]
g = sns.clustermap( jkern , xticklabels= profiles.name , yticklabels= profiles.name , figsize = (20,20) , row_colors=rowcolors )
plt.show()

# %%
#and here we perform our enrichment of each cluster with a query in it
goares = {}

for c in np.unique(clusters):
    sub = profiles.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        study.wr_txt(namestr + "_reprocluster_enrich.txt", goea_results_sig)
        print(len(goea_results_sig))
# Out:
# ['' 'REC8']
# {'HOG:0218461'}
# ['218461']
#                                                   hashsig name
# 218313  <datasketch.weighted_minhash.WeightedMinHash o...
# 218786  <datasketch.weighted_minhash.WeightedMinHash o...
# 218827  <datasketch.weighted_minhash.WeightedMinHash o...
# 219333  <datasketch.weighted_minhash.WeightedMinHash o...
# 219380  <datasketch.weighted_minhash.WeightedMinHash o...
# 219449  <datasketch.weighted_minhash.WeightedMinHash o...
# 219466  <datasketch.weighted_minhash.WeightedMinHash o...
# 219492  <datasketch.weighted_minhash.WeightedMinHash o...
# 220344  <datasketch.weighted_minhash.WeightedMinHash o...
# 220453  <datasketch.weighted_minhash.WeightedMinHash o...
# 220487  <datasketch.weighted_minhash.WeightedMinHash o...
# 220592  <datasketch.weighted_minhash.WeightedMinHash o...
# 220770  <datasketch.weighted_minhash.WeightedMinHash o...
# 220938  <datasketch.weighted_minhash.WeightedMinHash o...
# 220940  <datasketch.weighted_minhash.WeightedMinHash o...
# 220991  <datasketch.weighted_minhash.WeightedMinHash o...
# 221211  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 127 IDs ...
# 100%     86 of     86 study items found in association
#  68%     86 of    127 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       65 GO terms are associated with     86 of    127 study items
#   METHOD fdr_bh:
#       24 GO terms found significant (< 0.15=alpha) ( 23 enriched +   1 purified): statsmodels fdr_bh
#       77 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      24 GOEA results for    77 study items. WROTE: REC8__reprocluster_enrich.txt
# 24
# ['' 'SPS2' 'SPS22']
# {'HOG:0219845.1a', 'HOG:0219845.1b'}
# ['219845', '219845']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPS2_SPS22__reprocluster_enrich.txt
# 0
# ['' 'SPO75']
# {'HOG:0219677'}
# ['219677']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO75__reprocluster_enrich.txt
# 0
# ['' 'STE20']
# {'HOG:0219392'}
# ['219392']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING STE20__reprocluster_enrich.txt
# 0
# ['' 'HOP2']
# {'HOG:0219365.2b'}
# ['219365']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING HOP2__reprocluster_enrich.txt
# 0
# ['' 'SPO24']
# {'HOG:0218505'}
# ['218505']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO24__reprocluster_enrich.txt
# 0
# ['' 'SPR3']
# {'HOG:0219538'}
# ['219538']
#                                                   hashsig name
# 218952  <datasketch.weighted_minhash.WeightedMinHash o...
# 219063  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 132 IDs ...
# 100%    129 of    129 study items found in association
#  98%    129 of    132 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       41 GO terms are associated with    129 of    132 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.15=alpha) ( 24 enriched +  11 purified): statsmodels fdr_bh
#      126 study items associated with significant GO IDs (enriched)
#       27 study items associated with significant GO IDs (purified)
# done
# DONE!
#      33 GOEA results for   126 study items. WROTE: SPR3__reprocluster_enrich.txt
# 33
# ['' 'SPA2']
# {'HOG:0220110'}
# ['220110']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPA2__reprocluster_enrich.txt
# 0
# ['' 'KAR9']
# {'HOG:0218343'}
# ['218343']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING KAR9__reprocluster_enrich.txt
# 0
# ['' 'SPO23']
# {'HOG:0218418'}
# ['218418']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO23__reprocluster_enrich.txt
# 0
# ['' 'SPS100']
# {'HOG:0218320.2a'}
# ['218320']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPS100__reprocluster_enrich.txt
# 0
# ['' 'FUS1']
# {'HOG:0218522'}
# ['218522']
#                                                   hashsig name
# 218794  <datasketch.weighted_minhash.WeightedMinHash o...
# 219465  <datasketch.weighted_minhash.WeightedMinHash o...
# 219717  <datasketch.weighted_minhash.WeightedMinHash o...
# 220918  <datasketch.weighted_minhash.WeightedMinHash o...
# 221183  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 48 IDs ...
# 100%     44 of     44 study items found in association
#  92%     44 of     48 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       28 GO terms are associated with     44 of     48 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.15=alpha) ( 14 enriched +   2 purified): statsmodels fdr_bh
#       44 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      16 GOEA results for    44 study items. WROTE: FUS1__reprocluster_enrich.txt
# 16
# ['' 'LDS1']
# {'HOG:0220154.1b'}
# ['220154']
#                                                   hashsig name
# 219051  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 7 IDs ...
# 100%      6 of      6 study items found in association
#  86%      6 of      7 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        3 GO terms are associated with      6 of      7 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       3 GOEA results for     6 study items. WROTE: LDS1__reprocluster_enrich.txt
# 3
# ['' 'SSP2' 'CIK1']
# {'HOG:0218424', 'HOG:0218435.1b'}
# ['218424', '218435']
#                                                   hashsig name
# 218314  <datasketch.weighted_minhash.WeightedMinHash o...
# 219131  <datasketch.weighted_minhash.WeightedMinHash o...
# 219362  <datasketch.weighted_minhash.WeightedMinHash o...
# 219476  <datasketch.weighted_minhash.WeightedMinHash o...
# 219730  <datasketch.weighted_minhash.WeightedMinHash o...
# 219786  <datasketch.weighted_minhash.WeightedMinHash o...
# 219859  <datasketch.weighted_minhash.WeightedMinHash o...
# 220204  <datasketch.weighted_minhash.WeightedMinHash o...
# 220210  <datasketch.weighted_minhash.WeightedMinHash o...
# 220525  <datasketch.weighted_minhash.WeightedMinHash o...
# 220845  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 68 IDs ...
# 100%     54 of     54 study items found in association
#  79%     54 of     68 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       44 GO terms are associated with     54 of     68 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.15=alpha) ( 17 enriched +   0 purified): statsmodels fdr_bh
#       51 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      16 GOEA results for    51 study items. WROTE: SSP2_CIK1__reprocluster_enrich.txt
# 16
# ['' 'SPC72']
# {'HOG:0218807'}
# ['218807']
#                                                   hashsig name
# 218388  <datasketch.weighted_minhash.WeightedMinHash o...
# 218460  <datasketch.weighted_minhash.WeightedMinHash o...
# 218520  <datasketch.weighted_minhash.WeightedMinHash o...
# 218596  <datasketch.weighted_minhash.WeightedMinHash o...
# 218619  <datasketch.weighted_minhash.WeightedMinHash o...
# 218666  <datasketch.weighted_minhash.WeightedMinHash o...
# 218730  <datasketch.weighted_minhash.WeightedMinHash o...
# 218865  <datasketch.weighted_minhash.WeightedMinHash o...
# 218910  <datasketch.weighted_minhash.WeightedMinHash o...
# 219005  <datasketch.weighted_minhash.WeightedMinHash o...
# 219130  <datasketch.weighted_minhash.WeightedMinHash o...
# 219142  <datasketch.weighted_minhash.WeightedMinHash o...
# 219161  <datasketch.weighted_minhash.WeightedMinHash o...
# 219311  <datasketch.weighted_minhash.WeightedMinHash o...
# 219355  <datasketch.weighted_minhash.WeightedMinHash o...
# 219368  <datasketch.weighted_minhash.WeightedMinHash o...
# 219424  <datasketch.weighted_minhash.WeightedMinHash o...
# 219901  <datasketch.weighted_minhash.WeightedMinHash o...
# 220023  <datasketch.weighted_minhash.WeightedMinHash o...
# 220082  <datasketch.weighted_minhash.WeightedMinHash o...
# 220155  <datasketch.weighted_minhash.WeightedMinHash o...
# 220283  <datasketch.weighted_minhash.WeightedMinHash o...
# 220505  <datasketch.weighted_minhash.WeightedMinHash o...
# 220512  <datasketch.weighted_minhash.WeightedMinHash o...
# 220718  <datasketch.weighted_minhash.WeightedMinHash o...
# 220740  <datasketch.weighted_minhash.WeightedMinHash o...
# 220759  <datasketch.weighted_minhash.WeightedMinHash o...
# 220769  <datasketch.weighted_minhash.WeightedMinHash o...
# 220848  <datasketch.weighted_minhash.WeightedMinHash o...
# 220854  <datasketch.weighted_minhash.WeightedMinHash o...
# 221132  <datasketch.weighted_minhash.WeightedMinHash o...
# 221172  <datasketch.weighted_minhash.WeightedMinHash o...
# 221191  <datasketch.weighted_minhash.WeightedMinHash o...
# 221282  <datasketch.weighted_minhash.WeightedMinHash o...
# 221283  <datasketch.weighted_minhash.WeightedMinHash o...
# 221344  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# 20
# 30
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 229 IDs ...
# 100%    140 of    140 study items found in association
#  61%    140 of    229 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      137 GO terms are associated with    140 of    229 study items
#   METHOD fdr_bh:
#       63 GO terms found significant (< 0.15=alpha) ( 55 enriched +   8 purified): statsmodels fdr_bh
#      119 study items associated with significant GO IDs (enriched)
#       23 study items associated with significant GO IDs (purified)
# done
# DONE!
#      63 GOEA results for   133 study items. WROTE: SPC72__reprocluster_enrich.txt
# 63
# ['' 'FIG1']
# {'HOG:0219823'}
# ['219823']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING FIG1__reprocluster_enrich.txt
# 0
# ['' 'MUM3']
# {'HOG:0218797'}
# ['218797']
#                                                   hashsig name
# 218446  <datasketch.weighted_minhash.WeightedMinHash o...
# 218696  <datasketch.weighted_minhash.WeightedMinHash o...
# 218839  <datasketch.weighted_minhash.WeightedMinHash o...
# 219315  <datasketch.weighted_minhash.WeightedMinHash o...
# 219856  <datasketch.weighted_minhash.WeightedMinHash o...
# 220613  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 51 IDs ...
# 100%     38 of     38 study items found in association
#  75%     38 of     51 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       23 GO terms are associated with     38 of     51 study items
#   METHOD fdr_bh:
#        9 GO terms found significant (< 0.15=alpha) (  7 enriched +   2 purified): statsmodels fdr_bh
#       34 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       9 GOEA results for    34 study items. WROTE: MUM3__reprocluster_enrich.txt
# 9
# ['' 'FUS2']
# {'HOG:0218583'}
# ['218583']
#                                                   hashsig name
# 218365  <datasketch.weighted_minhash.WeightedMinHash o...
# 218626  <datasketch.weighted_minhash.WeightedMinHash o...
# 218628  <datasketch.weighted_minhash.WeightedMinHash o...
# 218751  <datasketch.weighted_minhash.WeightedMinHash o...
# 219408  <datasketch.weighted_minhash.WeightedMinHash o...
# 219810  <datasketch.weighted_minhash.WeightedMinHash o...
# 219815  <datasketch.weighted_minhash.WeightedMinHash o...
# 220071  <datasketch.weighted_minhash.WeightedMinHash o...
# 220196  <datasketch.weighted_minhash.WeightedMinHash o...
# 220455  <datasketch.weighted_minhash.WeightedMinHash o...
# 220665  <datasketch.weighted_minhash.WeightedMinHash o...
# 220905  <datasketch.weighted_minhash.WeightedMinHash o...
# 221362  <datasketch.weighted_minhash.WeightedMinHash o...
# 221380  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 74 IDs ...
# 100%     54 of     54 study items found in association
#  73%     54 of     74 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       41 GO terms are associated with     54 of     74 study items
#   METHOD fdr_bh:
#       20 GO terms found significant (< 0.15=alpha) ( 20 enriched +   0 purified): statsmodels fdr_bh
#       36 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      20 GOEA results for    36 study items. WROTE: FUS2__reprocluster_enrich.txt
# 20
# ['' 'STE12']
# {'HOG:0218493'}
# ['218493']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING STE12__reprocluster_enrich.txt
# 0
# ['' 'FAR1' 'AXL1']
# {'HOG:0218693', 'HOG:0219055'}
# ['218693', '219055']
#                                                   hashsig name
# 218342  <datasketch.weighted_minhash.WeightedMinHash o...
# 218499  <datasketch.weighted_minhash.WeightedMinHash o...
# 218536  <datasketch.weighted_minhash.WeightedMinHash o...
# 219043  <datasketch.weighted_minhash.WeightedMinHash o...
# 219047  <datasketch.weighted_minhash.WeightedMinHash o...
# 219504  <datasketch.weighted_minhash.WeightedMinHash o...
# 219544  <datasketch.weighted_minhash.WeightedMinHash o...
# 219678  <datasketch.weighted_minhash.WeightedMinHash o...
# 219696  <datasketch.weighted_minhash.WeightedMinHash o...
# 219813  <datasketch.weighted_minhash.WeightedMinHash o...
# 219924  <datasketch.weighted_minhash.WeightedMinHash o...
# 220099  <datasketch.weighted_minhash.WeightedMinHash o...
# 220123  <datasketch.weighted_minhash.WeightedMinHash o...
# 220339  <datasketch.weighted_minhash.WeightedMinHash o...
# 221042  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 189 IDs ...
# 100%    148 of    148 study items found in association
#  78%    148 of    189 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      106 GO terms are associated with    148 of    189 study items
#   METHOD fdr_bh:
#       73 GO terms found significant (< 0.15=alpha) ( 65 enriched +   8 purified): statsmodels fdr_bh
#      136 study items associated with significant GO IDs (enriched)
#       28 study items associated with significant GO IDs (purified)
# done
# DONE!
#      71 GOEA results for   144 study items. WROTE: FAR1_AXL1__reprocluster_enrich.txt
# 71
# ['' 'STE18']
# {'HOG:0219743'}
# ['219743']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING STE18__reprocluster_enrich.txt
# 0
# ['' 'RSC1']
# {'HOG:0219321.2b'}
# ['219321']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING RSC1__reprocluster_enrich.txt
# 0
# ['' 'SPO20']
# {'HOG:0217573'}
# ['217573']
#                                                   hashsig name
# 216158  <datasketch.weighted_minhash.WeightedMinHash o...
# 216215  <datasketch.weighted_minhash.WeightedMinHash o...
# 216346  <datasketch.weighted_minhash.WeightedMinHash o...
# 216495  <datasketch.weighted_minhash.WeightedMinHash o...
# 216785  <datasketch.weighted_minhash.WeightedMinHash o...
# 216804  <datasketch.weighted_minhash.WeightedMinHash o...
# 217053  <datasketch.weighted_minhash.WeightedMinHash o...
# 217150  <datasketch.weighted_minhash.WeightedMinHash o...
# 217173  <datasketch.weighted_minhash.WeightedMinHash o...
# 217438  <datasketch.weighted_minhash.WeightedMinHash o...
# 217628  <datasketch.weighted_minhash.WeightedMinHash o...
# 217694  <datasketch.weighted_minhash.WeightedMinHash o...
# 217735  <datasketch.weighted_minhash.WeightedMinHash o...
# 217739  <datasketch.weighted_minhash.WeightedMinHash o...
# 218009  <datasketch.weighted_minhash.WeightedMinHash o...
# 218096  <datasketch.weighted_minhash.WeightedMinHash o...
# 218140  <datasketch.weighted_minhash.WeightedMinHash o...
# 218239  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 95 IDs ...
# 100%     62 of     62 study items found in association
#  65%     62 of     95 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       63 GO terms are associated with     62 of     95 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.15=alpha) ( 12 enriched +   0 purified): statsmodels fdr_bh
#       44 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       8 GOEA results for    43 study items. WROTE: SPO20__reprocluster_enrich.txt
# 8
# ['' 'SPS18']
# {'HOG:0217577'}
# ['217577']
#                                                   hashsig name
# 216103  <datasketch.weighted_minhash.WeightedMinHash o...
# 216254  <datasketch.weighted_minhash.WeightedMinHash o...
# 216355  <datasketch.weighted_minhash.WeightedMinHash o...
# 217043  <datasketch.weighted_minhash.WeightedMinHash o...
# 217061  <datasketch.weighted_minhash.WeightedMinHash o...
# 217348  <datasketch.weighted_minhash.WeightedMinHash o...
# 217728  <datasketch.weighted_minhash.WeightedMinHash o...
# 217877  <datasketch.weighted_minhash.WeightedMinHash o...
# 217888  <datasketch.weighted_minhash.WeightedMinHash o...
# 217976  <datasketch.weighted_minhash.WeightedMinHash o...
# 218190  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 69 IDs ...
# 100%     46 of     46 study items found in association
#  67%     46 of     69 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       69 GO terms are associated with     46 of     69 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.15=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#       31 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      11 GOEA results for    31 study items. WROTE: SPS18__reprocluster_enrich.txt
# 11
# ['' 'SPO71']
# {'HOG:0217730'}
# ['217730']
#                                                   hashsig name
# 216187  <datasketch.weighted_minhash.WeightedMinHash o...
# 216360  <datasketch.weighted_minhash.WeightedMinHash o...
# 216446  <datasketch.weighted_minhash.WeightedMinHash o...
# 216716  <datasketch.weighted_minhash.WeightedMinHash o...
# 216921  <datasketch.weighted_minhash.WeightedMinHash o...
# 216935  <datasketch.weighted_minhash.WeightedMinHash o...
# 217012  <datasketch.weighted_minhash.WeightedMinHash o...
# 217478  <datasketch.weighted_minhash.WeightedMinHash o...
# 217674  <datasketch.weighted_minhash.WeightedMinHash o...
# 217767  <datasketch.weighted_minhash.WeightedMinHash o...
# 217887  <datasketch.weighted_minhash.WeightedMinHash o...
# 218046  <datasketch.weighted_minhash.WeightedMinHash o...
# 218271  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 65 IDs ...
# 100%     42 of     42 study items found in association
#  65%     42 of     65 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       37 GO terms are associated with     42 of     65 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.15=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#       32 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      11 GOEA results for    32 study items. WROTE: SPO71__reprocluster_enrich.txt
# 11
# ['' 'AGA1' 'SAG1']
# {'HOG:0218063.3m', 'HOG:0218063.3h'}
# ['218063', '218063']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING AGA1_SAG1__reprocluster_enrich.txt
# 0
# ['' 'SPO12']
# {'HOG:0217297'}
# ['217297']
#                                                   hashsig name
# 216272  <datasketch.weighted_minhash.WeightedMinHash o...
# 216988  <datasketch.weighted_minhash.WeightedMinHash o...
# 217024  <datasketch.weighted_minhash.WeightedMinHash o...
# 217685  <datasketch.weighted_minhash.WeightedMinHash o...
# 217782  <datasketch.weighted_minhash.WeightedMinHash o...
# 217875  <datasketch.weighted_minhash.WeightedMinHash o...
# 217893  <datasketch.weighted_minhash.WeightedMinHash o...
# 217914  <datasketch.weighted_minhash.WeightedMinHash o...
# 217947  <datasketch.weighted_minhash.WeightedMinHash o...
# 217963  <datasketch.weighted_minhash.WeightedMinHash o...
# 218114  <datasketch.weighted_minhash.WeightedMinHash o...
# 218256  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 95 IDs ...
# 100%     46 of     46 study items found in association
#  48%     46 of     95 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       63 GO terms are associated with     46 of     95 study items
#   METHOD fdr_bh:
#       26 GO terms found significant (< 0.15=alpha) ( 26 enriched +   0 purified): statsmodels fdr_bh
#       44 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      24 GOEA results for    44 study items. WROTE: SPO12__reprocluster_enrich.txt
# 24
# ['' 'STE7']
# {'HOG:0217590.1b'}
# ['217590']
#                                                   hashsig name
# 216568  <datasketch.weighted_minhash.WeightedMinHash o...
# 216647  <datasketch.weighted_minhash.WeightedMinHash o...
# 216830  <datasketch.weighted_minhash.WeightedMinHash o...
# 216924  <datasketch.weighted_minhash.WeightedMinHash o...
# 217007  <datasketch.weighted_minhash.WeightedMinHash o...
# 217062  <datasketch.weighted_minhash.WeightedMinHash o...
# 217158  <datasketch.weighted_minhash.WeightedMinHash o...
# 217163  <datasketch.weighted_minhash.WeightedMinHash o...
# 217217  <datasketch.weighted_minhash.WeightedMinHash o...
# 217364  <datasketch.weighted_minhash.WeightedMinHash o...
# 217895  <datasketch.weighted_minhash.WeightedMinHash o...
# 218154  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 70 IDs ...
# 100%     34 of     34 study items found in association
#  49%     34 of     70 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       58 GO terms are associated with     34 of     70 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.15=alpha) ( 35 enriched +   0 purified): statsmodels fdr_bh
#       29 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      35 GOEA results for    29 study items. WROTE: STE7__reprocluster_enrich.txt
# 35
# ['' 'PEA2']
# {'HOG:0217913'}
# ['217913']
#                                                   hashsig name
# 217236  <datasketch.weighted_minhash.WeightedMinHash o...
# 217660  <datasketch.weighted_minhash.WeightedMinHash o...
# 218005  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 16 IDs ...
# 100%     13 of     13 study items found in association
#  81%     13 of     16 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       24 GO terms are associated with     13 of     16 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.15=alpha) ( 15 enriched +   0 purified): statsmodels fdr_bh
#       13 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      14 GOEA results for    13 study items. WROTE: PEA2__reprocluster_enrich.txt
# 14
# ['' 'MPC54']
# {'HOG:0218194'}
# ['218194']
#                                                   hashsig name
# 216164  <datasketch.weighted_minhash.WeightedMinHash o...
# 216592  <datasketch.weighted_minhash.WeightedMinHash o...
# 216643  <datasketch.weighted_minhash.WeightedMinHash o...
# 216787  <datasketch.weighted_minhash.WeightedMinHash o...
# 217204  <datasketch.weighted_minhash.WeightedMinHash o...
# 217235  <datasketch.weighted_minhash.WeightedMinHash o...
# 217339  <datasketch.weighted_minhash.WeightedMinHash o...
# 217475  <datasketch.weighted_minhash.WeightedMinHash o...
# 217522  <datasketch.weighted_minhash.WeightedMinHash o...
# 217591  <datasketch.weighted_minhash.WeightedMinHash o...
# 218079  <datasketch.weighted_minhash.WeightedMinHash o...
# 218124  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 63 IDs ...
# 100%     33 of     33 study items found in association
#  52%     33 of     63 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       44 GO terms are associated with     33 of     63 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.15=alpha) ( 21 enriched +   0 purified): statsmodels fdr_bh
#       29 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      21 GOEA results for    29 study items. WROTE: MPC54__reprocluster_enrich.txt
# 21
# ['' 'PRM3']
# {'HOG:0217526'}
# ['217526']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING PRM3__reprocluster_enrich.txt
# 0
# ['' 'SPO13']
# {'HOG:0217386'}
# ['217386']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO13__reprocluster_enrich.txt
# 0
# ['' 'HOP1']
# {'HOG:0218221'}
# ['218221']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING HOP1__reprocluster_enrich.txt
# 0
# ['' 'NUD1']
# {'HOG:0218021'}
# ['218021']
#                                                   hashsig name
# 218128  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 6 IDs ...
# 100%      2 of      2 study items found in association
#  33%      2 of      6 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        6 GO terms are associated with      2 of      6 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 GOEA results. NOT WRITING NUD1__reprocluster_enrich.txt
# 0
# ['' 'SPS1']
# {'HOG:0217915'}
# ['217915']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPS1__reprocluster_enrich.txt
# 0
# ['' 'SPO77']
# {'HOG:0217505'}
# ['217505']
#                                                   hashsig name
# 216114  <datasketch.weighted_minhash.WeightedMinHash o...
# 216132  <datasketch.weighted_minhash.WeightedMinHash o...
# 216135  <datasketch.weighted_minhash.WeightedMinHash o...
# 216191  <datasketch.weighted_minhash.WeightedMinHash o...
# 216309  <datasketch.weighted_minhash.WeightedMinHash o...
# 216349  <datasketch.weighted_minhash.WeightedMinHash o...
# 216475  <datasketch.weighted_minhash.WeightedMinHash o...
# 216745  <datasketch.weighted_minhash.WeightedMinHash o...
# 216746  <datasketch.weighted_minhash.WeightedMinHash o...
# 217201  <datasketch.weighted_minhash.WeightedMinHash o...
# 217311  <datasketch.weighted_minhash.WeightedMinHash o...
# 217419  <datasketch.weighted_minhash.WeightedMinHash o...
# 217482  <datasketch.weighted_minhash.WeightedMinHash o...
# 217516  <datasketch.weighted_minhash.WeightedMinHash o...
# 217575  <datasketch.weighted_minhash.WeightedMinHash o...
# 217788  <datasketch.weighted_minhash.WeightedMinHash o...
# 217905  <datasketch.weighted_minhash.WeightedMinHash o...
# 217922  <datasketch.weighted_minhash.WeightedMinHash o...
# 217952  <datasketch.weighted_minhash.WeightedMinHash o...
# 217994  <datasketch.weighted_minhash.WeightedMinHash o...
# 218102  <datasketch.weighted_minhash.WeightedMinHash o...
# 218247  <datasketch.weighted_minhash.WeightedMinHash o...
# 218250  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# 20
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 152 IDs ...
# 100%    111 of    111 study items found in association
#  73%    111 of    152 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      108 GO terms are associated with    111 of    152 study items
#   METHOD fdr_bh:
#       54 GO terms found significant (< 0.15=alpha) ( 50 enriched +   4 purified): statsmodels fdr_bh
#       86 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      52 GOEA results for    86 study items. WROTE: SPO77__reprocluster_enrich.txt
# 52
# ['' 'SPO19']
# {'HOG:0217403'}
# ['217403']
#                                                   hashsig name
# 216611  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2 IDs ...
#   0%      0 of      0 study items found in association
#   0%      0 of      2 study items found in population(8270255)
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO19__reprocluster_enrich.txt
# 0
# ['' 'AMA1']
# {'HOG:0219014'}
# ['219014']
#                                                   hashsig name
# 218291  <datasketch.weighted_minhash.WeightedMinHash o...
# 218389  <datasketch.weighted_minhash.WeightedMinHash o...
# 218442  <datasketch.weighted_minhash.WeightedMinHash o...
# 218574  <datasketch.weighted_minhash.WeightedMinHash o...
# 218585  <datasketch.weighted_minhash.WeightedMinHash o...
# 218690  <datasketch.weighted_minhash.WeightedMinHash o...
# 218728  <datasketch.weighted_minhash.WeightedMinHash o...
# 219197  <datasketch.weighted_minhash.WeightedMinHash o...
# 219394  <datasketch.weighted_minhash.WeightedMinHash o...
# 219905  <datasketch.weighted_minhash.WeightedMinHash o...
# 220051  <datasketch.weighted_minhash.WeightedMinHash o...
# 220077  <datasketch.weighted_minhash.WeightedMinHash o...
# 220086  <datasketch.weighted_minhash.WeightedMinHash o...
# 220223  <datasketch.weighted_minhash.WeightedMinHash o...
# 221041  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 136 IDs ...
# 100%     75 of     75 study items found in association
#  55%     75 of    136 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       73 GO terms are associated with     75 of    136 study items
#   METHOD fdr_bh:
#       51 GO terms found significant (< 0.15=alpha) ( 50 enriched +   1 purified): statsmodels fdr_bh
#       73 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      51 GOEA results for    73 study items. WROTE: AMA1__reprocluster_enrich.txt
# 51
# ['' 'SPO1']
# {'HOG:0218375'}
# ['218375']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING SPO1__reprocluster_enrich.txt
# 0
# ['' 'KAR5']
# {'HOG:0219280'}
# ['219280']
#                                                   hashsig name
# 218355  <datasketch.weighted_minhash.WeightedMinHash o...
# 218967  <datasketch.weighted_minhash.WeightedMinHash o...
# 219016  <datasketch.weighted_minhash.WeightedMinHash o...
# 219274  <datasketch.weighted_minhash.WeightedMinHash o...
# 219626  <datasketch.weighted_minhash.WeightedMinHash o...
# 219824  <datasketch.weighted_minhash.WeightedMinHash o...
# 220119  <datasketch.weighted_minhash.WeightedMinHash o...
# 220840  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 91 IDs ...
# 100%     59 of     59 study items found in association
#  65%     59 of     91 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       48 GO terms are associated with     59 of     91 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#       57 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      28 GOEA results for    57 study items. WROTE: KAR5__reprocluster_enrich.txt
# 28
# ['' 'SPS4']
# {'HOG:0219017'}
# ['219017']
#                                                   hashsig name
# 218646  <datasketch.weighted_minhash.WeightedMinHash o...
# 218647  <datasketch.weighted_minhash.WeightedMinHash o...
# 218712  <datasketch.weighted_minhash.WeightedMinHash o...
# 218758  <datasketch.weighted_minhash.WeightedMinHash o...
# 219241  <datasketch.weighted_minhash.WeightedMinHash o...
# 219294  <datasketch.weighted_minhash.WeightedMinHash o...
# 219377  <datasketch.weighted_minhash.WeightedMinHash o...
# 219464  <datasketch.weighted_minhash.WeightedMinHash o...
# 219527  <datasketch.weighted_minhash.WeightedMinHash o...
# 219669  <datasketch.weighted_minhash.WeightedMinHash o...
# 219851  <datasketch.weighted_minhash.WeightedMinHash o...
# 219946  <datasketch.weighted_minhash.WeightedMinHash o...
# 220323  <datasketch.weighted_minhash.WeightedMinHash o...
# 220808  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 97 IDs ...
# 100%     67 of     67 study items found in association
#  69%     67 of     97 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       85 GO terms are associated with     67 of     97 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#       50 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      27 GOEA results for    50 study items. WROTE: SPS4__reprocluster_enrich.txt
# 27
# ['' 'BIK1']
# {'HOG:0219830'}
# ['219830']
#                                                   hashsig name
# 218336  <datasketch.weighted_minhash.WeightedMinHash o...
# 218570  <datasketch.weighted_minhash.WeightedMinHash o...
# 219027  <datasketch.weighted_minhash.WeightedMinHash o...
# 219219  <datasketch.weighted_minhash.WeightedMinHash o...
# 219347  <datasketch.weighted_minhash.WeightedMinHash o...
# 219438  <datasketch.weighted_minhash.WeightedMinHash o...
# 219458  <datasketch.weighted_minhash.WeightedMinHash o...
# 219869  <datasketch.weighted_minhash.WeightedMinHash o...
# 220057  <datasketch.weighted_minhash.WeightedMinHash o...
# 220097  <datasketch.weighted_minhash.WeightedMinHash o...
# 220436  <datasketch.weighted_minhash.WeightedMinHash o...
# 220462  <datasketch.weighted_minhash.WeightedMinHash o...
# 220581  <datasketch.weighted_minhash.WeightedMinHash o...
# 220789  <datasketch.weighted_minhash.WeightedMinHash o...
# 220807  <datasketch.weighted_minhash.WeightedMinHash o...
# 220895  <datasketch.weighted_minhash.WeightedMinHash o...
# 220899  <datasketch.weighted_minhash.WeightedMinHash o...
# 221095  <datasketch.weighted_minhash.WeightedMinHash o...
# 221341  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 114 IDs ...
# 100%     77 of     77 study items found in association
#  68%     77 of    114 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       80 GO terms are associated with     77 of    114 study items
#   METHOD fdr_bh:
#       44 GO terms found significant (< 0.15=alpha) ( 43 enriched +   1 purified): statsmodels fdr_bh
#       70 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      40 GOEA results for    70 study items. WROTE: BIK1__reprocluster_enrich.txt
# 40
# ['' 'PRM2']
# {'HOG:0218591'}
# ['218591']
#                                                   hashsig name
# 220046  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 20 IDs ...
# 100%      7 of      7 study items found in association
#  35%      7 of     20 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        7 GO terms are associated with      7 of     20 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.15=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 GOEA results for     6 study items. WROTE: PRM2__reprocluster_enrich.txt
# 4
# ['' 'PMD1']
# {'HOG:0219467.1b'}
# ['219467']
#                                                   hashsig name
# 218714  <datasketch.weighted_minhash.WeightedMinHash o...
# 218766  <datasketch.weighted_minhash.WeightedMinHash o...
# 218932  <datasketch.weighted_minhash.WeightedMinHash o...
# 219155  <datasketch.weighted_minhash.WeightedMinHash o...
# 219270  <datasketch.weighted_minhash.WeightedMinHash o...
# 220255  <datasketch.weighted_minhash.WeightedMinHash o...
# 220484  <datasketch.weighted_minhash.WeightedMinHash o...
# 220545  <datasketch.weighted_minhash.WeightedMinHash o...
# 220616  <datasketch.weighted_minhash.WeightedMinHash o...
# 220747  <datasketch.weighted_minhash.WeightedMinHash o...
# 220847  <datasketch.weighted_minhash.WeightedMinHash o...
# 220853  <datasketch.weighted_minhash.WeightedMinHash o...
# 220963  <datasketch.weighted_minhash.WeightedMinHash o...
# 220983  <datasketch.weighted_minhash.WeightedMinHash o...
# 221261  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 82 IDs ...
# 100%     51 of     51 study items found in association
#  62%     51 of     82 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       35 GO terms are associated with     51 of     82 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#       47 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      27 GOEA results for    47 study items. WROTE: PMD1__reprocluster_enrich.txt
# 27
# ['' 'STE5']
# {'HOG:0218765'}
# ['218765']
#                                                   hashsig name
# 218736  <datasketch.weighted_minhash.WeightedMinHash o...
# 219228  <datasketch.weighted_minhash.WeightedMinHash o...
# 219322  <datasketch.weighted_minhash.WeightedMinHash o...
# 219366  <datasketch.weighted_minhash.WeightedMinHash o...
# 219528  <datasketch.weighted_minhash.WeightedMinHash o...
# 219637  <datasketch.weighted_minhash.WeightedMinHash o...
# 219672  <datasketch.weighted_minhash.WeightedMinHash o...
# 219784  <datasketch.weighted_minhash.WeightedMinHash o...
# 219791  <datasketch.weighted_minhash.WeightedMinHash o...
# 219806  <datasketch.weighted_minhash.WeightedMinHash o...
# 219829  <datasketch.weighted_minhash.WeightedMinHash o...
# 220033  <datasketch.weighted_minhash.WeightedMinHash o...
# 220100  <datasketch.weighted_minhash.WeightedMinHash o...
# 220185  <datasketch.weighted_minhash.WeightedMinHash o...
# 220198  <datasketch.weighted_minhash.WeightedMinHash o...
# 220263  <datasketch.weighted_minhash.WeightedMinHash o...
# 220315  <datasketch.weighted_minhash.WeightedMinHash o...
# 220786  <datasketch.weighted_minhash.WeightedMinHash o...
# 221217  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 175 IDs ...
# 100%    118 of    118 study items found in association
#  67%    118 of    175 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       75 GO terms are associated with    118 of    175 study items
#   METHOD fdr_bh:
#       50 GO terms found significant (< 0.15=alpha) ( 45 enriched +   5 purified): statsmodels fdr_bh
#      101 study items associated with significant GO IDs (enriched)
#       23 study items associated with significant GO IDs (purified)
# done
# DONE!
#      46 GOEA results for   117 study items. WROTE: STE5__reprocluster_enrich.txt
# 46
# ['' 'KAR1']
# {'HOG:0218691'}
# ['218691']
#                                                   hashsig name
# 218284  <datasketch.weighted_minhash.WeightedMinHash o...
# 218370  <datasketch.weighted_minhash.WeightedMinHash o...
# 218478  <datasketch.weighted_minhash.WeightedMinHash o...
# 218555  <datasketch.weighted_minhash.WeightedMinHash o...
# 218688  <datasketch.weighted_minhash.WeightedMinHash o...
# 218989  <datasketch.weighted_minhash.WeightedMinHash o...
# ...
#       84 study items associated with significant GO IDs (purified)
# done
# DONE!
#      47 GOEA results for   387 study items. WROTE: CDC10_SPR28__reprocluster_enrich.txt
# 47
# ['' 'RAD52']
# {'HOG:0402872'}
# ['402872']
#                                                   hashsig name
# 388564  <datasketch.weighted_minhash.WeightedMinHash o...
# 389546  <datasketch.weighted_minhash.WeightedMinHash o...
# 390243  <datasketch.weighted_minhash.WeightedMinHash o...
# 390774  <datasketch.weighted_minhash.WeightedMinHash o...
# 390783  <datasketch.weighted_minhash.WeightedMinHash o...
# 391379  <datasketch.weighted_minhash.WeightedMinHash o...
# 392544  <datasketch.weighted_minhash.WeightedMinHash o...
# 395091  <datasketch.weighted_minhash.WeightedMinHash o...
# 396104  <datasketch.weighted_minhash.WeightedMinHash o...
# 396404  <datasketch.weighted_minhash.WeightedMinHash o...
# 399178  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 154 IDs ...
# 100%    130 of    130 study items found in association
#  84%    130 of    154 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       44 GO terms are associated with    130 of    154 study items
#   METHOD fdr_bh:
#       41 GO terms found significant (< 0.15=alpha) ( 31 enriched +  10 purified): statsmodels fdr_bh
#      125 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
# done
# DONE!
#      39 GOEA results for   126 study items. WROTE: RAD52__reprocluster_enrich.txt
# 39
# ['' 'BIM1']
# {'HOG:0408681.3d'}
# ['408681']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING BIM1__reprocluster_enrich.txt
# 0
# ['' 'MSH6' 'MSH5' 'MSH2']
# {'HOG:0405252.10e', 'HOG:0405252.10i', 'HOG:0405252.10l'}
# ['405252', '405252', '405252']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING MSH6_MSH5_MSH2__reprocluster_enrich.txt
# 0
# ['' 'MSH4']
# {'HOG:0401907.3b.7a'}
# ['401907']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING MSH4__reprocluster_enrich.txt
# 0
# ['' 'MYO2']
# {'HOG:0401396.1a'}
# ['401396']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING MYO2__reprocluster_enrich.txt
# 0
# ['' 'ERG6']
# {'HOG:0419362.4a.12a.14b'}
# ['419362']
# Empty DataFrame
# Columns: [hashsig, name]
# Index: []
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 GOEA results. NOT WRITING ERG6__reprocluster_enrich.txt
# 0
# ['' 'FUS3']
# {'HOG:0401069.3r.26a'}
# ['401069']
#                                                   hashsig name
# 399519  <datasketch.weighted_minhash.WeightedMinHash o...
# 399898  <datasketch.weighted_minhash.WeightedMinHash o...
# 400309  <datasketch.weighted_minhash.WeightedMinHash o...
# 400501  <datasketch.weighted_minhash.WeightedMinHash o...
# 401361  <datasketch.weighted_minhash.WeightedMinHash o...
# 402107  <datasketch.weighted_minhash.WeightedMinHash o...
# 402405  <datasketch.weighted_minhash.WeightedMinHash o...
# 402500  <datasketch.weighted_minhash.WeightedMinHash o...
# 402815  <datasketch.weighted_minhash.WeightedMinHash o...
# 402842  <datasketch.weighted_minhash.WeightedMinHash o...
# 402897  <datasketch.weighted_minhash.WeightedMinHash o...
# 403065  <datasketch.weighted_minhash.WeightedMinHash o...
# 403161  <datasketch.weighted_minhash.WeightedMinHash o...
# 403711  <datasketch.weighted_minhash.WeightedMinHash o...
# 404048  <datasketch.weighted_minhash.WeightedMinHash o...
# 405077  <datasketch.weighted_minhash.WeightedMinHash o...
# 405506  <datasketch.weighted_minhash.WeightedMinHash o...
# 405584  <datasketch.weighted_minhash.WeightedMinHash o...
# 405836  <datasketch.weighted_minhash.WeightedMinHash o...
# 405881  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 830 IDs ...
# 100%    666 of    666 study items found in association
#  80%    666 of    830 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      112 GO terms are associated with    666 of    830 study items
#   METHOD fdr_bh:
#       99 GO terms found significant (< 0.15=alpha) ( 56 enriched +  43 purified): statsmodels fdr_bh
#      615 study items associated with significant GO IDs (enriched)
#       71 study items associated with significant GO IDs (purified)
# done
# DONE!
#      95 GOEA results for   648 study items. WROTE: FUS3__reprocluster_enrich.txt
# 95
# ['' 'KAR2']
# {'HOG:0404837.10ab.59d'}
# ['404837']
#                                                   hashsig name
# 399400  <datasketch.weighted_minhash.WeightedMinHash o...
# 399459  <datasketch.weighted_minhash.WeightedMinHash o...
# 399564  <datasketch.weighted_minhash.WeightedMinHash o...
# 399652  <datasketch.weighted_minhash.WeightedMinHash o...
# 399856  <datasketch.weighted_minhash.WeightedMinHash o...
# 400117  <datasketch.weighted_minhash.WeightedMinHash o...
# 400257  <datasketch.weighted_minhash.WeightedMinHash o...
# 400717  <datasketch.weighted_minhash.WeightedMinHash o...
# 400796  <datasketch.weighted_minhash.WeightedMinHash o...
# 400799  <datasketch.weighted_minhash.WeightedMinHash o...
# 400800  <datasketch.weighted_minhash.WeightedMinHash o...
# 400834  <datasketch.weighted_minhash.WeightedMinHash o...
# 401594  <datasketch.weighted_minhash.WeightedMinHash o...
# 402694  <datasketch.weighted_minhash.WeightedMinHash o...
# 403646  <datasketch.weighted_minhash.WeightedMinHash o...
# 404279  <datasketch.weighted_minhash.WeightedMinHash o...
# 404575  <datasketch.weighted_minhash.WeightedMinHash o...
# 404861  <datasketch.weighted_minhash.WeightedMinHash o...
# 405377  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 475 IDs ...
# 100%    330 of    330 study items found in association
#  69%    330 of    475 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       53 GO terms are associated with    330 of    475 study items
#   METHOD fdr_bh:
#       30 GO terms found significant (< 0.15=alpha) ( 10 enriched +  20 purified): statsmodels fdr_bh
#      228 study items associated with significant GO IDs (enriched)
#       75 study items associated with significant GO IDs (purified)
# done
# DONE!
#      26 GOEA results for   254 study items. WROTE: KAR2__reprocluster_enrich.txt
# 26
# ['' 'SHP1']
# {'HOG:0408836.3a'}
# ['408836']
#                                                   hashsig name
# 406181  <datasketch.weighted_minhash.WeightedMinHash o...
# 406294  <datasketch.weighted_minhash.WeightedMinHash o...
# 406665  <datasketch.weighted_minhash.WeightedMinHash o...
# 406743  <datasketch.weighted_minhash.WeightedMinHash o...
# 407050  <datasketch.weighted_minhash.WeightedMinHash o...
# 407353  <datasketch.weighted_minhash.WeightedMinHash o...
# 407529  <datasketch.weighted_minhash.WeightedMinHash o...
# 408366  <datasketch.weighted_minhash.WeightedMinHash o...
# 408504  <datasketch.weighted_minhash.WeightedMinHash o...
# 408562  <datasketch.weighted_minhash.WeightedMinHash o...
# 408791  <datasketch.weighted_minhash.WeightedMinHash o...
# 408987  <datasketch.weighted_minhash.WeightedMinHash o...
# 409304  <datasketch.weighted_minhash.WeightedMinHash o...
# 409467  <datasketch.weighted_minhash.WeightedMinHash o...
# 409476  <datasketch.weighted_minhash.WeightedMinHash o...
# 410084  <datasketch.weighted_minhash.WeightedMinHash o...
# 410201  <datasketch.weighted_minhash.WeightedMinHash o...
# 410515  <datasketch.weighted_minhash.WeightedMinHash o...
# 410707  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 191 IDs ...
# 100%     71 of     71 study items found in association
#  37%     71 of    191 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       51 GO terms are associated with     71 of    191 study items
#   METHOD fdr_bh:
#       13 GO terms found significant (< 0.15=alpha) ( 11 enriched +   2 purified): statsmodels fdr_bh
#       54 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#      13 GOEA results for    57 study items. WROTE: SHP1__reprocluster_enrich.txt
# 13
# ['' 'RAD18']
# {'HOG:0408660.4c.3d'}
# ['408660']
#                                                   hashsig name
# 406029  <datasketch.weighted_minhash.WeightedMinHash o...
# 406706  <datasketch.weighted_minhash.WeightedMinHash o...
# 407075  <datasketch.weighted_minhash.WeightedMinHash o...
# 407449  <datasketch.weighted_minhash.WeightedMinHash o...
# 407865  <datasketch.weighted_minhash.WeightedMinHash o...
# 407904  <datasketch.weighted_minhash.WeightedMinHash o...
# 408264  <datasketch.weighted_minhash.WeightedMinHash o...
# 408365  <datasketch.weighted_minhash.WeightedMinHash o...
# 408462  <datasketch.weighted_minhash.WeightedMinHash o...
# 408808  <datasketch.weighted_minhash.WeightedMinHash o...
# 408857  <datasketch.weighted_minhash.WeightedMinHash o...
# 409054  <datasketch.weighted_minhash.WeightedMinHash o...
# 409298  <datasketch.weighted_minhash.WeightedMinHash o...
# 409523  <datasketch.weighted_minhash.WeightedMinHash o...
# 409592  <datasketch.weighted_minhash.WeightedMinHash o...
# 410290  <datasketch.weighted_minhash.WeightedMinHash o...
# 410451  <datasketch.weighted_minhash.WeightedMinHash o...
# 410484  <datasketch.weighted_minhash.WeightedMinHash o...
# 410793  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1207 IDs ...
# 100%    854 of    854 study items found in association
#  71%    854 of  1,207 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      128 GO terms are associated with    854 of  1,207 study items
#   METHOD fdr_bh:
#      105 GO terms found significant (< 0.15=alpha) ( 54 enriched +  51 purified): statsmodels fdr_bh
#      834 study items associated with significant GO IDs (enriched)
#      133 study items associated with significant GO IDs (purified)
# done
# DONE!
#     100 GOEA results for   848 study items. WROTE: RAD18__reprocluster_enrich.txt
# 100
# ['' 'MRE11']
# {'HOG:0408036.5a'}
# ['408036']
#                                                   hashsig name
# 407973  <datasketch.weighted_minhash.WeightedMinHash o...
# 408323  <datasketch.weighted_minhash.WeightedMinHash o...
# 408484  <datasketch.weighted_minhash.WeightedMinHash o...
# 408534  <datasketch.weighted_minhash.WeightedMinHash o...
# 408726  <datasketch.weighted_minhash.WeightedMinHash o...
# 409400  <datasketch.weighted_minhash.WeightedMinHash o...
# 409433  <datasketch.weighted_minhash.WeightedMinHash o...
# 409534  <datasketch.weighted_minhash.WeightedMinHash o...
# 409570  <datasketch.weighted_minhash.WeightedMinHash o...
# 409640  <datasketch.weighted_minhash.WeightedMinHash o...
# 409714  <datasketch.weighted_minhash.WeightedMinHash o...
# 410128  <datasketch.weighted_minhash.WeightedMinHash o...
# 410156  <datasketch.weighted_minhash.WeightedMinHash o...
# 410498  <datasketch.weighted_minhash.WeightedMinHash o...
# 410635  <datasketch.weighted_minhash.WeightedMinHash o...
# 410666  <datasketch.weighted_minhash.WeightedMinHash o...
# 410706  <datasketch.weighted_minhash.WeightedMinHash o...
# 410751  <datasketch.weighted_minhash.WeightedMinHash o...
# 410808  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 487 IDs ...
# 100%    389 of    389 study items found in association
#  80%    389 of    487 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      114 GO terms are associated with    389 of    487 study items
#   METHOD fdr_bh:
#       65 GO terms found significant (< 0.15=alpha) ( 43 enriched +  22 purified): statsmodels fdr_bh
#      355 study items associated with significant GO IDs (enriched)
#       12 study items associated with significant GO IDs (purified)
# done
# DONE!
#      64 GOEA results for   358 study items. WROTE: MRE11__reprocluster_enrich.txt
# 64
# ['' 'GPA1']
# {'HOG:0409582.6u.29h'}
# ['409582']
#                                                   hashsig name
# 406502  <datasketch.weighted_minhash.WeightedMinHash o...
# 406546  <datasketch.weighted_minhash.WeightedMinHash o...
# 407001  <datasketch.weighted_minhash.WeightedMinHash o...
# 407158  <datasketch.weighted_minhash.WeightedMinHash o...
# 407406  <datasketch.weighted_minhash.WeightedMinHash o...
# 407583  <datasketch.weighted_minhash.WeightedMinHash o...
# 407590  <datasketch.weighted_minhash.WeightedMinHash o...
# 407591  <datasketch.weighted_minhash.WeightedMinHash o...
# 407723  <datasketch.weighted_minhash.WeightedMinHash o...
# 407863  <datasketch.weighted_minhash.WeightedMinHash o...
# 408058  <datasketch.weighted_minhash.WeightedMinHash o...
# 408387  <datasketch.weighted_minhash.WeightedMinHash o...
# 408420  <datasketch.weighted_minhash.WeightedMinHash o...
# 408645  <datasketch.weighted_minhash.WeightedMinHash o...
# 408871  <datasketch.weighted_minhash.WeightedMinHash o...
# 409707  <datasketch.weighted_minhash.WeightedMinHash o...
# 409861  <datasketch.weighted_minhash.WeightedMinHash o...
# 410034  <datasketch.weighted_minhash.WeightedMinHash o...
# 410713  <datasketch.weighted_minhash.WeightedMinHash o...
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1365 IDs ...
# 100%  1,081 of  1,081 study items found in association
#  79%  1,081 of  1,365 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      134 GO terms are associated with  1,081 of  1,365 study items
#   METHOD fdr_bh:
#      162 GO terms found significant (< 0.15=alpha) ( 73 enriched +  89 purified): statsmodels fdr_bh
#    1,065 study items associated with significant GO IDs (enriched)
#       96 study items associated with significant GO IDs (purified)
# done
# DONE!
#     158 GOEA results for  1078 study items. WROTE: GPA1__reprocluster_enrich.txt
# 158
