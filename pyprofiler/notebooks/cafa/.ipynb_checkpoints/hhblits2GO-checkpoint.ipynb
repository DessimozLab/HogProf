# %%
import subprocess
import shlex

# %%
pip install csb
# Out:
# Requirement already satisfied: csb in /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csb

# %%
def runHHblits( aln , name, path , outdir, db , iterations , ncores , runName , SS  , oa3m , verbose = False):
    if verbose == True:
        print( [aln , name, path , outdir, db , iterations , ncores , runName] )
    outhhr= outdir+name+runName+".hhr"
    args = path + ' -cpu '+ str(ncores) +' -d ' + db + ' -i ' + aln  +' -o '+ outhhr + ' -n ' + str(iterations) + ' -norealign -add_cons -M 50'
    if SS == True:
         args += ' -ssm 2 -ssw .5 '
    
    if oa3m == True:
        outa3m = outdir+name+runName+'.a3m'
        args += ' -oa3m ' + outa3m
    else: 
        outa3m = None
    if verbose == True:
        print(args)
    
    args = shlex.split(args)
    p = subprocess.Popen(args )
    return p , [outhhr,outa3m]


def runHHmake( aln , name, path = 'hhmake' , outdir='./', verbose = False, SS = False):
    if verbose == True:
        print( [aln , name, path , outdir] )
    outhhm= outdir+name+".hhm"
    args = path + ' -i '+  aln  +' -o '+ outhhm + ' -M 50'
    if SS == True:
        #todo : make ss prediction here
        pass
    args = shlex.split(args)
    p = subprocess.Popen(args )
    return p , [outhhm]


def hhrparse(hhr , coverage , proba ):
    profile = HHOutputParser(alignments=False).parse_file(hhr)
    qname = profile.query_name
    for hit in profile:
        proba = hit.probability
        i = hit.id

def query2PFAM_PDB(qaln, name , outdir= './' , path = 'hhblits' , verbose = False):
    uniclust = '/home/cactuskid13/mntpt/HHBLITsdb/uniclust30_2018_08/uniclust30_2018_08'
    pdb70 = '/home/cactuskid13/mntpt/HHBLITsdb/pdb70/pdb70'
    pfam = '/home/cactuskid13/mntpt/HHBLITsdb/pfam'

    p,ret = runHHmake(qaln, name)
    qaln = ret[0]
    
    db = uniclust
    iterations = 2
    ncores = 4
    
    runName = 'UNI'
    SS  = False
    oa3m = True
    
    p, ret = runHHblits( qaln ,name, path , outdir, db , iterations , ncores , runName , SS  , oa3m , verbose)
    p.wait()
    UNI_HHR = ret[0]
    '''
    #todo_add SS to model here
    
    db = pfam
    iterations = 1
    ncores = 1
    runName = 'PFAM'
    SS  = False
    oa3m = False
    qaln = ret[1]
    
    p, ret = runHHblits( qaln , name,  path , outdir, db , iterations , ncores , runName , SS  , oa3m , verbose)
    p.wait()
    PFAM_HHR = ret[1]
    
    
    db = pdb70
    iterations = 1
    ncores = 1
    runName = 'PDB'
    SS  = False
    oa3m = False
    
    p, ret = runHHblits( qaln ,name , path , outdir, db , iterations , ncores , runName , SS  , oa3m , verbose  )
    p.wait()
    PDB_HHR = ret[1]
    '''
    return UNI_HHR #, PDB_HHR , PFAM_HHR

def PFAM_HHR2GO(hhr):
    #map thru interpro
    
    pass

def PDB_HHR2GO(hhr):
    #map from pdb
    
    pass

def UNI_HHR2GO(hhr):
    #map from uniprot gaf
    
    #map to uniclust cluster rep and grab all identifiers
    
    #check if there are any annotations in cluster
    
    
    
    
    
    pass

# %%
#make pandas df of cath dom chains
import glob 
import pandas as pd

df = pd.read_csv('./pdb_chain_go.csv' , comment = '#' , error_bad_lines = False ,  warn_bad_lines = False )
print(df)
# Out:
#            PDB CHAIN SP_PRIMARY                WITH_STRING EVIDENCE  \
# 0         101m     A       IPRO         InterPro:IPR000971      IEA
# 1         101m     A       IPRO         InterPro:IPR002335      IEA
# 2         101m     A       IPRO         InterPro:IPR002335      IEA
# 3         101m     A       IPRO         InterPro:IPR002335      IEA
# 4         101m     A       IPRO         InterPro:IPR012292      IEA
# 5         101m     A       IPRO         InterPro:IPR012292      IEA
# 6         101m     A     P02185       UniProtKB-KW:KW-0479      IEA
# 7         101m     A     P02185       UniProtKB-KW:KW-0561      IEA
# 8         101m     A     P02185       UniProtKB-KW:KW-0561      IEA
# 9         102l     A       IPRO         InterPro:IPR001165      IEA
# 10        102l     A       IPRO         InterPro:IPR001165      IEA
# 11        102l     A       IPRO         InterPro:IPR002196      IEA
# 12        102l     A       IPRO         InterPro:IPR002196      IEA
# 13        102l     A       IPRO         InterPro:IPR002196      IEA
# 14        102l     A       IPRO         InterPro:IPR034690      IEA
# 15        102l     A       IPRO         InterPro:IPR034690      IEA
# 16        102l     A       IPRO         InterPro:IPR034690      IEA
# 17        102l     A       IPRO         InterPro:IPR034690      IEA
# 18        102m     A       IPRO         InterPro:IPR000971      IEA
# 19        102m     A       IPRO         InterPro:IPR002335      IEA
# 20        102m     A       IPRO         InterPro:IPR002335      IEA
# 21        102m     A       IPRO         InterPro:IPR002335      IEA
# 22        102m     A       IPRO         InterPro:IPR012292      IEA
# 23        102m     A       IPRO         InterPro:IPR012292      IEA
# 24        102m     A     P02185       UniProtKB-KW:KW-0479      IEA
# 25        102m     A     P02185       UniProtKB-KW:KW-0561      IEA
# 26        102m     A     P02185       UniProtKB-KW:KW-0561      IEA
# 27        103l     A       IPRO         InterPro:IPR001165      IEA
# 28        103l     A       IPRO         InterPro:IPR001165      IEA
# 29        103l     A       IPRO         InterPro:IPR002196      IEA
# ...        ...   ...        ...                        ...      ...
# 28809296  9xim     C       IPRO         InterPro:IPR001998      IEA
# 28809297  9xim     C       IPRO         InterPro:IPR001998      IEA
# 28809298  9xim     C       IPRO         InterPro:IPR013453      IEA
# 28809299  9xim     C       IPRO         InterPro:IPR013453      IEA
# 28809300  9xim     C     P12851                 EC:5.3.1.5      IEA
# 28809301  9xim     C     P12851       UniProtKB-KW:KW-0119      IEA
# 28809302  9xim     C     P12851       UniProtKB-KW:KW-0413      IEA
# 28809303  9xim     C     P12851       UniProtKB-KW:KW-0479      IEA
# 28809304  9xim     C     P12851       UniProtKB-KW:KW-0859      IEA
# 28809305  9xim     C     P12851       UniProtKB-KW:KW-0963      IEA
# 28809306  9xim     C     P12851  UniProtKB-SubCell:SL-0086      IEA
# 28809307  9xim     C     P12851        UniRule:UR000089075      IEA
# 28809308  9xim     C     P12851        UniRule:UR000089075      IEA
# 28809309  9xim     C     P12851        UniRule:UR000089075      IEA
# 28809310  9xim     C     P12851        UniRule:UR000089075      IEA
# 28809311  9xim     D       IPRO         InterPro:IPR001998      IEA
# 28809312  9xim     D       IPRO         InterPro:IPR001998      IEA
# 28809313  9xim     D       IPRO         InterPro:IPR013453      IEA
# 28809314  9xim     D       IPRO         InterPro:IPR013453      IEA
# 28809315  9xim     D     P12851                 EC:5.3.1.5      IEA
# 28809316  9xim     D     P12851       UniProtKB-KW:KW-0119      IEA
# 28809317  9xim     D     P12851       UniProtKB-KW:KW-0413      IEA
# 28809318  9xim     D     P12851       UniProtKB-KW:KW-0479      IEA
# 28809319  9xim     D     P12851       UniProtKB-KW:KW-0859      IEA
# 28809320  9xim     D     P12851       UniProtKB-KW:KW-0963      IEA
# 28809321  9xim     D     P12851  UniProtKB-SubCell:SL-0086      IEA
# 28809322  9xim     D     P12851        UniRule:UR000089075      IEA
# 28809323  9xim     D     P12851        UniRule:UR000089075      IEA
# 28809324  9xim     D     P12851        UniRule:UR000089075      IEA
# 28809325  9xim     D     P12851        UniRule:UR000089075      IEA
#
#                GO_ID
# 0         GO:0020037
# 1         GO:0015671
# 2         GO:0019825
# 3         GO:0020037
# 4         GO:0019825
# 5         GO:0020037
# 6         GO:0046872
# 7         GO:0005344
# 8         GO:0015671
# 9         GO:0003796
# 10        GO:0016998
# 11        GO:0003796
# 12        GO:0009253
# 13        GO:0016998
# 14        GO:0003796
# 15        GO:0009253
# 16        GO:0019076
# 17        GO:0019835
# 18        GO:0020037
# 19        GO:0015671
# 20        GO:0019825
# 21        GO:0020037
# 22        GO:0019825
# 23        GO:0020037
# 24        GO:0046872
# 25        GO:0005344
# 26        GO:0015671
# 27        GO:0003796
# 28        GO:0016998
# 29        GO:0003796
# ...              ...
# 28809296  GO:0005975
# 28809297  GO:0009045
# 28809298  GO:0009045
# 28809299  GO:0042732
# 28809300  GO:0009045
# 28809301  GO:0005975
# 28809302  GO:0016853
# 28809303  GO:0046872
# 28809304  GO:0042732
# 28809305  GO:0005737
# 28809306  GO:0005737
# 28809307  GO:0000287
# 28809308  GO:0005737
# 28809309  GO:0009045
# 28809310  GO:0042732
# 28809311  GO:0005975
# 28809312  GO:0009045
# 28809313  GO:0009045
# 28809314  GO:0042732
# 28809315  GO:0009045
# 28809316  GO:0005975
# 28809317  GO:0016853
# 28809318  GO:0046872
# 28809319  GO:0042732
# 28809320  GO:0005737
# 28809321  GO:0005737
# 28809322  GO:0000287
# 28809323  GO:0005737
# 28809324  GO:0009045
# 28809325  GO:0042732
#
# [28809326 rows x 6 columns]

# %%
#make a dataframe of uniprot noniea annotations
import pandas as pd
gaf = './goa_noiea.gaf'
unigaf = pd.read_csv( gaf , comment = '!' , sep = '\t'  , header = None)
print(unigaf.head())

uniclust = '/home/cactuskid13/mntpt/HHBLITsdb/uniclust30_2018_08/uniclust30_2018_08.tsv'
dfclust = pd.read_csv( uniclust , comment = '!' , sep = '\t' , header = None )

print(dfclust.head())
# Out:
#    UniProtKB  A0A021WW32  vtd Unnamed: 3  GO:0000278   PMID:12573216  IMP  \
# 0  UniProtKB  A0A021WW32  vtd        NaN  GO:0000278   PMID:25101996  IMP
# 1  UniProtKB  A0A021WW32  vtd        NaN  GO:0000775   PMID:11258476  NAS
# 2  UniProtKB  A0A021WW32  vtd        NaN  GO:0000795   PMID:25101996  IDA
# 3  UniProtKB  A0A021WW32  vtd        NaN  GO:0000798   PMID:21873635  IBA
# 4  UniProtKB  A0A021WW32  vtd        NaN  GO:0003682  GO_REF:0000024  ISS
#
#                                           Unnamed: 7  P  \
# 0                                                NaN  P
# 1                                                NaN  C
# 2                                                NaN  C
# 3  MGI:MGI:1929645|MGI:MGI:3652039|PANTHER:PTN000...  C
# 4                                     SGD:S000002161  F
#
#    Rad21_Rec8_N domain-containing protein  \
# 0  Rad21_Rec8_N domain-containing protein
# 1  Rad21_Rec8_N domain-containing protein
# 2  Rad21_Rec8_N domain-containing protein
# 3  Rad21_Rec8_N domain-containing protein
# 4  Rad21_Rec8_N domain-containing protein
#
#   vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG17436|Drad21|RAD21|Rad21|Scc1|VTD|Vtd|dRad21|drad21|l(3)80Fh|l(3)Lh3|l3|lethal 3  \
# 0  vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG...
# 1  vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG...
# 2  vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG...
# 3  vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG...
# 4  vtd|80Fh|CG40222|DRAD21|DRad21|DmRAD21|Dmel\CG...
#
#    protein  taxon:7227  20060803     FlyBase Unnamed: 15 Unnamed: 16
# 0  protein  taxon:7227  20141120     FlyBase         NaN         NaN
# 1  protein  taxon:7227  20060803     FlyBase         NaN         NaN
# 2  protein  taxon:7227  20141120     FlyBase         NaN         NaN
# 3  protein  taxon:7227  20170228  GO_Central         NaN         NaN
# 4  protein  taxon:7227  20140515     FlyBase         NaN         NaN
#             0           1
# 0  A0A1Q6BRU5  A0A1Q6BRU5
# 1  A0A0A9U2E6  A0A0A9U2E6
# 2  A0A1Y6B8R2  A0A1Y6B8R2
# 3  A0A1Y6B8R2  A0A2E8I3A4
# 4  A0A094PJX3  A0A094PJX3
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# <ipython-input-4-7899761400f8> in <module>
#       9 print(dfclust.head())
#      10
# ---> 11 unigaf = unigaf.merge( dfclust , how   = 'left' , left_on = 1 , right_on =  1  )
#
# ~/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6866                      right_on=right_on, left_index=left_index,
#    6867                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6868                      copy=copy, indicator=indicator, validate=validate)
#    6869
#    6870     def round(self, decimals=0, *args, **kwargs):
#
# ~/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# ~/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# ~/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     844                         right_keys.append(rk)
#     845                     if lk is not None:
# --> 846                         left_keys.append(left._get_label_or_level_values(lk))
#     847                         join_names.append(lk)
#     848                     else:
#
# ~/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 1

# %%
unigaf = unigaf.merge( dfclust , how   = 'left' , left_on = 1 , right_on =  1  )
print(unigaf)

# %%
#make a branching tree of uniclust mapping
def lookup_clust(btree, ref):
    c = iter(ref)
    level = btree[next(c)]
    while len(level)>1:
        level = level[c]
    return level[c]

btree = {}

for l in uniclustin:
    clusterhead = l
    prots = []    
    for i,c in enumerate(clusterhead[0:-1]):
        if i == 0:
            if c not in btree:
                btree[c] = {}
            level = btree [c]
        else:
            if c not in level:
                level[c] = {}
            level[c] = {}
    else:
        #store refs in cluster head
        level[ clusterhead[0:-1]] = prots

# %%
#make a dataframe of interpro domains mapped to GO terms
interpro_df = pd.read_csv('./interpro2go.txt' ,  sep = ';' , header = None, comment = '!' )
interpro_df['IPID'] = interpro_df[0].map( lambda x : x.split()[0].split(':')[1] )
pf_df = pd.read_csv('./ip2pfam.tsv' ,  sep = '\t' ,comment = '!' )
interpro_df = interpro_df.merge( pf_df , how='right' , right_on ='Accession' , left_on='IPID' )
interpro_df = interpro_df[ interpro_df[1].notnull() ]
#and map back to pfam

# %%
testaln = './Hap2HOG.aln.fasta'
import time
t0 = time.time()
query2PFAM_PDB(testaln, name='hap2' ,  outdir= '/home/cactuskid13/pyprofiler/pyprofiler/notebooks/cafa/' , path = 'hhblits' , verbose = True)
print( time.time() - t0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-2760a0b740d2> in <module>
#       2 import time
#       3 t0 = time.time()
# ----> 4 query2PFAM_PDB(testaln, name='hap2' ,  outdir= '/home/cactuskid13/pyprofiler/pyprofiler/notebooks/cafa/' , path = 'hhblits' , verbose = True)
#       5 print( time.time() - t0)
#       6
#
# <ipython-input-6-1fbe6806ee74> in query2PFAM_PDB(qaln, name, outdir, path, verbose)
#      45     pfam = '/home/cactuskid13/mntpt/HHBLITsdb/pfam'
#      46
# ---> 47     p,ret = runHHmake(qaln, name)
#      48     qaln = ret[0]
#      49
#
# <ipython-input-6-1fbe6806ee74> in runHHmake(aln, name, path, outdir, verbose, SS)
#      29         pass
#      30     args = shlex.split(args)
# ---> 31     p = subprocess.Popen(args )
#      32     return p , [outhhm]
#      33
#
# ~/miniconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     773                                 c2pread, c2pwrite,
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#     777             # Cleanup if the child failed starting.
#
# ~/miniconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1520                         if errno_num == errno.ENOENT:
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#    1524
#
# FileNotFoundError: [Errno 2] No such file or directory: 'hhmake': 'hhmake'

# %%
#parse hhr files for each query and filter for nice hits


#map go from pdb chains and pfam domains


#output final pred
