# %%
# %load_ext autoreload
# %autoreload 2
import sys
from matplotlib.backends.backend_pdf import PdfPages
sys.path.append('../..')
sys.path.append( '/home/cactuskid13/miniconda3/pkgs/')
print(sys.path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ['/home/cactuskid13/pyprofiler/pyprofiler/notebooks', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python37.zip', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/lib-dynload', '', '/home/cactuskid13/.local/lib/python3.7/site-packages', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages', '/home/cactuskid13/pyham', '/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/IPython/extensions', '/home/cactuskid13/.ipython', '../..', '/home/cactuskid13/miniconda3/pkgs/', '../..', '/home/cactuskid13/miniconda3/pkgs/', '../..', '/home/cactuskid13/miniconda3/pkgs/']

# %%
#using the profiler. It's easy!
#lets import the profiler, configuration file and some tools for GO analysis to look at our returned results
from pyprofiler.utils import config_utils
import pyprofiler.utils.goatools_utils as goa
import pyprofiler.profiler as profiler
# Out:
# {'dir': {'datadir': '/home/cactuskid13/pyprofiler/pyprofiler/all/all512/', 'omadir': '/home/cactuskid13/mntpt/OMA/jun/'}, 'orthoxmltar': '', 'email': 'dmoi@unil.ch'}

# %%
#lets also create a go annotation enrichment study object to describe functional enrichment in our profiling results
gaf = goa.buildGAF( '/home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/oma-go.txt' )
study = goa.return_enrichment_study_obj( gaf , obo = '/home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/go.obo')
# Out:
# /home/cactuskid13/mntpt/unil_backup/profilingbackup/gaf/go.obo: fmt(1.2) rel(2019-07-01) 47,413 GO Terms
#
# Load GOEA Gene Ontology Analysis ...
# fisher module not installed.  Falling back on scipy.stats.fisher_exact
# 100% 8,270,255 of 8,270,255 population items found in association

# %%
#lets load a compiled db containing the OMA root HOGs into a profiler oject 
p = profiler.Profiler(lshforestpath = config_utils.datadir+ 'newlshforest.pkl' , hashes_h5=config_utils.datadir  +'hashes.h5' , mat_path= None, oma = True, tar= None , nsamples = 512)
# Out:
# loading lsh
# indexing lsh
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/Protein/_i_Entries/OmaHOG/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# 3146
# DONE

# %%
import pandas as pd
import numpy as np

def grabHog(ID):
    try:
        return p.db_obj.entry_by_entry_nr(p.db_obj.id_resolver.resolve(ID))[4].decode()
    except:
        return np.nan
    

#map to OMA HOGs

# %%
#load the kinetochore data and map it to OMA HOGs
#these are blast results against oma since they had their own adhoc IDs

kinetodf = pd.DataFrame.from_csv('kineto_mapping.csv', header = None)
#filter by evalue
kinetodf= kinetodf[kinetodf[10]< .000001]
kinetodf['name'] = kinetodf.index.map( lambda x : x.split('_')[-1] )

kinetodf['HOG'] = kinetodf[1].map(grabHog)
print(kinetodf.head())
kinetodf.to_csv('kineto_mapping.csv')
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   after removing the cwd from sys.path.
#                                               1        2     3   4  5  6  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  HUMAN17502  100.000  1944   0  0  1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28459   99.743  1944   5  0  1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  CHLSB04039   99.383  1944  12  0  1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  PAPAN05104   99.331  1944  13  0  1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28460   99.126  1945  14  2  1
#
#                                         7  8     9   10      11    12  13  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  1944  1  1944  0.0  4029.0  Apc1 NaN
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  1944  1  1944  0.0  4017.0  Apc1 NaN
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  1944  1  1944  0.0  4007.0  Apc1 NaN
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  1944  1  1944  0.0  4007.0  Apc1 NaN
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  1944  1  1943  0.0  3982.0  Apc1 NaN
#
#                                        14              15  name  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  Apc1  HOG:0397431.2a  Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  Apc1             NaN  Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  Apc1  HOG:0397431.2a  Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  Apc1  HOG:0397431.2a  Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  Apc1  HOG:0397431.2a  Apc1
#
#                                                 HOG
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1  HOG:0397431.2a

# %%
kinetodf = pd.DataFrame.from_csv('kineto_mapping.csv')

kinetodf = kinetodf.dropna(subset=['HOG'] , axis=0)
print(kinetodf)
# Out:
#                                                 1        2     3    4   5  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    HUMAN17502  100.000  1944    0   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    CHLSB04039   99.383  1944   12   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PAPAN05104   99.331  1944   13   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PANTR28460   99.126  1945   14   2
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    CALJA06361   98.405  1944   30   1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    FELCA03737   97.274  1944   53   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    HORSE05873   97.171  1944   55   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    MUSPF05472   97.274  1944   53   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    RABIT08361   96.914  1944   60   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PIGXX21392   96.862  1944   61   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    CANLF05104   96.109  1953   66   4
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    AILME07555   96.006  1953   64   5
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PIGXX21394   95.576  1944   61   1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    CHILA17152   96.397  1943   70   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    FUKDA12987   96.348  1944   71   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    TURTR11097   94.907  1944   61   3
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    MYOLU12992   95.786  1946   79   2
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    LOXAF07011   95.730  1944   83   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    OTOGA03978   95.216  1944   93   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    CAVPO04440   95.280  1949   84   5
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    RATNO13640   92.953  1944  137   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    MOUSE27805   92.387  1944  148   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    BOVIN01722   95.084  1953   86   4
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    SHEEP14121   95.319  1944   90   1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    MACMU06518   93.830  1945  112   6
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    VICPA06518   90.844  1944   62   3
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PIGXX21396   96.917  1784   55   0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    ICTTR11360   93.297  1820  121   1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    SARHA11943   86.872  1950  249   4
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    PIGXX21397   95.101  1735   49   1
# ...                                           ...      ...   ...  ...  ..
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  POEFO08541   43.688   602  311  13
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  XIPMA09280   45.167   569  285  12
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  GADMO16666   42.906   585  293  11
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ORYLA14890   44.425   565  295   9
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ECHTE14492   64.723   343   48   5
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ECHTE14492   51.982   227   62   3
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MACEU01438   60.279   287  106   3
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MACEU01438   56.863   153   64   2
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  TETNG03932   31.728   602  281  17
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  LINUN08582   28.938   546  330  14
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  LOTGI20654   28.298   470  307  11
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  LINUN32836   29.446   523  309  16
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  CRAGI10711   26.778   478  295  15
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  OCTBM14125   26.316   380  252   8
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  CAPTE27259   24.086   465  286  12
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  CAPI103667   24.086   465  286  12
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  NEMVE25457   24.172   513  340  15
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  SPIPN02036   23.418   474  307  16
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  AMPQE22704   26.733   303  181   9
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  DAPPU24447   22.166   397  284  10
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  HYDVU11200   23.925   372  235  14
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  BRUMA12883   22.198   464  302  18
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ONCVO12014   23.011   465  298  17
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  BATDJ03857   29.694   229  138   8
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  BATDE03857   29.694   229  138   8
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  LOALO09915   22.042   431  282  16
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ZOONE12356   23.774   265  187   5
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  PRIPA01848   23.136   389  233  17
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MELHA08950   22.156   334  215   9
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  SOLIN05576   23.188   414  266  17
#
#                                          6     7    8     9             10  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1943   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1943   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1952   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1948   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1919   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1943    1  1943   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1906   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1945   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1946   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1944   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1952   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1943   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1938   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1828   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    161  1944    1  1784   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    126  1944    1  1820   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      1  1944    1  1949   0.000000e+00
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    210  1944    1  1699   0.000000e+00
# ...                                    ...   ...  ...   ...            ...
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    1   586    1   590  1.050000e-155
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   34   586   30   587  1.720000e-154
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   18   590   11   566  1.660000e-153
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   30   588   27   578  4.990000e-149
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  250   591  136   406  4.510000e-127
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    2   226    2   183   6.720000e-61
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   36   318    1   283  3.630000e-107
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  438   590  276   426   2.790000e-50
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    9   590   10   501   9.220000e-81
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   21   526   28   555   5.990000e-59
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   98   557  173   622   5.780000e-52
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   21   501   28   532   6.560000e-51
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   99   559   46   485   1.750000e-43
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  183   557  222   578   6.870000e-38
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  100   558  112   515   9.120000e-34
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  100   558  112   515   9.120000e-34
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   59   545  115   604   4.210000e-26
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   68   499  101   560   3.250000e-20
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  225   504  277   561   6.450000e-20
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  135   527  136   511   1.860000e-17
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  203   540  265   622   2.200000e-14
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  100   535  132   564   1.890000e-13
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  100   535  636  1069   8.020000e-13
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  298   508  306   529   3.160000e-12
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  298   508  306   529   3.160000e-12
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  134   535  118   523   1.980000e-11
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  241   494  238   498   3.050000e-11
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   94   463  115   456   5.190000e-10
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  170   487  188   492   3.200000e-09
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  100   486   70   458   5.850000e-08
#
#                                            11      12  13      14  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    4029.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    4007.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    4007.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3982.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3969.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3923.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3922.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3922.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3922.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3912.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3868.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3861.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3848.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3807.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3807.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3803.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3793.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3787.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3751.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3748.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3739.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3713.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3697.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3678.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3640.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3616.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3590.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3428.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3424.0    Apc1 NaN    Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    3408.0    Apc1 NaN    Apc1
# ...                                       ...     ...  ..     ...
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   466.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   462.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   459.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   448.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   385.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   214.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   335.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   186.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   269.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   213.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   196.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   191.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   169.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   155.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   142.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   142.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   120.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   102.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch   101.0  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    93.6  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    84.3  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    81.6  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    80.1  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    77.4  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    77.4  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    75.1  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    74.3  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    70.9  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    67.8  Zwilch NaN  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch    63.9  Zwilch NaN  Zwilch
#
#                                                                      15  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    HOG:0409203.1b.1b.1b.1b.1a.1d.1a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0390733.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                         HOG:0397431
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                HOG:0372138.1b.6b.1a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                         HOG:0397431
# Homo_sapiens_HSAP017770_ANAPC1_Apc1         HOG:0421837.3d.2a.4b.6d.25c
# ...                                                                 ...
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.2b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.2b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                 HOG:0380531.2b.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                 HOG:0380531.2b.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.1b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0261237
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0402152
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0402152
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0294611
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0261237
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0281218
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0180540
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0180540
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0325882
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0325882.1b
#
#                                          name  \
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# Homo_sapiens_HSAP017770_ANAPC1_Apc1      Apc1
# ...                                       ...
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch  Zwilch
#
#                                                                     HOG
# 0
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1    HOG:0409203.1b.1b.1b.1b.1a.1d.1a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0390733.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                         HOG:0397431
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                HOG:0372138.1b.6b.1a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                      HOG:0397431.2a
# Homo_sapiens_HSAP017770_ANAPC1_Apc1                         HOG:0397431
# Homo_sapiens_HSAP017770_ANAPC1_Apc1         HOG:0421837.3d.2a.4b.6d.25c
# ...                                                                 ...
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.2b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.2b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                 HOG:0380531.2b.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                 HOG:0380531.2b.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.1b
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0380531.1a
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0380531
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0261237
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0402152
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0402152
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0294611
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0261237
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0281218
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0180540
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0180540
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0325882
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                       HOG:0291935
# Homo_sapiens_HSAP008261_ZWILCH_Zwilch                    HOG:0325882.1b
#
# [17966 rows x 17 columns]
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
#lets search for interactors of each HOG in our dataset and map them back to the dataframe
from pyprofiler.utils.hashutils import hogid2fam
#print(kinetodf)
print(len(kinetodf.HOG.unique()))
print(len(kinetodf.name.unique()))
kinetodf['topHOG'] = kinetodf.HOG.map(lambda x : str(x).split('.')[0])
Hogs = []

#lets just grab the top one closest to the human sequence with a HOG ID
for n in kinetodf.name.unique():
    sub = kinetodf[kinetodf.name == n ]
    for Hog in list(sub.topHOG.unique())[0:3]:
        if len(Hog)>0:
            Hogs.append(Hog)
print(Hogs)
print(len(set(Hogs)))
# Out:
# 4200
# 89
# ['HOG:0397431', 'HOG:0409203', 'HOG:0390733', 'HOG:0217889', 'HOG:0373006', 'HOG:0354438', 'HOG:0394532', 'HOG:0371013', 'HOG:0605249', 'HOG:0420946', 'HOG:0420607', 'HOG:0172386', 'HOG:0366264', 'HOG:0603663', 'HOG:0352864', 'HOG:0354613', 'HOG:0383489', 'HOG:0357260', 'HOG:0363570', 'HOG:0379370', 'HOG:0366226', 'HOG:0218415', 'HOG:0252529', 'HOG:0255123', 'HOG:0372963', 'HOG:0365955', 'HOG:0393988', 'HOG:0260009', 'HOG:0214005', 'HOG:0375966', 'HOG:0327049', 'HOG:0334576', 'HOG:0390011', 'HOG:0340198', 'HOG:0420308', 'HOG:0365745', 'HOG:0362181', 'HOG:0368754', 'HOG:0392167', 'HOG:0389803', 'HOG:0403265', 'HOG:0358495', 'HOG:0353946', 'HOG:0381237', 'HOG:0413144', 'HOG:0364121', 'HOG:0367903', 'HOG:0366348', 'HOG:0359514', 'HOG:0343396', 'HOG:0217941', 'HOG:0406831', 'HOG:0347716', 'HOG:0381148', 'HOG:0362214', 'HOG:0357309', 'HOG:0359359', 'HOG:0403075', 'HOG:0612245', 'HOG:0408684', 'HOG:0408225', 'HOG:0355083', 'HOG:0114188', 'HOG:0218352', 'HOG:0369639', 'HOG:0395896', 'HOG:0422600', 'HOG:0398721', 'HOG:0407058', 'HOG:0353180', 'HOG:0422600', 'HOG:0366005', 'HOG:0409968', 'HOG:0363823', 'HOG:0344375', 'HOG:0410523', 'HOG:0408899', 'HOG:0335704', 'HOG:0175698', 'HOG:0368108', 'HOG:0609097', 'HOG:0360754', 'HOG:0400677', 'HOG:0358847', 'HOG:0227532', 'HOG:0218447', 'HOG:0219166', 'HOG:0255707', 'HOG:0218368', 'HOG:0257629', 'HOG:0216232', 'HOG:0217853', 'HOG:0256810', 'HOG:0217836', 'HOG:0408318', 'HOG:0605197', 'HOG:0605381', 'HOG:0395611', 'HOG:0385906', 'HOG:0402399', 'HOG:0417896', 'HOG:0614377', 'HOG:0218715', 'HOG:0362871', 'HOG:0346130', 'HOG:0345876', 'HOG:0415419', 'HOG:0379303', 'HOG:0319806', 'HOG:0387962', 'HOG:0365756', 'HOG:0342222', 'HOG:0422600', 'HOG:0400134', 'HOG:0361906', 'HOG:0422600', 'HOG:0395615', 'HOG:0406594', 'HOG:0358434', 'HOG:0403018', 'HOG:0354723', 'HOG:0393580', 'HOG:0392137', 'HOG:0348348', 'HOG:0355268', 'HOG:0379981', 'HOG:0369426', 'HOG:0361458', 'HOG:0409804', 'HOG:0369160', 'HOG:0218104', 'HOG:0256730', 'HOG:0369290', 'HOG:0349347', 'HOG:0341404', 'HOG:0381706', 'HOG:0357207', 'HOG:0328102', 'HOG:0370884', 'HOG:0362633', 'HOG:0604038', 'HOG:0422600', 'HOG:0388379', 'HOG:0377525', 'HOG:0422600', 'HOG:0375716', 'HOG:0394176', 'HOG:0385214', 'HOG:0418884', 'HOG:0422600', 'HOG:0360822', 'HOG:0423327', 'HOG:0347684', 'HOG:0362095', 'HOG:0344339', 'HOG:0363345', 'HOG:0350786', 'HOG:0383343', 'HOG:0397485', 'HOG:0364188', 'HOG:0411916', 'HOG:0415589', 'HOG:0374964', 'HOG:0406052', 'HOG:0419974', 'HOG:0366836', 'HOG:0398880', 'HOG:0402126', 'HOG:0401889', 'HOG:0278114', 'HOG:0369370', 'HOG:0363331', 'HOG:0421378', 'HOG:0368270', 'HOG:0382814', 'HOG:0422600', 'HOG:0369113', 'HOG:0377931', 'HOG:0401887', 'HOG:0396793', 'HOG:0370349', 'HOG:0353058', 'HOG:0365997', 'HOG:0408807', 'HOG:0417115', 'HOG:0346735', 'HOG:0355577', 'HOG:0422600', 'HOG:0298633', 'HOG:0372806', 'HOG:0408599', 'HOG:0412698', 'HOG:0416845', 'HOG:0369088', 'HOG:0375485', 'HOG:0371538', 'HOG:0399542', 'HOG:0371876', 'HOG:0348980', 'HOG:0422600', 'HOG:0401620', 'HOG:0395089', 'HOG:0405091', 'HOG:0326796', 'HOG:0118793', 'HOG:0421960', 'HOG:0371699', 'HOG:0335696', 'HOG:0218162', 'HOG:0422600', 'HOG:0332138', 'HOG:0420485', 'HOG:0396904', 'HOG:0360940', 'HOG:0294262', 'HOG:0386959', 'HOG:0391276', 'HOG:0350967', 'HOG:0370002', 'HOG:0390562', 'HOG:0380289', 'HOG:0400250', 'HOG:0366830', 'HOG:0423325', 'HOG:0395134', 'HOG:0402027', 'HOG:0367012', 'HOG:0363255', 'HOG:0362641', 'HOG:0612606', 'HOG:0356554', 'HOG:0408220', 'HOG:0369198', 'HOG:0401872', 'HOG:0372616', 'HOG:0372799', 'HOG:0380531', 'HOG:0381594', 'HOG:0261237']
# 229

# %%
#now we can make a second dataframe with the hash signatures of each of our queries
#reading the hdf5 and grabbing all the hash signatures may take a moment
profiles = p.pull_hashes( set(Hogs) )
names = dict( zip( kinetodf.HOG , kinetodf.name) )
profiles = { h: {'hashsig': profiles[h] , 'name': names[h]  }  for h in profiles if h in names}
profiles = pd.DataFrame.from_dict( profiles , orient='index' )
print(profiles.head())
print(len(profiles))
print(len(profiles.name.unique()))
profiles = profiles.drop_duplicates( subset = 'name', keep = 'last')
print(len(profiles))
print(profiles)
# Out:
#                                                        hashsig    name
# HOG:0175698  <datasketch.weighted_minhash.WeightedMinHash o...  Nup107
# HOG:0214005  <datasketch.weighted_minhash.WeightedMinHash o...    Dad4
# HOG:0216232  <datasketch.weighted_minhash.WeightedMinHash o...    Dad3
# HOG:0217836  <datasketch.weighted_minhash.WeightedMinHash o...    Hsk3
# HOG:0217853  <datasketch.weighted_minhash.WeightedMinHash o...   Spc19
# 166
# 84
# 84
#                                                        hashsig      name
# HOG:0217836  <datasketch.weighted_minhash.WeightedMinHash o...      Hsk3
# HOG:0217853  <datasketch.weighted_minhash.WeightedMinHash o...     Spc19
# HOG:0217889  <datasketch.weighted_minhash.WeightedMinHash o...      Duo1
# HOG:0217941  <datasketch.weighted_minhash.WeightedMinHash o...     Ndc10
# HOG:0218162  <datasketch.weighted_minhash.WeightedMinHash o...     Ctf13
# HOG:0218352  <datasketch.weighted_minhash.WeightedMinHash o...      Apc9
# HOG:0218715  <datasketch.weighted_minhash.WeightedMinHash o...     Spc34
# HOG:0255123  <datasketch.weighted_minhash.WeightedMinHash o...      Dam1
# HOG:0255707  <datasketch.weighted_minhash.WeightedMinHash o...      Dad2
# HOG:0256730  <datasketch.weighted_minhash.WeightedMinHash o...      Cep3
# HOG:0257629  <datasketch.weighted_minhash.WeightedMinHash o...      Dad3
# HOG:0260009  <datasketch.weighted_minhash.WeightedMinHash o...      Dad4
# HOG:0348348  <datasketch.weighted_minhash.WeightedMinHash o...  Borealin
# HOG:0353180  <datasketch.weighted_minhash.WeightedMinHash o...     CenpU
# HOG:0360822  <datasketch.weighted_minhash.WeightedMinHash o...     CenpA
# HOG:0361458  <datasketch.weighted_minhash.WeightedMinHash o...   Zwint-1
# HOG:0361906  <datasketch.weighted_minhash.WeightedMinHash o...     CenpE
# HOG:0362095  <datasketch.weighted_minhash.WeightedMinHash o...     CenpQ
# HOG:0362214  <datasketch.weighted_minhash.WeightedMinHash o...     CenpW
# HOG:0362871  <datasketch.weighted_minhash.WeightedMinHash o...     CenpT
# HOG:0363255  <datasketch.weighted_minhash.WeightedMinHash o...      Knl1
# HOG:0363345  <datasketch.weighted_minhash.WeightedMinHash o...     CenpR
# HOG:0364121  <datasketch.weighted_minhash.WeightedMinHash o...      Apc3
# HOG:0365997  <datasketch.weighted_minhash.WeightedMinHash o...      Dsn1
# HOG:0366226  <datasketch.weighted_minhash.WeightedMinHash o...      Ska3
# HOG:0366264  <datasketch.weighted_minhash.WeightedMinHash o...       Sgo
# HOG:0366348  <datasketch.weighted_minhash.WeightedMinHash o...    Astrin
# HOG:0368108  <datasketch.weighted_minhash.WeightedMinHash o...    Incenp
# HOG:0368754  <datasketch.weighted_minhash.WeightedMinHash o...     CenpH
# HOG:0369198  <datasketch.weighted_minhash.WeightedMinHash o...      SKAP
# ...                                                        ...       ...
# HOG:0396793  <datasketch.weighted_minhash.WeightedMinHash o...     Apc13
# HOG:0396904  <datasketch.weighted_minhash.WeightedMinHash o...      Apc4
# HOG:0397431  <datasketch.weighted_minhash.WeightedMinHash o...      Apc1
# HOG:0398880  <datasketch.weighted_minhash.WeightedMinHash o...      Bub3
# HOG:0399542  <datasketch.weighted_minhash.WeightedMinHash o...   Spindly
# HOG:0400677  <datasketch.weighted_minhash.WeightedMinHash o...     CenpI
# HOG:0401872  <datasketch.weighted_minhash.WeightedMinHash o...     RINT1
# HOG:0401887  <datasketch.weighted_minhash.WeightedMinHash o...     CenpM
# HOG:0402126  <datasketch.weighted_minhash.WeightedMinHash o...    Nup160
# HOG:0402399  <datasketch.weighted_minhash.WeightedMinHash o...      Ska1
# HOG:0403018  <datasketch.weighted_minhash.WeightedMinHash o...     CenpS
# HOG:0403075  <datasketch.weighted_minhash.WeightedMinHash o...       Rod
# HOG:0403265  <datasketch.weighted_minhash.WeightedMinHash o...     CenpO
# HOG:0405091  <datasketch.weighted_minhash.WeightedMinHash o...     Apc10
# HOG:0406831  <datasketch.weighted_minhash.WeightedMinHash o...      Apc5
# HOG:0408225  <datasketch.weighted_minhash.WeightedMinHash o...      Mad2
# HOG:0408318  <datasketch.weighted_minhash.WeightedMinHash o...      Apc2
# HOG:0408599  <datasketch.weighted_minhash.WeightedMinHash o...     Spc25
# HOG:0408899  <datasketch.weighted_minhash.WeightedMinHash o...    Nup107
# HOG:0410523  <datasketch.weighted_minhash.WeightedMinHash o...    HORMAD
# HOG:0411916  <datasketch.weighted_minhash.WeightedMinHash o...       NAG
# HOG:0413144  <datasketch.weighted_minhash.WeightedMinHash o...      Apc8
# HOG:0415419  <datasketch.weighted_minhash.WeightedMinHash o...      Skp1
# HOG:0415589  <datasketch.weighted_minhash.WeightedMinHash o...      Apc7
# HOG:0417115  <datasketch.weighted_minhash.WeightedMinHash o...      Nuf2
# HOG:0420308  <datasketch.weighted_minhash.WeightedMinHash o...  p31comet
# HOG:0420946  <datasketch.weighted_minhash.WeightedMinHash o...    TRIP13
# HOG:0421960  <datasketch.weighted_minhash.WeightedMinHash o...     Ndc80
# HOG:0423325  <datasketch.weighted_minhash.WeightedMinHash o...      ZW10
# HOG:0604038  <datasketch.weighted_minhash.WeightedMinHash o...    MadBub
#
# [84 rows x 2 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import colour
#we can perform an all vs all comparison to replicate the results in va hoof et al
import time 



with PdfPages('kineto_hash.pdf') as pdf:
    print(len(list(profiles.hashsig)) )
    start = time.time()
    print( list( profiles.hashsig )[0].jaccard(list(profiles.hashsig)[1]) )       
    print(time.time()-start)

    jkern = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(list(profiles.hashsig)) ] for i,h1 in enumerate(list(profiles.hashsig))]


    jkern = np.asarray(jkern)
    jkern+=jkern.T
    np.fill_diagonal( jkern , 1 )
    print(jkern)
    g = sns.clustermap( jkern , xticklabels= profiles.name , yticklabels= profiles.name , figsize = (20,20) )


    colorcode = pd.DataFrame.from_csv('./colorcode_kineto.csv')
    red = colour.Color('red')
    blue = colour.Color('blue')
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode.index) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')

    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)
    pdf.savefig()


    plt.show()
# Out:
# 84
# 0.19921875
# 0.0026862621307373047
# [[1.         0.19921875 0.85742188 ... 0.         0.         0.        ]
#  [0.19921875 1.         0.20117188 ... 0.         0.         0.        ]
#  [0.85742188 0.20117188 1.         ... 0.         0.         0.        ]
#  ...
#  [0.         0.         0.         ... 1.         0.18945312 0.        ]
#  [0.         0.         0.         ... 0.18945312 1.         0.        ]
#  [0.         0.         0.         ... 0.         0.         1.        ]]
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:25: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
#lets load the original pearson correlation data and compare to our jaccard similarity metric
pearsondf = pd.DataFrame.from_csv('./kinetocore_pearson.csv')

with PdfPages('kineto_pearson.pdf') as pdf:

    g = sns.clustermap( pearsondf , xticklabels= pearsondf.index , yticklabels= pearsondf.index , figsize = (20,20) )

    colorcode = pd.DataFrame.from_csv('./colorcode_kineto.csv')
    red = colour.Color('red')
    blue = colour.Color('blue')
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode.index) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')

    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)


    pdf.savefig()

    plt.show()
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
#lets compare the organisation of the complex in both as graph structures
import networkx as nx
pG = nx.from_numpy_matrix( pearsondf.to_numpy() )
jG = nx.from_numpy_matrix( jkern )
pG = nx.relabel_nodes( pG , { i:p for i,p in enumerate(pearsondf.index) })
jG = nx.relabel_nodes( jG , { i:p for i,p in enumerate(profiles.name) })
print(pG)
print(jG)
alledges={}
shared={}
topk = 20

for g in [jG, pG]:
    finalg = nx.Graph()
    for n in g.nodes():
        alledges = [ (n,l) for l in g.neighbors(n) if n != l ]
        weights = [ g[e[0]][e[1]]['weight'] for e in alledges]
        keep = np.flip(np.argsort(weights))[0:topk]
        edges = [ alledges[s] for s in list(keep) ]
        [  finalg.add_edge(e[0],e[1], weight= max(1/(i +1),g[e[0]][e[1]]['weight']) ) if finalg.has_edge(e[0],e[1]) else finalg.add_edge(e[0],e[1], weight= g[e[0]][e[1]]['weight']) for i,e in enumerate(edges)   ]
    pos = nx.spring_layout( finalg , weight='weight')
    weights = np.asarray([e[2]['weight'] for e in g.edges(data = True)])
    plt.figure( figsize = (17,17))
    cvec = [ colordict[n] if n in colordict else 'black' for n in finalg.nodes()]
    nx.draw(finalg, pos=pos, edge_color='grey', width= 5*np.log( weights ), node_size= 700, node_color = cvec ,alpha = .5 ) 
    labels=nx.draw_networkx_labels(finalg , pos = pos , font_size= 25 )
    plt.show()
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in log

# %%
from scipy.stats import pearsonr , spearmanr , brunnermunzel
pearsondf = pearsondf[profiles.name]
pearsondf = pearsondf.loc[profiles.name]
pearsonmat = pearsondf.to_numpy()
print(pearsonmat.shape)

print(jkern.shape)
print('spearman')
print( spearmanr( pearsonmat.ravel(), jkern.ravel() ))
print( 'pearson')
print( pearsonr( pearsonmat.ravel(), jkern.ravel() ))
print('permutation')
print( brunnermunzel( pearsonmat.ravel(), jkern.ravel() ))
# Out:
# (84, 84)
# (84, 84)
# spearman
# SpearmanrResult(correlation=0.15506484906773868, pvalue=3.1874470216737904e-39)
# pearson
# (0.3762119900518547, 4.371853556457976e-236)
# permutation
# BrunnerMunzelResult(statistic=-71.60755971761836, pvalue=0.0)

# %%
#now we can add in the HOGs we found in our search
#the clustering shows a similar structure
print(len(profiles.index))

#lets query the the lsh with each HOG
res = { h: p.hog_query(hog_id= h, k = 10 ) for h in list(profiles.index) }
profiles_full = p.pull_hashes( set(res.keys()).union( set( [ h for results in res.values() for h in results ] ) ) )

names = dict( zip( kinetodf.HOG , kinetodf.name) )

profiles_ = { h: {'hashsig': profiles_full[h] , 'name': names[h]  } if h in names else {'hashsig': profiles_full[h] , 'name': ''  }   for h in profiles_full }

profiles_full = pd.DataFrame.from_dict( profiles_ , orient='index' )

print(profiles_full)
print(len(profiles_full))
# Out:
# 84
#                                                        hashsig      name
# 216118       <datasketch.weighted_minhash.WeightedMinHash o...
# 216200       <datasketch.weighted_minhash.WeightedMinHash o...
# 216237       <datasketch.weighted_minhash.WeightedMinHash o...
# 216259       <datasketch.weighted_minhash.WeightedMinHash o...
# 216267       <datasketch.weighted_minhash.WeightedMinHash o...
# 216277       <datasketch.weighted_minhash.WeightedMinHash o...
# 216278       <datasketch.weighted_minhash.WeightedMinHash o...
# 216392       <datasketch.weighted_minhash.WeightedMinHash o...
# 216412       <datasketch.weighted_minhash.WeightedMinHash o...
# 216457       <datasketch.weighted_minhash.WeightedMinHash o...
# 216638       <datasketch.weighted_minhash.WeightedMinHash o...
# 216663       <datasketch.weighted_minhash.WeightedMinHash o...
# 216713       <datasketch.weighted_minhash.WeightedMinHash o...
# 216729       <datasketch.weighted_minhash.WeightedMinHash o...
# 216767       <datasketch.weighted_minhash.WeightedMinHash o...
# 216825       <datasketch.weighted_minhash.WeightedMinHash o...
# 216912       <datasketch.weighted_minhash.WeightedMinHash o...
# 216926       <datasketch.weighted_minhash.WeightedMinHash o...
# 216936       <datasketch.weighted_minhash.WeightedMinHash o...
# 216939       <datasketch.weighted_minhash.WeightedMinHash o...
# 217082       <datasketch.weighted_minhash.WeightedMinHash o...
# 217107       <datasketch.weighted_minhash.WeightedMinHash o...
# 217110       <datasketch.weighted_minhash.WeightedMinHash o...
# 217230       <datasketch.weighted_minhash.WeightedMinHash o...
# 217288       <datasketch.weighted_minhash.WeightedMinHash o...
# 217330       <datasketch.weighted_minhash.WeightedMinHash o...
# 217353       <datasketch.weighted_minhash.WeightedMinHash o...
# 217429       <datasketch.weighted_minhash.WeightedMinHash o...
# 217437       <datasketch.weighted_minhash.WeightedMinHash o...
# 217462       <datasketch.weighted_minhash.WeightedMinHash o...
# ...                                                        ...       ...
# HOG:0396793  <datasketch.weighted_minhash.WeightedMinHash o...     Apc13
# HOG:0396904  <datasketch.weighted_minhash.WeightedMinHash o...      Apc4
# HOG:0397431  <datasketch.weighted_minhash.WeightedMinHash o...      Apc1
# HOG:0398880  <datasketch.weighted_minhash.WeightedMinHash o...      Bub3
# HOG:0399542  <datasketch.weighted_minhash.WeightedMinHash o...   Spindly
# HOG:0400677  <datasketch.weighted_minhash.WeightedMinHash o...     CenpI
# HOG:0401872  <datasketch.weighted_minhash.WeightedMinHash o...     RINT1
# HOG:0401887  <datasketch.weighted_minhash.WeightedMinHash o...     CenpM
# HOG:0402126  <datasketch.weighted_minhash.WeightedMinHash o...    Nup160
# HOG:0402399  <datasketch.weighted_minhash.WeightedMinHash o...      Ska1
# HOG:0403018  <datasketch.weighted_minhash.WeightedMinHash o...     CenpS
# HOG:0403075  <datasketch.weighted_minhash.WeightedMinHash o...       Rod
# HOG:0403265  <datasketch.weighted_minhash.WeightedMinHash o...     CenpO
# HOG:0405091  <datasketch.weighted_minhash.WeightedMinHash o...     Apc10
# HOG:0406831  <datasketch.weighted_minhash.WeightedMinHash o...      Apc5
# HOG:0408225  <datasketch.weighted_minhash.WeightedMinHash o...      Mad2
# HOG:0408318  <datasketch.weighted_minhash.WeightedMinHash o...      Apc2
# HOG:0408599  <datasketch.weighted_minhash.WeightedMinHash o...     Spc25
# HOG:0408899  <datasketch.weighted_minhash.WeightedMinHash o...    Nup107
# HOG:0410523  <datasketch.weighted_minhash.WeightedMinHash o...    HORMAD
# HOG:0411916  <datasketch.weighted_minhash.WeightedMinHash o...       NAG
# HOG:0413144  <datasketch.weighted_minhash.WeightedMinHash o...      Apc8
# HOG:0415419  <datasketch.weighted_minhash.WeightedMinHash o...      Skp1
# HOG:0415589  <datasketch.weighted_minhash.WeightedMinHash o...      Apc7
# HOG:0417115  <datasketch.weighted_minhash.WeightedMinHash o...      Nuf2
# HOG:0420308  <datasketch.weighted_minhash.WeightedMinHash o...  p31comet
# HOG:0420946  <datasketch.weighted_minhash.WeightedMinHash o...    TRIP13
# HOG:0421960  <datasketch.weighted_minhash.WeightedMinHash o...     Ndc80
# HOG:0423325  <datasketch.weighted_minhash.WeightedMinHash o...      ZW10
# HOG:0604038  <datasketch.weighted_minhash.WeightedMinHash o...    MadBub
#
# [919 rows x 2 columns]
# 919

# %%
#whats inside the matrix

# %%
#lets perform and enrichment on each cluster to see if we were able to pull down some functional modules
#some of these results may be unknown kinetochore proteins under an open world assumption
jkern0 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(list(profiles_full.hashsig) ) ] for i,h1 in enumerate(list( profiles_full.hashsig ) ) ]
jkern0 = np.asarray(jkern0)
jkern0+=jkern0.T
np.fill_diagonal( jkern0 , 1 )

# %%
import scipy
with PdfPages('kineto_augment.pdf') as pdf:

    cutoff = 1.3
    z = scipy.cluster.hierarchy.linkage(jkern0, method='average', metric='euclidean')
    clusters = scipy.cluster.hierarchy.fcluster(z, t=cutoff, criterion='distance')
    colors = [ c.hex_l for c in red.range_to( blue , len(set(clusters)) ) ]
    colordict2 = dict( zip( list(set(clusters)) , list(colors)))
    rowcolors = [ colordict2[c] for c in clusters]

    print(np.unique(clusters).shape )

    g = sns.clustermap( jkern0 , xticklabels= profiles_full.name , yticklabels= profiles_full.name , figsize = (20,20) )
    colorcode = pd.DataFrame.from_csv('./colorcode_kineto.csv')
    red = colour.Color('red')
    blue = colour.Color('blue')
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode.index) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')


    g.ax_row_dendrogram.axvline(cutoff)
    g.ax_col_dendrogram.axhline(cutoff)

    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)   
    
    pdf.savefig()
    plt.show()
# Out:
# (143,)
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
#we can enrich for functionality in each cluster
goares = {}
dfs = []
for c in list(np.unique(clusters)):
    sub = profiles_full.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ][0:5])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        study.wr_tsv(namestr + "_kinetocluster_enrich.tsv", goea_results_sig)
        try:
            res = pd.DataFrame.from_csv(namestr + "_kinetocluster_enrich.tsv" , sep= '\t' , header = None)
            res['queries'] = ''.join( [ n + ' ' for n in sub.name ])
            dfs.append(res)

        except:
            print('no res')
        print(len(goea_results_sig))

finaldf = pd.concat(dfs)
finaldf.to_csv('kineto_augment_goenrich.csv')
print('DONE')
# Out:
# ['' 'Nup133' 'Apc5']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 281 IDs ...
# 100%    226 of    226 study items found in association
#  80%    226 of    281 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       69 GO terms are associated with    226 of    281 study items
#   METHOD fdr_bh:
#       48 GO terms found significant (< 0.15=alpha) ( 30 enriched +  18 purified): statsmodels fdr_bh
#      220 study items associated with significant GO IDs (enriched)
#       23 study items associated with significant GO IDs (purified)
# done
# DONE!
#      46 items WROTE: Nup133_Apc5__kinetocluster_enrich.tsv
# 46
# ['' 'Plk' 'CenpP']
# compiling hogs
# 0
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 484 IDs ...
# 100%    380 of    380 study items found in association
#  79%    380 of    484 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       83 GO terms are associated with    380 of    484 study items
#   METHOD fdr_bh:
#       66 GO terms found significant (< 0.15=alpha) ( 48 enriched +  18 purified): statsmodels fdr_bh
#      345 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#      65 items WROTE: Plk_CenpP__kinetocluster_enrich.tsv
# 65
# ['' 'Apc12']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 92 IDs ...
# 100%     65 of     65 study items found in association
#  71%     65 of     92 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       17 GO terms are associated with     65 of     92 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.15=alpha) (  3 enriched +   2 purified): statsmodels fdr_bh
#       59 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#       5 items WROTE: Apc12__kinetocluster_enrich.tsv
# 5
# ['' 'Spc24']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Spc24__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Incenp']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 528 IDs ...
# 100%    387 of    387 study items found in association
#  73%    387 of    528 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       89 GO terms are associated with    387 of    528 study items
#   METHOD fdr_bh:
#       69 GO terms found significant (< 0.15=alpha) ( 51 enriched +  18 purified): statsmodels fdr_bh
#      381 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      68 items WROTE: Incenp__kinetocluster_enrich.tsv
# 68
# ['' 'Survivin' 'Cdh1']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 420 IDs ...
# 100%    351 of    351 study items found in association
#  84%    351 of    420 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       98 GO terms are associated with    351 of    420 study items
#   METHOD fdr_bh:
#       72 GO terms found significant (< 0.15=alpha) ( 53 enriched +  19 purified): statsmodels fdr_bh
#      339 study items associated with significant GO IDs (enriched)
#       23 study items associated with significant GO IDs (purified)
# done
# DONE!
#      71 items WROTE: Survivin_Cdh1__kinetocluster_enrich.tsv
# 71
# ['' 'CenpQ' 'CenpW']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 315 IDs ...
# 100%    247 of    247 study items found in association
#  78%    247 of    315 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      160 GO terms are associated with    247 of    315 study items
#   METHOD fdr_bh:
#      106 GO terms found significant (< 0.15=alpha) ( 91 enriched +  15 purified): statsmodels fdr_bh
#      227 study items associated with significant GO IDs (enriched)
#       70 study items associated with significant GO IDs (purified)
# done
# DONE!
#     102 items WROTE: CenpQ_CenpW__kinetocluster_enrich.tsv
# 102
# ['' 'CenpS']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 572 IDs ...
# 100%    273 of    273 study items found in association
#  48%    273 of    572 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       61 GO terms are associated with    273 of    572 study items
#   METHOD fdr_bh:
#       50 GO terms found significant (< 0.15=alpha) ( 30 enriched +  20 purified): statsmodels fdr_bh
#      248 study items associated with significant GO IDs (enriched)
#       13 study items associated with significant GO IDs (purified)
# done
# DONE!
#      50 items WROTE: CenpS__kinetocluster_enrich.tsv
# 50
# ['' 'Ska1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 330 IDs ...
# 100%    261 of    261 study items found in association
#  79%    261 of    330 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       24 GO terms are associated with    261 of    330 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.15=alpha) ( 14 enriched +  21 purified): statsmodels fdr_bh
#      256 study items associated with significant GO IDs (enriched)
#       11 study items associated with significant GO IDs (purified)
# done
# DONE!
#      34 items WROTE: Ska1__kinetocluster_enrich.tsv
# 34
# ['' 'CenpO']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 15 IDs ...
# 100%      8 of      8 study items found in association
#  53%      8 of     15 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       22 GO terms are associated with      8 of     15 study items
#   METHOD fdr_bh:
#        2 GO terms found significant (< 0.15=alpha) (  2 enriched +   0 purified): statsmodels fdr_bh
#        5 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       2 items WROTE: CenpO__kinetocluster_enrich.tsv
# 2
# ['' 'Skp1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 596 IDs ...
# 100%    463 of    463 study items found in association
#  78%    463 of    596 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       73 GO terms are associated with    463 of    596 study items
#   METHOD fdr_bh:
#       80 GO terms found significant (< 0.15=alpha) ( 47 enriched +  33 purified): statsmodels fdr_bh
#      462 study items associated with significant GO IDs (enriched)
#       32 study items associated with significant GO IDs (purified)
# done
# DONE!
#      80 items WROTE: Skp1__kinetocluster_enrich.tsv
# 80
# ['' 'NAG']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1336 IDs ...
# 100%  1,109 of  1,109 study items found in association
#  83%  1,109 of  1,336 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      122 GO terms are associated with  1,109 of  1,336 study items
#   METHOD fdr_bh:
#      171 GO terms found significant (< 0.15=alpha) ( 84 enriched +  87 purified): statsmodels fdr_bh
#    1,107 study items associated with significant GO IDs (enriched)
#      156 study items associated with significant GO IDs (purified)
# done
# DONE!
#     167 items WROTE: NAG__kinetocluster_enrich.tsv
# 167
# ['' 'CenpI']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 23 IDs ...
# 100%      3 of      3 study items found in association
#  13%      3 of     23 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        7 GO terms are associated with      3 of     23 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING CenpI__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Spc25']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 365 IDs ...
# 100%    281 of    281 study items found in association
#  77%    281 of    365 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       55 GO terms are associated with    281 of    365 study items
#   METHOD fdr_bh:
#       40 GO terms found significant (< 0.15=alpha) ( 18 enriched +  22 purified): statsmodels fdr_bh
#      270 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
# done
# DONE!
#      39 items WROTE: Spc25__kinetocluster_enrich.tsv
# 39
# ['' 'HORMAD']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 252 IDs ...
# 100%     51 of     51 study items found in association
#  20%     51 of    252 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       21 GO terms are associated with     51 of    252 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.15=alpha) (  5 enriched +   1 purified): statsmodels fdr_bh
#       45 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#       6 items WROTE: HORMAD__kinetocluster_enrich.tsv
# 6
# ['' 'RINT1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 439 IDs ...
# 100%    364 of    364 study items found in association
#  83%    364 of    439 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       39 GO terms are associated with    364 of    439 study items
#   METHOD fdr_bh:
#       25 GO terms found significant (< 0.15=alpha) (  4 enriched +  21 purified): statsmodels fdr_bh
#      355 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
# done
# DONE!
#      23 items WROTE: RINT1__kinetocluster_enrich.tsv
# 23
# ['' 'Nup107']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1043 IDs ...
# 100%    939 of    939 study items found in association
#  90%    939 of  1,043 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      119 GO terms are associated with    939 of  1,043 study items
#   METHOD fdr_bh:
#      127 GO terms found significant (< 0.15=alpha) ( 62 enriched +  65 purified): statsmodels fdr_bh
#      929 study items associated with significant GO IDs (enriched)
#       14 study items associated with significant GO IDs (purified)
# done
# DONE!
#     125 items WROTE: Nup107__kinetocluster_enrich.tsv
# 125
# ['' 'Borealin']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 32 IDs ...
# 100%     13 of     13 study items found in association
#  41%     13 of     32 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       37 GO terms are associated with     13 of     32 study items
#   METHOD fdr_bh:
#       11 GO terms found significant (< 0.15=alpha) ( 11 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      11 items WROTE: Borealin__kinetocluster_enrich.tsv
# 11
# ['' 'Cep57']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 12 IDs ...
#   0%      0 of      0 study items found in association
#   0%      0 of     12 study items found in population(8270255)
# done
# DONE!
#       0 items. NOT WRITING Cep57__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpK']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 111 IDs ...
# 100%     76 of     76 study items found in association
#  68%     76 of    111 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       13 GO terms are associated with     76 of    111 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.15=alpha) (  3 enriched +   1 purified): statsmodels fdr_bh
#       73 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 items WROTE: CenpK__kinetocluster_enrich.tsv
# 4
# ['' 'Nup160']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 185 IDs ...
# 100%    127 of    127 study items found in association
#  69%    127 of    185 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       31 GO terms are associated with    127 of    185 study items
#   METHOD fdr_bh:
#       17 GO terms found significant (< 0.15=alpha) ( 10 enriched +   7 purified): statsmodels fdr_bh
#      120 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 items WROTE: Nup160__kinetocluster_enrich.tsv
# 15
# ['' 'ARHGEF17']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 65 IDs ...
# 100%     41 of     41 study items found in association
#  63%     41 of     65 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       57 GO terms are associated with     41 of     65 study items
#   METHOD fdr_bh:
#       36 GO terms found significant (< 0.15=alpha) ( 34 enriched +   2 purified): statsmodels fdr_bh
#       37 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      35 items WROTE: ARHGEF17__kinetocluster_enrich.tsv
# 35
# ['' 'CenpL']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 321 IDs ...
# 100%    240 of    240 study items found in association
#  75%    240 of    321 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       69 GO terms are associated with    240 of    321 study items
#   METHOD fdr_bh:
#       66 GO terms found significant (< 0.15=alpha) ( 46 enriched +  20 purified): statsmodels fdr_bh
#      233 study items associated with significant GO IDs (enriched)
#        8 study items associated with significant GO IDs (purified)
# done
# DONE!
#      65 items WROTE: CenpL__kinetocluster_enrich.tsv
# 65
# ['' 'CenpN']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 274 IDs ...
# 100%    220 of    220 study items found in association
#  80%    220 of    274 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       30 GO terms are associated with    220 of    274 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 14 enriched +  14 purified): statsmodels fdr_bh
#      217 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      28 items WROTE: CenpN__kinetocluster_enrich.tsv
# 28
# ['' 'Apc13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 525 IDs ...
# 100%    342 of    342 study items found in association
#  65%    342 of    525 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      109 GO terms are associated with    342 of    525 study items
#   METHOD fdr_bh:
#       84 GO terms found significant (< 0.15=alpha) ( 64 enriched +  20 purified): statsmodels fdr_bh
#      324 study items associated with significant GO IDs (enriched)
#       35 study items associated with significant GO IDs (purified)
# done
# DONE!
#      83 items WROTE: Apc13__kinetocluster_enrich.tsv
# 83
# ['' 'Apc1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 224 IDs ...
# 100%    186 of    186 study items found in association
#  83%    186 of    224 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       70 GO terms are associated with    186 of    224 study items
#   METHOD fdr_bh:
#       55 GO terms found significant (< 0.15=alpha) ( 45 enriched +  10 purified): statsmodels fdr_bh
#      184 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      54 items WROTE: Apc1__kinetocluster_enrich.tsv
# 54
# ['' 'Mad2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 152 IDs ...
# 100%    121 of    121 study items found in association
#  80%    121 of    152 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       21 GO terms are associated with    121 of    152 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.15=alpha) ( 13 enriched +   8 purified): statsmodels fdr_bh
#      121 study items associated with significant GO IDs (enriched)
#        9 study items associated with significant GO IDs (purified)
# done
# DONE!
#      21 items WROTE: Mad2__kinetocluster_enrich.tsv
# 21
# ['' 'Apc2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 201 IDs ...
# 100%    137 of    137 study items found in association
#  68%    137 of    201 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       79 GO terms are associated with    137 of    201 study items
#   METHOD fdr_bh:
#       62 GO terms found significant (< 0.15=alpha) ( 50 enriched +  12 purified): statsmodels fdr_bh
#      132 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      62 items WROTE: Apc2__kinetocluster_enrich.tsv
# 62
# ['' 'Bub3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 592 IDs ...
# 100%    481 of    481 study items found in association
#  81%    481 of    592 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       67 GO terms are associated with    481 of    592 study items
#   METHOD fdr_bh:
#       61 GO terms found significant (< 0.15=alpha) ( 30 enriched +  31 purified): statsmodels fdr_bh
#      472 study items associated with significant GO IDs (enriched)
#       24 study items associated with significant GO IDs (purified)
# done
# DONE!
#      60 items WROTE: Bub3__kinetocluster_enrich.tsv
# 60
# ['' 'Mis12']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 160 IDs ...
# 100%     80 of     80 study items found in association
#  50%     80 of    160 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       11 GO terms are associated with     80 of    160 study items
#   METHOD fdr_bh:
#        5 GO terms found significant (< 0.15=alpha) (  2 enriched +   3 purified): statsmodels fdr_bh
#       75 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 items WROTE: Mis12__kinetocluster_enrich.tsv
# 4
# ['' 'Spc19']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 60 IDs ...
# 100%     40 of     40 study items found in association
#  67%     40 of     60 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       53 GO terms are associated with     40 of     60 study items
#   METHOD fdr_bh:
#       18 GO terms found significant (< 0.15=alpha) ( 18 enriched +   0 purified): statsmodels fdr_bh
#       38 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      16 items WROTE: Spc19__kinetocluster_enrich.tsv
# 16
# ['' 'Spc34']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 56 IDs ...
# 100%     43 of     43 study items found in association
#  77%     43 of     56 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       57 GO terms are associated with     43 of     56 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 28 enriched +   0 purified): statsmodels fdr_bh
#       43 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      28 items WROTE: Spc34__kinetocluster_enrich.tsv
# 28
# ['' 'Ctf13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 18 IDs ...
# 100%     14 of     14 study items found in association
#  78%     14 of     18 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       13 GO terms are associated with     14 of     18 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.15=alpha) (  8 enriched +   0 purified): statsmodels fdr_bh
#       14 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       8 items WROTE: Ctf13__kinetocluster_enrich.tsv
# 8
# ['' 'Apc9']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 130 IDs ...
# 100%    116 of    116 study items found in association
#  89%    116 of    130 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       45 GO terms are associated with    116 of    130 study items
#   METHOD fdr_bh:
#       27 GO terms found significant (< 0.15=alpha) ( 21 enriched +   6 purified): statsmodels fdr_bh
#      114 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      27 items WROTE: Apc9__kinetocluster_enrich.tsv
# 27
# ['' 'Hsk3' 'Duo1']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 68 IDs ...
# 100%     46 of     46 study items found in association
#  68%     46 of     68 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       44 GO terms are associated with     46 of     68 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.15=alpha) ( 15 enriched +   0 purified): statsmodels fdr_bh
#       30 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 items WROTE: Hsk3_Duo1__kinetocluster_enrich.tsv
# 15
# ['' 'Ndc10']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 56 IDs ...
# 100%     38 of     38 study items found in association
#  68%     38 of     56 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       34 GO terms are associated with     38 of     56 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.15=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 items WROTE: Ndc10__kinetocluster_enrich.tsv
# 4
# ['' 'CenpC']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 12 IDs ...
# 100%      1 of      1 study items found in association
#   8%      1 of     12 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        1 GO terms are associated with      1 of     12 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING CenpC__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Apc15']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 59 IDs ...
# 100%     49 of     49 study items found in association
#  83%     49 of     59 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       33 GO terms are associated with     49 of     59 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.15=alpha) (  5 enriched +   1 purified): statsmodels fdr_bh
#       41 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#       6 items WROTE: Apc15__kinetocluster_enrich.tsv
# 6
# ['' 'Nnf1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 56 IDs ...
# 100%     32 of     32 study items found in association
#  57%     32 of     56 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       54 GO terms are associated with     32 of     56 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.15=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
#       24 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       9 items WROTE: Nnf1__kinetocluster_enrich.tsv
# 9
# ['' 'Zwilch']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Zwilch__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Apc16']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 46 IDs ...
# 100%     32 of     32 study items found in association
#  70%     32 of     46 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with     32 of     46 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.15=alpha) (  7 enriched +   1 purified): statsmodels fdr_bh
#       29 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#       8 items WROTE: Apc16__kinetocluster_enrich.tsv
# 8
# ['' 'Apc11']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 29 IDs ...
# 100%      3 of      3 study items found in association
#  10%      3 of     29 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        3 GO terms are associated with      3 of     29 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING Apc11__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Apc10']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Apc10__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpM']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 91 IDs ...
# 100%     85 of     85 study items found in association
#  93%     85 of     91 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       15 GO terms are associated with     85 of     91 study items
#   METHOD fdr_bh:
#       16 GO terms found significant (< 0.15=alpha) ( 12 enriched +   4 purified): statsmodels fdr_bh
#       85 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 items WROTE: CenpM__kinetocluster_enrich.tsv
# 15
# ['' 'Apc4']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 6 IDs ...
# 100%      6 of      6 study items found in association
# 100%      6 of      6 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        8 GO terms are associated with      6 of      6 study items
#   METHOD fdr_bh:
#        4 GO terms found significant (< 0.15=alpha) (  4 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       4 items WROTE: Apc4__kinetocluster_enrich.tsv
# 4
# ['' 'Rod']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 3 IDs ...
# 100%      2 of      2 study items found in association
#  67%      2 of      3 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        3 GO terms are associated with      2 of      3 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING Rod__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Spindly']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Spindly__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Mps1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 366 IDs ...
# 100%    350 of    350 study items found in association
#  96%    350 of    366 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      135 GO terms are associated with    350 of    366 study items
#   METHOD fdr_bh:
#       90 GO terms found significant (< 0.15=alpha) ( 70 enriched +  20 purified): statsmodels fdr_bh
#      294 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
# done
# DONE!
#      89 items WROTE: Mps1__kinetocluster_enrich.tsv
# 89
# ['' 'CenpA']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 88 IDs ...
# 100%     49 of     49 study items found in association
#  56%     49 of     88 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       21 GO terms are associated with     49 of     88 study items
#   METHOD fdr_bh:
#        8 GO terms found significant (< 0.15=alpha) (  6 enriched +   2 purified): statsmodels fdr_bh
#       49 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       8 items WROTE: CenpA__kinetocluster_enrich.tsv
# 8
# ['' 'Ska3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 327 IDs ...
# 100%    270 of    270 study items found in association
#  83%    270 of    327 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      145 GO terms are associated with    270 of    327 study items
#   METHOD fdr_bh:
#      117 GO terms found significant (< 0.15=alpha) (102 enriched +  15 purified): statsmodels fdr_bh
#      268 study items associated with significant GO IDs (enriched)
#       17 study items associated with significant GO IDs (purified)
# done
# DONE!
#     116 items WROTE: Ska3__kinetocluster_enrich.tsv
# 116
# ['' 'SKAP']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 276 IDs ...
# 100%    268 of    268 study items found in association
#  97%    268 of    276 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       84 GO terms are associated with    268 of    276 study items
#   METHOD fdr_bh:
#       55 GO terms found significant (< 0.15=alpha) ( 39 enriched +  16 purified): statsmodels fdr_bh
#      258 study items associated with significant GO IDs (enriched)
#       11 study items associated with significant GO IDs (purified)
# done
# DONE!
#      52 items WROTE: SKAP__kinetocluster_enrich.tsv
# 52
# ['' 'Dsn1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 60 IDs ...
# 100%     26 of     26 study items found in association
#  43%     26 of     60 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        6 GO terms are associated with     26 of     60 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  2 enriched +   1 purified): statsmodels fdr_bh
#       25 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       2 items WROTE: Dsn1__kinetocluster_enrich.tsv
# 2
# ['' 'Astrin']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 207 IDs ...
# 100%    182 of    182 study items found in association
#  88%    182 of    207 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       72 GO terms are associated with    182 of    207 study items
#   METHOD fdr_bh:
#       53 GO terms found significant (< 0.15=alpha) ( 41 enriched +  12 purified): statsmodels fdr_bh
#      181 study items associated with significant GO IDs (enriched)
#        6 study items associated with significant GO IDs (purified)
# done
# DONE!
#      51 items WROTE: Astrin__kinetocluster_enrich.tsv
# 51
# ['' 'Sgo']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 110 IDs ...
# 100%     93 of     93 study items found in association
#  85%     93 of    110 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       68 GO terms are associated with     93 of    110 study items
#   METHOD fdr_bh:
#       57 GO terms found significant (< 0.15=alpha) ( 50 enriched +   7 purified): statsmodels fdr_bh
#       91 study items associated with significant GO IDs (enriched)
#       16 study items associated with significant GO IDs (purified)
# done
# DONE!
#      56 items WROTE: Sgo__kinetocluster_enrich.tsv
# 56
# ['' 'Nsl1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 273 IDs ...
# 100%    184 of    184 study items found in association
#  67%    184 of    273 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      108 GO terms are associated with    184 of    273 study items
#   METHOD fdr_bh:
#       86 GO terms found significant (< 0.15=alpha) ( 74 enriched +  12 purified): statsmodels fdr_bh
#      175 study items associated with significant GO IDs (enriched)
#       29 study items associated with significant GO IDs (purified)
# done
# DONE!
#      85 items WROTE: Nsl1__kinetocluster_enrich.tsv
# 85
# ['' 'Ska2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 177 IDs ...
# 100%    154 of    154 study items found in association
#  87%    154 of    177 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       69 GO terms are associated with    154 of    177 study items
#   METHOD fdr_bh:
#       57 GO terms found significant (< 0.15=alpha) ( 49 enriched +   8 purified): statsmodels fdr_bh
#      149 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      56 items WROTE: Ska2__kinetocluster_enrich.tsv
# 56
# ['' 'Cdc20']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 166 IDs ...
# 100%    159 of    159 study items found in association
#  96%    159 of    166 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       12 GO terms are associated with    159 of    166 study items
#   METHOD fdr_bh:
#       19 GO terms found significant (< 0.15=alpha) (  5 enriched +  14 purified): statsmodels fdr_bh
#      159 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      18 items WROTE: Cdc20__kinetocluster_enrich.tsv
# 18
# ['' 'CenpT']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 103 IDs ...
# 100%     92 of     92 study items found in association
#  89%     92 of    103 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       40 GO terms are associated with     92 of    103 study items
#   METHOD fdr_bh:
#       22 GO terms found significant (< 0.15=alpha) ( 19 enriched +   3 purified): statsmodels fdr_bh
#       85 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
# done
# DONE!
#      22 items WROTE: CenpT__kinetocluster_enrich.tsv
# 22
# ['' 'Knl1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 371 IDs ...
# 100%    264 of    264 study items found in association
#  71%    264 of    371 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#      118 GO terms are associated with    264 of    371 study items
#   METHOD fdr_bh:
#      100 GO terms found significant (< 0.15=alpha) ( 83 enriched +  17 purified): statsmodels fdr_bh
#      224 study items associated with significant GO IDs (enriched)
#       51 study items associated with significant GO IDs (purified)
# done
# DONE!
#     100 items WROTE: Knl1__kinetocluster_enrich.tsv
# 100
# ['' 'CenpR']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 162 IDs ...
# 100%    154 of    154 study items found in association
#  95%    154 of    162 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       54 GO terms are associated with    154 of    162 study items
#   METHOD fdr_bh:
#       43 GO terms found significant (< 0.15=alpha) ( 33 enriched +  10 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      41 items WROTE: CenpR__kinetocluster_enrich.tsv
# 41
# ['' 'CenpE']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 50 IDs ...
# 100%     37 of     37 study items found in association
#  74%     37 of     50 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       19 GO terms are associated with     37 of     50 study items
#   METHOD fdr_bh:
#       10 GO terms found significant (< 0.15=alpha) ( 10 enriched +   0 purified): statsmodels fdr_bh
#       31 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      10 items WROTE: CenpE__kinetocluster_enrich.tsv
# 10
# ['' 'Apc3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 232 IDs ...
# 100%    164 of    164 study items found in association
#  71%    164 of    232 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with    164 of    232 study items
#   METHOD fdr_bh:
#       27 GO terms found significant (< 0.15=alpha) ( 16 enriched +  11 purified): statsmodels fdr_bh
#      149 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      25 items WROTE: Apc3__kinetocluster_enrich.tsv
# 25
# ['' 'CenpH']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 268 IDs ...
# 100%    215 of    215 study items found in association
#  80%    215 of    268 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       94 GO terms are associated with    215 of    268 study items
#   METHOD fdr_bh:
#       54 GO terms found significant (< 0.15=alpha) ( 40 enriched +  14 purified): statsmodels fdr_bh
#      201 study items associated with significant GO IDs (enriched)
#       38 study items associated with significant GO IDs (purified)
# done
# DONE!
#      54 items WROTE: CenpH__kinetocluster_enrich.tsv
# 54
# ['' 'Dad2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 256 IDs ...
# 100%    153 of    153 study items found in association
#  60%    153 of    256 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       48 GO terms are associated with    153 of    256 study items
#   METHOD fdr_bh:
#       35 GO terms found significant (< 0.15=alpha) ( 27 enriched +   8 purified): statsmodels fdr_bh
#      135 study items associated with significant GO IDs (enriched)
#       33 study items associated with significant GO IDs (purified)
# done
# DONE!
#      32 items WROTE: Dad2__kinetocluster_enrich.tsv
# 32
# ['' 'Dam1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 129 IDs ...
# 100%     79 of     79 study items found in association
#  61%     79 of    129 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       19 GO terms are associated with     79 of    129 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.15=alpha) ( 11 enriched +   4 purified): statsmodels fdr_bh
#       79 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      14 items WROTE: Dam1__kinetocluster_enrich.tsv
# 14
# ['' 'Dad4']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 383 IDs ...
# 100%    259 of    259 study items found in association
#  68%    259 of    383 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with    259 of    383 study items
#   METHOD fdr_bh:
#       33 GO terms found significant (< 0.15=alpha) ( 14 enriched +  19 purified): statsmodels fdr_bh
#      231 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      32 items WROTE: Dad4__kinetocluster_enrich.tsv
# 32
# ['' 'Dad3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 161 IDs ...
# 100%    128 of    128 study items found in association
#  80%    128 of    161 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       23 GO terms are associated with    128 of    161 study items
#   METHOD fdr_bh:
#       12 GO terms found significant (< 0.15=alpha) (  7 enriched +   5 purified): statsmodels fdr_bh
#      126 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      12 items WROTE: Dad3__kinetocluster_enrich.tsv
# 12
# ['' 'Cep3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 155 IDs ...
# 100%    101 of    101 study items found in association
#  65%    101 of    155 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       50 GO terms are associated with    101 of    155 study items
#   METHOD fdr_bh:
#       29 GO terms found significant (< 0.15=alpha) ( 23 enriched +   6 purified): statsmodels fdr_bh
#       97 study items associated with significant GO IDs (enriched)
#       10 study items associated with significant GO IDs (purified)
# done
# DONE!
#      29 items WROTE: Cep3__kinetocluster_enrich.tsv
# 29
# ['' 'Ndc80']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 4 IDs ...
# 100%      3 of      3 study items found in association
#  75%      3 of      4 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        7 GO terms are associated with      3 of      4 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING Ndc80__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'p31comet']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 296 IDs ...
# 100%    263 of    263 study items found in association
#  89%    263 of    296 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       31 GO terms are associated with    263 of    296 study items
#   METHOD fdr_bh:
#       39 GO terms found significant (< 0.15=alpha) ( 18 enriched +  21 purified): statsmodels fdr_bh
#      261 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#      37 items WROTE: p31comet__kinetocluster_enrich.tsv
# 37
# ['' 'TRIP13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 26 IDs ...
# 100%     15 of     15 study items found in association
#  58%     15 of     26 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       11 GO terms are associated with     15 of     26 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  3 enriched +   0 purified): statsmodels fdr_bh
#        8 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       2 items WROTE: TRIP13__kinetocluster_enrich.tsv
# 2
# ['' 'Nuf2']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 21 IDs ...
# 100%      6 of      6 study items found in association
#  29%      6 of     21 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        3 GO terms are associated with      6 of     21 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING Nuf2__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'ZW10']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 485 IDs ...
# 100%    435 of    435 study items found in association
#  90%    435 of    485 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       32 GO terms are associated with    435 of    485 study items
#   METHOD fdr_bh:
#       52 GO terms found significant (< 0.15=alpha) ( 20 enriched +  32 purified): statsmodels fdr_bh
#      422 study items associated with significant GO IDs (enriched)
#       28 study items associated with significant GO IDs (purified)
# done
# DONE!
#      50 items WROTE: ZW10__kinetocluster_enrich.tsv
# 50
# ['' 'CenpF']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 91 IDs ...
# 100%     21 of     21 study items found in association
#  23%     21 of     91 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       29 GO terms are associated with     21 of     91 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.15=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       6 items WROTE: CenpF__kinetocluster_enrich.tsv
# 6
# ['' 'CenpU']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 33 IDs ...
# 100%      8 of      8 study items found in association
#  24%      8 of     33 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#        8 GO terms are associated with      8 of     33 study items
#   METHOD fdr_bh:
#        1 GO terms found significant (< 0.15=alpha) (  1 enriched +   0 purified): statsmodels fdr_bh
#        6 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       1 items WROTE: CenpU__kinetocluster_enrich.tsv
# 1
# ['' 'Zwint-1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 152 IDs ...
# 100%    145 of    145 study items found in association
#  95%    145 of    152 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       58 GO terms are associated with    145 of    152 study items
#   METHOD fdr_bh:
#       32 GO terms found significant (< 0.15=alpha) ( 25 enriched +   7 purified): statsmodels fdr_bh
#      138 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      31 items WROTE: Zwint-1__kinetocluster_enrich.tsv
# 31
# ['' 'MadBub']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 834 IDs ...
# 100%    709 of    709 study items found in association
#  85%    709 of    834 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       38 GO terms are associated with    709 of    834 study items
#   METHOD fdr_bh:
#       66 GO terms found significant (< 0.15=alpha) ( 13 enriched +  53 purified): statsmodels fdr_bh
#      642 study items associated with significant GO IDs (enriched)
#      147 study items associated with significant GO IDs (purified)
# done
# DONE!
#      64 items WROTE: MadBub__kinetocluster_enrich.tsv
# 64
# ['' 'Apc7']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 238 IDs ...
# 100%    156 of    156 study items found in association
#  66%    156 of    238 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       43 GO terms are associated with    156 of    238 study items
#   METHOD fdr_bh:
#       21 GO terms found significant (< 0.15=alpha) (  9 enriched +  12 purified): statsmodels fdr_bh
#      148 study items associated with significant GO IDs (enriched)
#        7 study items associated with significant GO IDs (purified)
# done
# DONE!
#      20 items WROTE: Apc7__kinetocluster_enrich.tsv
# 20
# ['' 'Apc8']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 48 IDs ...
# 100%     34 of     34 study items found in association
#  71%     34 of     48 study items found in population(8270255)
# Calculating 27,275 uncorrected p-values using fisher_scipy_stats
#   27,275 GO terms are associated with 8,270,213 of 8,270,255 population items
#       21 GO terms are associated with     34 of     48 study items
#   METHOD fdr_bh:
#        7 GO terms found significant (< 0.15=alpha) (  7 enriched +   0 purified): statsmodels fdr_bh
#       32 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       7 items WROTE: Apc8__kinetocluster_enrich.tsv
# 7
# DONE

# %%
#now lets look at a completely unknown network: sexual reproduction
#lets start with 3 queries of known proteins

# %%
#search Hap2 SPo11 Gex1
#mapping Hap2's uniprot ID to its OMA entry and querying with the OMA HOG
#we can use a pretty broad search to get the 100 closest profiles since we're only considering one HOG at a time
hap2= p.db_obj.id_resolver.resolve('f4jp36')
entry = p.db_obj.entry_by_entry_nr(hap2)
print(entry)
hap2hogs = p.hog_query(hog_id= str(entry[4]) ,  k=100)

#same for gex1
gex1= p.db_obj.id_resolver.resolve('A0A1P8B9F7')
entry = p.db_obj.entry_by_entry_nr(gex1)
print(entry)
gexhogs = p.hog_query(hog_id= str(entry[4]) , k=100)

#and spo11
spo11= p.db_obj.id_resolver.resolve('Q9M4A2')
entry = p.db_obj.entry_by_entry_nr(spo11)
print(entry)
spohogs = p.hog_query(hog_id= str(entry[4]) , k=100 )
# Out:
# (12398377, 4765549562, 706, 668654, b'HOG:0406399.2a.10b', b'4', 7063291, 7066784, 1, 0, b'HAP2_ARATH', 14309047062, 2119, b'64dcfddd880e7d4265a77286668f7be9', 630450286, 25, b'', -1, -1)
# (12410572, 4770822388, 516, 489288, b'HOG:0416115.3a', b'5', 22479153, 22481071, -1, 12410572, b'A0A1P8B9F7', 14324877735, 1549, b'c9c8e5d3b55063acdc397a5f1cd18710', 630755194, 25, b'', -1, -1)
# (12390911, 4762429318, 363, 831713, b'HOG:0605395.4b.6b', b'3', 4231560, 4234192, -1, 12390911, b'SPO11_ARATH', 14299678864, 1090, b'620e28803b4c72fae834a355cd77b6f3', 630263631, 25, b'', -1, -1)

# %%
#reading in the sequence identifiers for all HOGs pulled down in a search from the HDF5 can take some time
goares = {}
#'hap':hap2hogs, 'gex':gexhogs,
searches = { 'spo':spohogs}
for res in searches:
    enrich = goa.run_GOEA_onresults( searches[res], p.db_obj, study)
    goea_results_sig = [r for r in enrich[0] if r.p_fdr_bh < 0.05]
    study.wr_tsv(res + "_enrich.tsv", goea_results_sig)
# Out:
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 70

# %%
for res in goares:

    print(len(goea_results_sig))

# %%
#And now let's try the same thing with a bigger list of candidate genes
#load reproduction pathway hogs. These were downloaded from the SGD database as tsv files by selecting salient go terms.
#I added a few non yeast entries and stuff from literature manually

hogdf = pd.DataFrame.from_csv('./repro_hogs.csv')
hogdf['HOG'] = hogdf['1'].map( grabHog )
hogdf = hogdf[ ~hogdf.HOG.isna() ]
hashes = p.pull_hashes( [h for h in hogdf.HOG if len(h)>0] )
hogdf['hashsig'] = hogdf.HOG.map(hashes)
hogdf = hogdf[ ~hogdf.hashsig.isnull() ]
hogdf = hogdf.drop_duplicates('3')
names = dict(zip( hogdf.HOG, hogdf['3']))
print(hogdf)

# %%
#lets take a look at the clustering of our queries to see if some are coevolving and we can already notice some organisation
jkern2 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(hogdf.hashsig) ] for i,h1 in enumerate(hogdf.hashsig)]
jkern2 = np.asarray(jkern2)
jkern2+=jkern2.T
np.fill_diagonal(jkern2 , 1 )

# %%
import seaborn as sns

# %%
with PdfPages('repro_hash.pdf') as pdf:
    g = sns.clustermap( jkern2 , xticklabels= hogdf['3'] , yticklabels= hogdf['3'] , figsize = (25,25) )
    pdf.savefig()

# %%
#now lets fill in our network with some putative interactors
res = { h: p.hog_query( hog_id=str(h) , k = 20 ) for h in hogdf.HOG}
Hogs = [ h for results in res.values() for h in results ] + list(res.keys())

# %%
profiles = profiles = p.pull_hashes( set(Hogs) )
profiles = { h: {'hashsig': profiles[h] , 'name': names[h]  } if h in names else {'hashsig': profiles[h] , 'name': ''  }   for h in profiles }
profiles = pd.DataFrame.from_dict( profiles , orient='index' )

print(profiles.name.unique())
print(len(profiles.name.unique()))

print(len(profiles))

# %%
#lets calculate a new jaccard kernel for all of our search results and queries 
#again we can divide our results into clusters and try to see if each has a functional signature using GO enrichment

jkern3 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(profiles.hashsig) ] for i,h1 in enumerate(profiles.hashsig)]
jkern3 = np.asarray(jkern3)

jkern3+=jkern3.T
np.fill_diagonal(jkern3 , 1 )

# %%
print(jkern3)

# %%
cutoff = 0.995
import scipy

z = scipy.cluster.hierarchy.linkage(jkern3, method='average', metric='euclidean')
clusters = scipy.cluster.hierarchy.fcluster(z, t=cutoff, criterion='distance')
print(clusters)

# %%
with PdfPages('repro_hash.pdf') as pdf:

    #colors = [ c.hex_l for c in red.range_to( blue , len(set(clusters)) ) ]
    #colordict2 = dict( zip( list(set(clusters)) , list(colors)))
    #rowcolors = [ colordict2[c] for c in clusters]
    g = sns.clustermap( jkern3 , xticklabels= profiles.name , yticklabels= profiles.name , figsize = (20,20)  )
    g.ax_row_dendrogram.axvline(cutoff)
    g.ax_col_dendrogram.axhline(cutoff)
   
    pdf.savefig()

    plt.show()
# Out:
# --------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-22-87aac8c1d0b6> in <module>
#       4     #colordict2 = dict( zip( list(set(clusters)) , list(colors)))
#       5     #rowcolors = [ colordict2[c] for c in clusters]
# ----> 6     g = sns.clustermap( jkern3 , xticklabels= profiles.name , yticklabels= profiles.name , figsize = (20,20)  )
#       7     g.ax_row_dendrogram.axvline(cutoff)
#       8     g.ax_col_dendrogram.axhline(cutoff)
#
# NameError: name 'jkern3' is not defined

# %%
#and here we perform our enrichment of each cluster with a query in it
goares = {}
from pyprofiler.utils.hashutils import hogid2fam
dfs = []
for c in np.unique(clusters):
    sub = profiles.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        print(len(goea_results_sig))
        study.wr_tsv(namestr + "_reprocluster_enrich.tsv", goea_results_sig)
        try:
            res = pd.DataFrame.from_csv(namestr + "_reprocluster_enrich.tsv" , sep= '\t' , header = None)
            res['queries'] = ''.join( [ n + ' ' for  n in sub.name ])
            dfs.append( res)
        except:
            print('no res')
        print(len(goea_results_sig))

finaldf = pd.concat(dfs)
finaldf.to_csv('repro_augment_goenrich.csv')
print('DONE')
