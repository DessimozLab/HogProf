# %%
import sys
import pandas as pd
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
sys.path.append('../..')
print(sys.path)
# Out:
# ['/home/cactuskid/UNILMNT/projects/HogProf_refactor/src/HogProf/notebooks', '/home/cactuskid/miniconda3/envs/vscode/lib/python310.zip', '/home/cactuskid/miniconda3/envs/vscode/lib/python3.10', '/home/cactuskid/miniconda3/envs/vscode/lib/python3.10/lib-dynload', '', '/home/cactuskid/miniconda3/envs/vscode/lib/python3.10/site-packages', '../..', '../..']

# %%
#using the profiler. It's easy!
#lets import the profiler, configuration file and some tools for GO analysis to look at our returned results
from  hogprof.utils import hashutils , goautils
import hogprof.profiler as profiler

# %%
#lets also create a go annotation enrichment study object to describe functional enrichment in our profiling results
gaf = goautils.buildGAF( '/scratch/dmoi/datasets/OMA/apr2021/oma-go.txt' )
study = goautils.return_enrichment_study_obj( gaf , obo = '/scratch/dmoi/datasets/OMA/apr2021/go.obo')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/4360978/ipykernel_454722/198920216.py in <module>
#       1 #lets also create a go annotation enrichment study object to describe functional enrichment in our profiling results
# ----> 2 gaf = goa.buildGAF( '/scratch/dmoi/datasets/OMA/apr2021/oma-go.txt' )
#       3 study = goa.return_enrichment_study_obj( gaf , obo = '/scratch/dmoi/datasets/OMA/apr2021/go.obo')
#
# /scratch/dmoi/projects/HogProf/pyprofiler/notebooks/../../pyprofiler/utils/goatools_utils.py in buildGAF(gaf_file, universe)
#      50             words = line.split()
#      51             if words[0] not in gaf_filtered:
# ---> 52                 gaf_filtered[words[0]]=set([words[1]])
#      53             else:
#      54                 gaf_filtered[words[0]].add(words[1])
#
# KeyboardInterrupt:

# %%
	#lets load a compiled db containing the OMA root HOGs into a profiler oject 
	p = profiler.Profiler(lshforestpath = '/scratch/dmoi/datasets/birds/test/newlshforest.pkl' , hashes_h5='/scratch/dmoi/datasets/birds/test/hashes.h5' , mat_path= None, 
							oma = '/scratch/dmoi/datasets/birds/OmaServer.h5', tar= None , nsamples = 256 , mastertree = '/scratch/dmoi/datasets/birds/test_master_tree.pkl')
# Out:
# loading lsh
# indexing lsh
# /scratch/dmoi/condaenvs/ML2/lib/python3.9/site-packages/tables/leaf.py:367: PerformanceWarning: The Leaf ``/Protein/_i_Entries/OmaHOG/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   warnings.warn("""\
# 3508
# DONE

# %%
def grabHog(ID, verbose = True):
    try:
        entry = p.db_obj.entry_by_entry_nr(p.db_obj.id_resolver.resolve(ID))
        return entry[4].decode() , entry
    except:
        return np.nan,np.nan
#map to OMA HOGs

# %%
print(grabHog('F4JP36')) 
print(grabHog('YAL047C'))
# Out:
# ('HOG:A0232863.7b', (16769297, 6942599115, 706, 812226, b'HOG:A0232863.7b', b'4', 7063291, 7066784, 1, 0, b'HAP2_ARATH', 20844566641, 2119, b'64dcfddd880e7d4265a77286668f7be9', 799401297, 25, b'', -1, -1))
# ('HOG:A0310004', (7588641, 2630126000, 623, 785483, b'HOG:A0310004', b'I', 54989, 56857, -1, 0, b'SPC72_YEAST', 7897966640, 1870, b'31a1a828a53540768fac1af68a80375e', 0, 0, b'', -1, -1))

# %%
print( p.db_obj.hog_family(grabHog('F4JP36')[1]))
# Out:
# 232863

# %%
#load the kinetochore data and map it to OMA HOGs
#these are bla

# %%
#st results against oma since they had their own adhoc IDs
kinetodf = pd.read_csv('kineto_mapping.csv')
augment_datafreame = False

if augment_dataframe == True:
    #filter by evalue
    kinetodf  = kinetodf.drop('Unnamed: 0' , axis = 1)

    print(kinetodf)

    kinetodf= kinetodf[kinetodf['10']< .000001]
    kinetodf['name'] = kinetodf['0'].map( lambda x : x.split('_')[-1] )
    kinetodf['HOG'], kinetodf['entry'] = zip(*kinetodf['1'].map(grabHog))

    print(kinetodf.head())
    kinetodf.to_csv('kineto_mapping.csv')
# Out:
#                                            0           1        2     3    4  \
# 0        Homo_sapiens_HSAP017770_ANAPC1_Apc1  HUMAN17502  100.000  1944    0
# 1        Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28459   99.743  1944    5
# 2        Homo_sapiens_HSAP017770_ANAPC1_Apc1  CHLSB04039   99.383  1944   12
# 3        Homo_sapiens_HSAP017770_ANAPC1_Apc1  PAPAN05104   99.331  1944   13
# 4        Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28460   99.126  1945   14
# ...                                      ...         ...      ...   ...  ...
# 21788  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ZOONE12356   23.774   265  187
# 21789  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MOUSE51680   86.486    37    5
# 21790  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  PRIPA01848   23.136   389  233
# 21791  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MELHA08950   22.156   334  215
# 21792  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  SOLIN05576   23.188   414  266
#
#         5    6     7    8     9  ...              15      16              17  \
# 0       0    1  1944    1  1944  ...  HOG:0397431.2a    Apc1  HOG:0397431.2a
# 1       0    1  1944    1  1944  ...             NaN    Apc1             NaN
# 2       0    1  1944    1  1944  ...  HOG:0397431.2a    Apc1  HOG:0397431.2a
# 3       0    1  1944    1  1944  ...  HOG:0397431.2a    Apc1  HOG:0397431.2a
# 4       2    1  1944    1  1943  ...  HOG:0397431.2a    Apc1  HOG:0397431.2a
# ...    ..  ...   ...  ...   ...  ...             ...     ...             ...
# 21788   5  241   494  238   498  ...     HOG:0325882  Zwilch     HOG:0325882
# 21789   0  458   494    1    37  ...             NaN  Zwilch             NaN
# 21790  17   94   463  115   456  ...     HOG:0291935  Zwilch     HOG:0291935
# 21791   9  170   487  188   492  ...     HOG:0291935  Zwilch     HOG:0291935
# 21792  17  100   486   70   458  ...  HOG:0325882.1b  Zwilch  HOG:0325882.1b
#
#            18              19      20              21    name  \
# 0        Apc1  HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1
# 1        Apc1             NaN    Apc1             NaN    Apc1
# 2        Apc1  HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1
# 3        Apc1  HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1
# 4        Apc1  HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1
# ...       ...             ...     ...             ...     ...
# 21788  Zwilch     HOG:0365518  Zwilch     HOG:0325882  Zwilch
# 21789  Zwilch             NaN  Zwilch             NaN  Zwilch
# 21790  Zwilch     HOG:0329007  Zwilch     HOG:0291935  Zwilch
# 21791  Zwilch     HOG:0329007  Zwilch     HOG:0291935  Zwilch
# 21792  Zwilch  HOG:0365518.1a  Zwilch  HOG:0325882.1b  Zwilch
#
#                       HOG                                              entry
# 0      HOG:A0780445.8a.7a  (10451975, 4089787734, 341, 698029, b'HOG:A078...
# 1                     NaN  (10609157, 4160172944, 1945, 0, b'', b'2A', 10...
# 2      HOG:A0530973.3c.4b  (10090105, 3901830171, 1945, 711132, b'HOG:A05...
# 3      HOG:A0530973.3c.4b  (10268401, 3995754262, 1945, 711132, b'HOG:A05...
# 4      HOG:A0530973.3c.4b  (10609158, 4160174889, 1944, 711132, b'HOG:A05...
# ...                   ...                                                ...
# 21788        HOG:A0442397  (13336971, 5566601607, 622, 1003906, b'HOG:A04...
# 21789                 NaN  (9956062, 3831884737, 135, 0, b'', b'7', 72940...
# 21790        HOG:A0403944  (12038490, 4967805037, 836, 0, b'HOG:A0403944'...
# 21791        HOG:A0403944  (12258334, 5050779585, 638, 668089, b'HOG:A040...
# 21792     HOG:A0442397.1c  (13202173, 5513966156, 578, 1003906, b'HOG:A04...
#
# [21793 rows x 25 columns]
#                                      0           1        2     3   4  5  6  \
# 0  Homo_sapiens_HSAP017770_ANAPC1_Apc1  HUMAN17502  100.000  1944   0  0  1
# 1  Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28459   99.743  1944   5  0  1
# 2  Homo_sapiens_HSAP017770_ANAPC1_Apc1  CHLSB04039   99.383  1944  12  0  1
# 3  Homo_sapiens_HSAP017770_ANAPC1_Apc1  PAPAN05104   99.331  1944  13  0  1
# 4  Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28460   99.126  1945  14  2  1
#
#       7  8     9  ...              15    16              17    18  \
# 0  1944  1  1944  ...  HOG:0397431.2a  Apc1  HOG:0397431.2a  Apc1
# 1  1944  1  1944  ...             NaN  Apc1             NaN  Apc1
# 2  1944  1  1944  ...  HOG:0397431.2a  Apc1  HOG:0397431.2a  Apc1
# 3  1944  1  1944  ...  HOG:0397431.2a  Apc1  HOG:0397431.2a  Apc1
# 4  1944  1  1943  ...  HOG:0397431.2a  Apc1  HOG:0397431.2a  Apc1
#
#                19    20              21  name                 HOG  \
# 0  HOG:0452285.2a  Apc1  HOG:0397431.2a  Apc1  HOG:A0780445.8a.7a
# 1             NaN  Apc1             NaN  Apc1
# 2  HOG:0452285.2a  Apc1  HOG:0397431.2a  Apc1  HOG:A0530973.3c.4b
# 3  HOG:0452285.2a  Apc1  HOG:0397431.2a  Apc1  HOG:A0530973.3c.4b
# 4  HOG:0452285.2a  Apc1  HOG:0397431.2a  Apc1  HOG:A0530973.3c.4b
#
#                                                entry
# 0  [10451975, 4089787734, 341, 698029, b'HOG:A078...
# 1  [10609157, 4160172944, 1945, 0, b'', b'2A', 10...
# 2  [10090105, 3901830171, 1945, 711132, b'HOG:A05...
# 3  [10268401, 3995754262, 1945, 711132, b'HOG:A05...
# 4  [10609158, 4160174889, 1944, 711132, b'HOG:A05...
#
# [5 rows x 25 columns]

# %%
kinetodf = kinetodf.dropna(subset=['HOG'] , axis=0)
kinetodf['family_nr'] = kinetodf['entry'].map(p.hogid2fam).map(int)
kinetodf = kinetodf.dropna(subset=['family_nr'] , axis=0)
print(kinetodf)
# Out:
#                                            0           1        2     3    4  \
# 0        Homo_sapiens_HSAP017770_ANAPC1_Apc1  HUMAN17502  100.000  1944    0
# 2        Homo_sapiens_HSAP017770_ANAPC1_Apc1  CHLSB04039   99.383  1944   12
# 3        Homo_sapiens_HSAP017770_ANAPC1_Apc1  PAPAN05104   99.331  1944   13
# 4        Homo_sapiens_HSAP017770_ANAPC1_Apc1  PANTR28460   99.126  1945   14
# 5        Homo_sapiens_HSAP017770_ANAPC1_Apc1  CALJA06361   98.405  1944   30
# ...                                      ...         ...      ...   ...  ...
# 21787  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  LOALO09915   22.042   431  282
# 21788  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  ZOONE12356   23.774   265  187
# 21790  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  PRIPA01848   23.136   389  233
# 21791  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  MELHA08950   22.156   334  215
# 21792  Homo_sapiens_HSAP008261_ZWILCH_Zwilch  SOLIN05576   23.188   414  266
#
#         5    6     7    8     9  ...      16              17      18  \
# 0       0    1  1944    1  1944  ...    Apc1  HOG:0397431.2a    Apc1
# 2       0    1  1944    1  1944  ...    Apc1  HOG:0397431.2a    Apc1
# 3       0    1  1944    1  1944  ...    Apc1  HOG:0397431.2a    Apc1
# 4       2    1  1944    1  1943  ...    Apc1  HOG:0397431.2a    Apc1
# 5       1    1  1944    1  1943  ...    Apc1  HOG:0397431.2a    Apc1
# ...    ..  ...   ...  ...   ...  ...     ...             ...     ...
# 21787  16  134   535  118   523  ...  Zwilch     HOG:0291935  Zwilch
# 21788   5  241   494  238   498  ...  Zwilch     HOG:0325882  Zwilch
# 21790  17   94   463  115   456  ...  Zwilch     HOG:0291935  Zwilch
# 21791   9  170   487  188   492  ...  Zwilch     HOG:0291935  Zwilch
# 21792  17  100   486   70   458  ...  Zwilch  HOG:0325882.1b  Zwilch
#
#                    19      20              21    name                 HOG  \
# 0      HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1  HOG:A0780445.8a.7a
# 2      HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1  HOG:A0530973.3c.4b
# 3      HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1  HOG:A0530973.3c.4b
# 4      HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1  HOG:A0530973.3c.4b
# 5      HOG:0452285.2a    Apc1  HOG:0397431.2a    Apc1  HOG:A0530973.3c.4b
# ...               ...     ...             ...     ...                 ...
# 21787     HOG:0329007  Zwilch     HOG:0291935  Zwilch        HOG:A0403944
# 21788     HOG:0365518  Zwilch     HOG:0325882  Zwilch        HOG:A0442397
# 21790     HOG:0329007  Zwilch     HOG:0291935  Zwilch        HOG:A0403944
# 21791     HOG:0329007  Zwilch     HOG:0291935  Zwilch        HOG:A0403944
# 21792  HOG:0365518.1a  Zwilch  HOG:0325882.1b  Zwilch     HOG:A0442397.1c
#
#                                                    entry family_nr
# 0      [10451975, 4089787734, 341, 698029, b'HOG:A078...    780445
# 2      [10090105, 3901830171, 1945, 711132, b'HOG:A05...    530973
# 3      [10268401, 3995754262, 1945, 711132, b'HOG:A05...    530973
# 4      [10609158, 4160174889, 1944, 711132, b'HOG:A05...    530973
# 5      [10716394, 4217518810, 1944, 711132, b'HOG:A05...    530973
# ...                                                  ...       ...
# 21787  [12208163, 5030524859, 630, 668089, b'HOG:A040...    403944
# 21788  [13336971, 5566601607, 622, 1003906, b'HOG:A04...    442397
# 21790  [12038490, 4967805037, 836, 0, b'HOG:A0403944'...    403944
# 21791  [12258334, 5050779585, 638, 668089, b'HOG:A040...    403944
# 21792  [13202173, 5513966156, 578, 1003906, b'HOG:A04...    442397
#
# [18243 rows x 26 columns]

# %%
#now we can make a second dataframe with the hash signatures of each of our queries
#reading the hdf5 and grabbing all the hash signatures may take a moment
profiles = p.pull_hashes( set( kinetodf.family_nr) )
names = dict( zip( kinetodf.family_nr , kinetodf.name) )

# %%
profiles = { h: {'hashsig': profiles[h] , 'name': names[h]  }  for h in profiles if h in names}
profiles = pd.DataFrame.from_dict( profiles , orient='index' )
print(profiles)
profiles['sigsum'] = profiles.hashsig.map(lambda x : np.sum(x.digest()))
profiles = profiles[profiles.sigsum>0]
print(len(profiles.name.unique()))
profiles = profiles.drop_duplicates( subset = 'name', keep = 'last')
print(len(profiles))
print( profiles.hashsig.iloc[0].hashvalues.shape)
# Out:
#                                                   hashsig    name
# 49167   <datasketch.weighted_minhash.WeightedMinHash o...   CenpS
# 581649  <datasketch.weighted_minhash.WeightedMinHash o...     Plk
# 557079  <datasketch.weighted_minhash.WeightedMinHash o...  Nup160
# 172059  <datasketch.weighted_minhash.WeightedMinHash o...  Nup160
# 442397  <datasketch.weighted_minhash.WeightedMinHash o...  Zwilch
# ...                                                   ...     ...
# 442330  <datasketch.weighted_minhash.WeightedMinHash o...   CenpI
# 212953  <datasketch.weighted_minhash.WeightedMinHash o...   Cdc20
# 557026  <datasketch.weighted_minhash.WeightedMinHash o...  TRIP13
# 532468  <datasketch.weighted_minhash.WeightedMinHash o...   Cdc20
# 81915   <datasketch.weighted_minhash.WeightedMinHash o...    Cdh1
#
# [1528 rows x 2 columns]
# 89
# 89
# (256, 2)

# %%
import multiprocessing as mp
def distmp(args):
    if args == 0:
        return 0
    return  args[0].jaccard(args[1])
def jkern_mp(profiles,ncore = None):
    if ncore is None:
        pool = mp.Pool()
    else:
        pool = mp.Pool( ncore)
    jkern = [ pool.map( distmp, [ (h1,h2) if i<j else 0 for j,h2 in enumerate(list(profiles.hashsig)) ] , chunksize = 100 ) for i,h1 in enumerate(list(profiles.hashsig))]
    return jkern

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import colour
#we can perform an all vs all comparison to replicate the results in va hoof et al
import time 

with PdfPages('kineto_hash.pdf') as pdf:
    print(len(list(profiles.hashsig)) )
    start = time.time()
    print( list( profiles.hashsig )[0].jaccard(list(profiles.hashsig)[1]) )       
    print(time.time()-start)

    jkern = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(list(profiles.hashsig)) ] for i,h1 in enumerate(list(profiles.hashsig))]


    jkern = np.asarray(jkern)
    jkern+=jkern.T
    np.fill_diagonal( jkern , 1 )
    print(jkern)
    g = sns.clustermap( jkern , xticklabels= profiles.name , yticklabels= profiles.name , figsize = (20,20) )
    colorcode = pd.read_csv('./colorcode_kineto.csv')
    print(colorcode)
    red = colour.Color('red')
    blue = colour.Color('blue')
    
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode['Unnamed: 0']) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')
    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)
    pdf.savefig()
    g.savefig('kineto_hash.eps', format='eps')
    plt.show()
# Out:
# 89
# 0.1328125
# 0.0012516975402832031
# [[1.         0.1328125  0.         ... 0.29296875 0.         0.296875  ]
#  [0.1328125  1.         0.         ... 0.3359375  0.1015625  0.36328125]
#  [0.         0.         1.         ... 0.         0.         0.        ]
#  ...
#  [0.29296875 0.3359375  0.         ... 1.         0.171875   0.7890625 ]
#  [0.         0.1015625  0.         ... 0.171875   1.         0.171875  ]
#  [0.296875   0.36328125 0.         ... 0.7890625  0.171875   1.        ]]
#    Unnamed: 0  complex_number
# 0      Aurora               2
# 1      Incenp               2
# 2    Survivin               2
# 3    Borealin               2
# 4         Sgo               2
# ..        ...             ...
# 86        NAG              14
# 87      RINT1              14
# 88     Nup107              13
# 89     Nup133              13
# 90     Nup160              13
#
# [91 rows x 2 columns]

# %%
#lets load the original pearson correlation data and compare to our jaccard similarity metric
pearsondf = pd.DataFrame.from_csv('./kinetocore_pearson.csv')

with PdfPages('kineto_pearson.pdf') as pdf:

    g = sns.clustermap( pearsondf , xticklabels= pearsondf.index , yticklabels= pearsondf.index , figsize = (20,20) )

    colorcode = pd.DataFrame.from_csv('./colorcode_kineto.csv')
    red = colour.Color('red')
    blue = colour.Color('blue')
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode.index) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')

    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l in colordict:
            c =colordict[l]
        else:
            c = '#000000'
        tick_label.set_color(c)
    pdf.savefig()
    g.savefig('kineto_pearson.eps', format='eps')
    plt.show()
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
#lets compare the organisation of the complex in both as graph structures
import networkx as nx
pG = nx.from_numpy_matrix( pearsondf.to_numpy() )
jG = nx.from_numpy_matrix( jkern )
pG = nx.relabel_nodes( pG , { i:p for i,p in enumerate(pearsondf.index) })
jG = nx.relabel_nodes( jG , { i:p for i,p in enumerate(profiles.name) })
print(pG)
print(jG)
alledges={}
shared={}
topk = 20

for g in [jG, pG]:
    finalg = nx.Graph()
    for n in g.nodes():
        alledges = [ (n,l) for l in g.neighbors(n) if n != l ]
        weights = [ g[e[0]][e[1]]['weight'] for e in alledges]
        keep = np.flip(np.argsort(weights))[0:topk]
        edges = [ alledges[s] for s in list(keep) ]
        [  finalg.add_edge(e[0],e[1], weight= max(1/(i +1),g[e[0]][e[1]]['weight']) ) if finalg.has_edge(e[0],e[1]) else finalg.add_edge(e[0],e[1], weight= g[e[0]][e[1]]['weight']) for i,e in enumerate(edges)   ]
    pos = nx.spring_layout( finalg , weight='weight')
    weights = np.asarray([e[2]['weight'] for e in g.edges(data = True)])
    plt.figure( figsize = (17,17))
    cvec = [ colordict[n] if n in colordict else 'black' for n in finalg.nodes()]
    nx.draw(finalg, pos=pos, edge_color='grey', width= 2*np.log( weights ), node_size= 700, node_color = cvec ,alpha = .25 ) 
    labels=nx.draw_networkx_labels(finalg , pos = pos , font_size= 25 )
    plt.show()
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in log

# %%
from scipy.stats import pearsonr , spearmanr , brunnermunzel
pearsondf = pearsondf[profiles.name]
pearsondf = pearsondf.loc[profiles.name]
pearsonmat = pearsondf.to_numpy()
print(pearsonmat.shape)

print(jkern.shape)
print('spearman')
print( spearmanr( pearsonmat.ravel(), jkern.ravel() ))
print( 'pearson')
print( pearsonr( pearsonmat.ravel(), jkern.ravel() ))
print('permutation')
print( brunnermunzel( pearsonmat.ravel(), jkern.ravel() ))
# Out:
# (81, 81)
# (81, 81)
# spearman
# SpearmanrResult(correlation=0.17726330412936042, pvalue=1.8658666430120212e-47)
# pearson
# (0.307963058209016, 3.8301423513019886e-144)
# permutation
# BrunnerMunzelResult(statistic=15.951644176641043, pvalue=0.0)

# %%
#now we can add in the HOGs we found in our search
#the clustering shows a similar structure
print(len(profiles.index))

#lets query the the lsh with each HOG
res = { h: p.hog_query(hog_id= h, k = 10 ) for h in list(profiles.index) }
profiles_full = p.pull_hashes( set(res.keys()).union( set( [ h for results in res.values() for h in results ] ) ) )

names = dict( zip( kinetodf.HOG , kinetodf.name) )

profiles_ = { h: {'hashsig': profiles_full[h] , 'name': names[h]  } if h in names else {'hashsig': profiles_full[h] , 'name': ''  }   for h in profiles_full }

profiles_full = pd.DataFrame.from_dict( profiles_ , orient='index' )

print(profiles_full)
print(len(profiles_full))
# Out:
# 81
#                                                        hashsig    name
# 251348       <datasketch.weighted_minhash.WeightedMinHash o...
# 252023       <datasketch.weighted_minhash.WeightedMinHash o...
# 253927       <datasketch.weighted_minhash.WeightedMinHash o...
# 255123       <datasketch.weighted_minhash.WeightedMinHash o...
# 255506       <datasketch.weighted_minhash.WeightedMinHash o...
# 255519       <datasketch.weighted_minhash.WeightedMinHash o...
# 255542       <datasketch.weighted_minhash.WeightedMinHash o...
# 255648       <datasketch.weighted_minhash.WeightedMinHash o...
# 255675       <datasketch.weighted_minhash.WeightedMinHash o...
# 255707       <datasketch.weighted_minhash.WeightedMinHash o...
# 255729       <datasketch.weighted_minhash.WeightedMinHash o...
# 255819       <datasketch.weighted_minhash.WeightedMinHash o...
# 255867       <datasketch.weighted_minhash.WeightedMinHash o...
# 255891       <datasketch.weighted_minhash.WeightedMinHash o...
# 255961       <datasketch.weighted_minhash.WeightedMinHash o...
# 256093       <datasketch.weighted_minhash.WeightedMinHash o...
# 256200       <datasketch.weighted_minhash.WeightedMinHash o...
# 256268       <datasketch.weighted_minhash.WeightedMinHash o...
# 256287       <datasketch.weighted_minhash.WeightedMinHash o...
# 256404       <datasketch.weighted_minhash.WeightedMinHash o...
# 256414       <datasketch.weighted_minhash.WeightedMinHash o...
# 256471       <datasketch.weighted_minhash.WeightedMinHash o...
# 256508       <datasketch.weighted_minhash.WeightedMinHash o...
# 256810       <datasketch.weighted_minhash.WeightedMinHash o...
# 256850       <datasketch.weighted_minhash.WeightedMinHash o...
# 256978       <datasketch.weighted_minhash.WeightedMinHash o...
# 256994       <datasketch.weighted_minhash.WeightedMinHash o...
# 257034       <datasketch.weighted_minhash.WeightedMinHash o...
# 257045       <datasketch.weighted_minhash.WeightedMinHash o...
# 257252       <datasketch.weighted_minhash.WeightedMinHash o...
# ...                                                        ...     ...
# HOG:0407058  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0408220  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0408225  <datasketch.weighted_minhash.WeightedMinHash o...    Mad2
# HOG:0408807  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0408899  <datasketch.weighted_minhash.WeightedMinHash o...  Nup107
# HOG:0409203  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0409804  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0409968  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0410523  <datasketch.weighted_minhash.WeightedMinHash o...  HORMAD
# HOG:0415419  <datasketch.weighted_minhash.WeightedMinHash o...    Skp1
# HOG:0415589  <datasketch.weighted_minhash.WeightedMinHash o...    Apc7
# HOG:0416845  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0417115  <datasketch.weighted_minhash.WeightedMinHash o...    Nuf2
# HOG:0418884  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0419974  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0420485  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0420946  <datasketch.weighted_minhash.WeightedMinHash o...  TRIP13
# HOG:0421378  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0421960  <datasketch.weighted_minhash.WeightedMinHash o...   Ndc80
# HOG:0422600  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0423325  <datasketch.weighted_minhash.WeightedMinHash o...    ZW10
# HOG:0423327  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0603663  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0604038  <datasketch.weighted_minhash.WeightedMinHash o...  MadBub
# HOG:0605249  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0605381  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0609097  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0612245  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0612606  <datasketch.weighted_minhash.WeightedMinHash o...
# HOG:0614377  <datasketch.weighted_minhash.WeightedMinHash o...
#
# [840 rows x 2 columns]
# 840

# %%
#lets perform and enrichment on each cluster to see if we were able to pull down some functional modules
#some of these results may be unknown kinetochore proteins under an open world assumption
jkern0 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(list(profiles_full.hashsig) ) ] for i,h1 in enumerate(list( profiles_full.hashsig ) ) ]
jkern0 = np.asarray(jkern0)
jkern0+=jkern0.T
np.fill_diagonal( jkern0 , 1 )

# %%
import scipy

with PdfPages('kineto_augment.pdf') as pdf:

    cutoff = 1.3
    z = scipy.cluster.hierarchy.linkage(jkern0, method='average', metric='euclidean')
    clusters = scipy.cluster.hierarchy.fcluster(z, t=cutoff, criterion='distance')
    colors = [ c.hex_l for c in red.range_to( blue , len(set(clusters)) ) ]
    colordict2 = dict( zip( list(set(clusters)) , list(colors)))
    rowcolors = [ colordict2[c] for c in clusters]
    print(np.unique(clusters).shape )
    spacer = itertools.cycle([0,5 ,10])
    
    spacednamesy = [  '__' * next(spacer) + p if len(p)> 0 else '' for p in profiles_full.name ]
    spacednamesx = [  p +  '__' * next(spacer) if len(p)> 0 else '' for p in profiles_full.name ]
    print('graph gen')
    g = sns.clustermap( jkern0 , xticklabels= spacednamesx, yticklabels= spacednamesy , figsize = (20,20) ,  rasterized=True )
    colorcode = pd.DataFrame.from_csv('./colorcode_kineto.csv')
    red = colour.Color('red')
    blue = colour.Color('blue')
    colors = [ c.hex_l for c in red.range_to( blue , len(colorcode.complex_number.unique())) ]
    colordict = dict( zip( list(colorcode.index) , list(colorcode.complex_number)))
    colordict = { n:colors[colordict[n]] for n in colordict}
    red = colour.Color('red')
    blue = colour.Color('blue')
    print('coloring')

    g.ax_row_dendrogram.axvline(cutoff)
    g.ax_col_dendrogram.axhline(cutoff)

    for tick_label in g.ax_heatmap.axes.get_yticklabels():
        l = tick_label.get_text()
        if l.replace('_','') in colordict:
            c =colordict[ l.replace('_','')]
        else:
            c = '#000000'
        tick_label.set_color(c)

    for tick_label in g.ax_heatmap.axes.get_xticklabels():
        l = tick_label.get_text()
        if l.replace('_','') in colordict:
            c =colordict[ l.replace('_','')]
        else:
            c = '#000000'
        tick_label.set_color(c)   
    print('saving')
    pdf.savefig()
    print('done pdf')
    plt.show()

    g.savefig('kineto_augment.eps', format='eps' )
    print('DONE')
# Out:
# (142,)
# graph gen
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# coloring
# saving
# DONE

# %%
#we can enrich for functionality in each cluster
goares = {}
dfs = []
for c in list(np.unique(clusters)):
    sub = profiles_full.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ][0:5])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        study.wr_tsv(namestr + "_kinetocluster_enrich.tsv", goea_results_sig)
        try:
            res = pd.DataFrame.from_csv(namestr + "_kinetocluster_enrich.tsv" , sep= '\t' , header = None)
            res['queries'] = ''.join( [ n + ' ' for n in sub.name ])
            dfs.append(res)

        except:
            print('no res')
        print(len(goea_results_sig))

finaldf = pd.concat(dfs)
finaldf.to_csv('kineto_augment_goenrich.csv')
print('DONE')
# Out:
# ['' 'Dad3']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 209 IDs ...
# 100%    106 of    106 study items found in association
#  51%    106 of    209 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       43 GO terms are associated with    106 of    209 study items
#   METHOD fdr_bh:
#       27 GO terms found significant (< 0.15=alpha) ( 23 enriched +   4 purified): statsmodels fdr_bh
#       55 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      26 items WROTE: Dad3__kinetocluster_enrich.tsv
# 26
# ['' 'Dam1']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Dam1__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Dad2']
# compiling hogs
# 0
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:21: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 736 IDs ...
# 100%    579 of    579 study items found in association
#  79%    579 of    736 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       89 GO terms are associated with    579 of    736 study items
#   METHOD fdr_bh:
#       82 GO terms found significant (< 0.15=alpha) ( 49 enriched +  33 purified): statsmodels fdr_bh
#      472 study items associated with significant GO IDs (enriched)
#      144 study items associated with significant GO IDs (purified)
# done
# DONE!
#      80 items WROTE: Dad2__kinetocluster_enrich.tsv
# 80
# ['' 'Dad4']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 868 IDs ...
# 100%    794 of    794 study items found in association
#  91%    794 of    868 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      131 GO terms are associated with    794 of    868 study items
#   METHOD fdr_bh:
#      131 GO terms found significant (< 0.15=alpha) ( 80 enriched +  51 purified): statsmodels fdr_bh
#      634 study items associated with significant GO IDs (enriched)
#      251 study items associated with significant GO IDs (purified)
# done
# DONE!
#     126 items WROTE: Dad4__kinetocluster_enrich.tsv
# 126
# ['' 'ZW10']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 16 IDs ...
# 100%     12 of     12 study items found in association
#  75%     12 of     16 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       21 GO terms are associated with     12 of     16 study items
#   METHOD fdr_bh:
#       18 GO terms found significant (< 0.15=alpha) ( 18 enriched +   0 purified): statsmodels fdr_bh
#       11 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#      18 items WROTE: ZW10__kinetocluster_enrich.tsv
# 18
# ['' 'MadBub']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING MadBub__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpP']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING CenpP__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Cdc20']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 12 IDs ...
# 100%      9 of      9 study items found in association
#  75%      9 of     12 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       12 GO terms are associated with      9 of     12 study items
#   METHOD fdr_bh:
#        6 GO terms found significant (< 0.15=alpha) (  6 enriched +   0 purified): statsmodels fdr_bh
#        9 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       6 items WROTE: Cdc20__kinetocluster_enrich.tsv
# 6
# ['' 'Skp1']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 13178 IDs ...
# 100% 11,862 of 11,862 study items found in association
#  90% 11,862 of 13,178 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#    1,572 GO terms are associated with 11,862 of 13,178 study items
#   METHOD fdr_bh:
#    1,770 GO terms found significant (< 0.15=alpha) (624 enriched + 1146 purified): statsmodels fdr_bh
#   11,714 study items associated with significant GO IDs (enriched)
#    5,337 study items associated with significant GO IDs (purified)
# done
# DONE!
#    1659 items WROTE: Skp1__kinetocluster_enrich.tsv
# 1659
# ['' 'Mad2' 'Ndc80']
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 30340 IDs ...
# 100% 26,986 of 26,986 study items found in association
#  89% 26,986 of 30,340 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#    2,427 GO terms are associated with 26,986 of 30,340 study items
#   METHOD fdr_bh:
#    3,778 GO terms found significant (< 0.15=alpha) (956 enriched + 2822 purified): statsmodels fdr_bh
#   26,449 study items associated with significant GO IDs (enriched)
#   13,489 study items associated with significant GO IDs (purified)
# done
# DONE!
#    3549 items WROTE: Mad2_Ndc80__kinetocluster_enrich.tsv
# 3549
# ['' 'Apc10']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 4269 IDs ...
# 100%  3,829 of  3,829 study items found in association
#  90%  3,829 of  4,269 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      555 GO terms are associated with  3,829 of  4,269 study items
#   METHOD fdr_bh:
#      530 GO terms found significant (< 0.15=alpha) (171 enriched + 359 purified): statsmodels fdr_bh
#    3,775 study items associated with significant GO IDs (enriched)
#      824 study items associated with significant GO IDs (purified)
# done
# DONE!
#     488 items WROTE: Apc10__kinetocluster_enrich.tsv
# 488
# ['' 'Nuf2']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Nuf2__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'RINT1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 883 IDs ...
# 100%    643 of    643 study items found in association
#  73%    643 of    883 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      143 GO terms are associated with    643 of    883 study items
#   METHOD fdr_bh:
#       89 GO terms found significant (< 0.15=alpha) ( 51 enriched +  38 purified): statsmodels fdr_bh
#      639 study items associated with significant GO IDs (enriched)
#       56 study items associated with significant GO IDs (purified)
# done
# DONE!
#      89 items WROTE: RINT1__kinetocluster_enrich.tsv
# 89
# ['' 'Apc16' 'Nsl1']
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2919 IDs ...
# 100%  2,721 of  2,721 study items found in association
#  93%  2,721 of  2,919 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      899 GO terms are associated with  2,721 of  2,919 study items
#   METHOD fdr_bh:
#      683 GO terms found significant (< 0.15=alpha) (471 enriched + 212 purified): statsmodels fdr_bh
#    2,659 study items associated with significant GO IDs (enriched)
#      824 study items associated with significant GO IDs (purified)
# done
# DONE!
#     660 items WROTE: Apc16_Nsl1__kinetocluster_enrich.tsv
# 660
# ['' 'Spc24']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 92 IDs ...
# 100%     89 of     89 study items found in association
#  97%     89 of     92 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       33 GO terms are associated with     89 of     92 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 25 enriched +   3 purified): statsmodels fdr_bh
#       88 study items associated with significant GO IDs (enriched)
#        1 study items associated with significant GO IDs (purified)
# done
# DONE!
#      28 items WROTE: Spc24__kinetocluster_enrich.tsv
# 28
# ['' 'p31comet']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING p31comet__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpH']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 163 IDs ...
# 100%    101 of    101 study items found in association
#  62%    101 of    163 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      114 GO terms are associated with    101 of    163 study items
#   METHOD fdr_bh:
#       74 GO terms found significant (< 0.15=alpha) ( 69 enriched +   5 purified): statsmodels fdr_bh
#       97 study items associated with significant GO IDs (enriched)
#        4 study items associated with significant GO IDs (purified)
# done
# DONE!
#      72 items WROTE: CenpH__kinetocluster_enrich.tsv
# 72
# ['' 'CenpM']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 148 IDs ...
# 100%     75 of     75 study items found in association
#  51%     75 of    148 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#        6 GO terms are associated with     75 of    148 study items
#   METHOD fdr_bh:
#        3 GO terms found significant (< 0.15=alpha) (  2 enriched +   1 purified): statsmodels fdr_bh
#       74 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       3 items WROTE: CenpM__kinetocluster_enrich.tsv
# 3
# ['' 'Apc12' 'CenpL' 'Mis12']
# compiling hogs
# 0
# 10
# 20
# 30
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 3007 IDs ...
# 100%  2,578 of  2,578 study items found in association
#  86%  2,578 of  3,007 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      626 GO terms are associated with  2,578 of  3,007 study items
#   METHOD fdr_bh:
#      579 GO terms found significant (< 0.15=alpha) (361 enriched + 218 purified): statsmodels fdr_bh
#    2,399 study items associated with significant GO IDs (enriched)
#    1,399 study items associated with significant GO IDs (purified)
# done
# DONE!
#     561 items WROTE: Apc12_CenpL_Mis12__kinetocluster_enrich.tsv
# 561
# ['' 'CenpK' 'CenpO' 'CenpN']
# compiling hogs
# 0
# 10
# 20
# 30
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2804 IDs ...
# 100%  2,200 of  2,200 study items found in association
#  78%  2,200 of  2,804 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      685 GO terms are associated with  2,200 of  2,804 study items
#   METHOD fdr_bh:
#      568 GO terms found significant (< 0.15=alpha) (403 enriched + 165 purified): statsmodels fdr_bh
#    1,977 study items associated with significant GO IDs (enriched)
#    1,013 study items associated with significant GO IDs (purified)
# done
# DONE!
#     555 items WROTE: CenpK_CenpO_CenpN__kinetocluster_enrich.tsv
# 555
# ['' 'Nnf1']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 116 IDs ...
# 100%      6 of      6 study items found in association
#   5%      6 of    116 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       22 GO terms are associated with      6 of    116 study items
#   METHOD fdr_bh:
#        0 GO terms found significant (< 0.15=alpha) (  0 enriched +   0 purified): statsmodels fdr_bh
#        0 study items associated with significant GO IDs (enriched)
#        0 study items associated with significant GO IDs (purified)
# done
# DONE!
#       0 items. NOT WRITING Nnf1__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpR']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 199 IDs ...
# 100%    186 of    186 study items found in association
#  93%    186 of    199 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      126 GO terms are associated with    186 of    199 study items
#   METHOD fdr_bh:
#       77 GO terms found significant (< 0.15=alpha) ( 65 enriched +  12 purified): statsmodels fdr_bh
#      184 study items associated with significant GO IDs (enriched)
#       15 study items associated with significant GO IDs (purified)
# done
# DONE!
#      76 items WROTE: CenpR__kinetocluster_enrich.tsv
# 76
# ['' 'Apc3']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 1077 IDs ...
# 100%    943 of    943 study items found in association
#  88%    943 of  1,077 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      558 GO terms are associated with    943 of  1,077 study items
#   METHOD fdr_bh:
#      366 GO terms found significant (< 0.15=alpha) (302 enriched +  64 purified): statsmodels fdr_bh
#      931 study items associated with significant GO IDs (enriched)
#      401 study items associated with significant GO IDs (purified)
# done
# DONE!
#     361 items WROTE: Apc3__kinetocluster_enrich.tsv
# 361
# ['' 'Astrin']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 239 IDs ...
# 100%    234 of    234 study items found in association
#  98%    234 of    239 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      150 GO terms are associated with    234 of    239 study items
#   METHOD fdr_bh:
#       95 GO terms found significant (< 0.15=alpha) ( 86 enriched +   9 purified): statsmodels fdr_bh
#      233 study items associated with significant GO IDs (enriched)
#        3 study items associated with significant GO IDs (purified)
# done
# DONE!
#      95 items WROTE: Astrin__kinetocluster_enrich.tsv
# 95
# ['' 'CenpQ' 'CenpW']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 228 IDs ...
# 100%    142 of    142 study items found in association
#  62%    142 of    228 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      125 GO terms are associated with    142 of    228 study items
#   METHOD fdr_bh:
#       48 GO terms found significant (< 0.15=alpha) ( 37 enriched +  11 purified): statsmodels fdr_bh
#      140 study items associated with significant GO IDs (enriched)
#        9 study items associated with significant GO IDs (purified)
# done
# DONE!
#      48 items WROTE: CenpQ_CenpW__kinetocluster_enrich.tsv
# 48
# ['' 'CenpC' 'CenpT']
# compiling hogs
# 0
# 10
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 850 IDs ...
# 100%    732 of    732 study items found in association
#  86%    732 of    850 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      230 GO terms are associated with    732 of    850 study items
#   METHOD fdr_bh:
#      132 GO terms found significant (< 0.15=alpha) ( 91 enriched +  41 purified): statsmodels fdr_bh
#      644 study items associated with significant GO IDs (enriched)
#      211 study items associated with significant GO IDs (purified)
# done
# DONE!
#     130 items WROTE: CenpC_CenpT__kinetocluster_enrich.tsv
# 130
# ['' 'Apc13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 208 IDs ...
# 100%    182 of    182 study items found in association
#  88%    182 of    208 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       54 GO terms are associated with    182 of    208 study items
#   METHOD fdr_bh:
#       28 GO terms found significant (< 0.15=alpha) ( 17 enriched +  11 purified): statsmodels fdr_bh
#      120 study items associated with significant GO IDs (enriched)
#        5 study items associated with significant GO IDs (purified)
# done
# DONE!
#      27 items WROTE: Apc13__kinetocluster_enrich.tsv
# 27
# ['' 'Apc4' 'Nup160']
# compiling hogs
# 0
# 10
# 20
# 30
# 40
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 6473 IDs ...
# 100%  5,882 of  5,882 study items found in association
#  91%  5,882 of  6,473 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#    1,306 GO terms are associated with  5,882 of  6,473 study items
#   METHOD fdr_bh:
#    1,212 GO terms found significant (< 0.15=alpha) (709 enriched + 503 purified): statsmodels fdr_bh
#    5,726 study items associated with significant GO IDs (enriched)
#    3,038 study items associated with significant GO IDs (purified)
# done
# DONE!
#    1172 items WROTE: Apc4_Nup160__kinetocluster_enrich.tsv
# 1172
# ['' 'HORMAD']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING HORMAD__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'NAG']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 764 IDs ...
# 100%    660 of    660 study items found in association
#  86%    660 of    764 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      258 GO terms are associated with    660 of    764 study items
#   METHOD fdr_bh:
#      122 GO terms found significant (< 0.15=alpha) ( 86 enriched +  36 purified): statsmodels fdr_bh
#      638 study items associated with significant GO IDs (enriched)
#       48 study items associated with significant GO IDs (purified)
# done
# DONE!
#     121 items WROTE: NAG__kinetocluster_enrich.tsv
# 121
# ['' 'Apc15']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Apc15__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'Spindly']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING Spindly__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpS']
# compiling hogs
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 0 IDs ...
# done
# DONE!
#       0 items. NOT WRITING CenpS__kinetocluster_enrich.tsv
# no res
# 0
# ['' 'CenpI']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 197 IDs ...
# 100%    184 of    184 study items found in association
#  93%    184 of    197 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       71 GO terms are associated with    184 of    197 study items
#   METHOD fdr_bh:
#       46 GO terms found significant (< 0.15=alpha) ( 32 enriched +  14 purified): statsmodels fdr_bh
#      183 study items associated with significant GO IDs (enriched)
#        2 study items associated with significant GO IDs (purified)
# done
# DONE!
#      46 items WROTE: CenpI__kinetocluster_enrich.tsv
# 46
# ['' 'Nup107']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 179 IDs ...
# 100%    137 of    137 study items found in association
#  77%    137 of    179 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#       43 GO terms are associated with    137 of    179 study items
#   METHOD fdr_bh:
#       15 GO terms found significant (< 0.15=alpha) (  5 enriched +  10 purified): statsmodels fdr_bh
#      132 study items associated with significant GO IDs (enriched)
#        8 study items associated with significant GO IDs (purified)
# done
# DONE!
#      15 items WROTE: Nup107__kinetocluster_enrich.tsv
# 15
# ['' 'Apc5' 'Apc7']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2199 IDs ...
# 100%  1,822 of  1,822 study items found in association
#  83%  1,822 of  2,199 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      430 GO terms are associated with  1,822 of  2,199 study items
#   METHOD fdr_bh:
#      292 GO terms found significant (< 0.15=alpha) (169 enriched + 123 purified): statsmodels fdr_bh
#    1,753 study items associated with significant GO IDs (enriched)
#      503 study items associated with significant GO IDs (purified)
# done
# DONE!
#     284 items WROTE: Apc5_Apc7__kinetocluster_enrich.tsv
# 284
# ['' 'TRIP13']
# compiling hogs
# 0
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 2771 IDs ...
# 100%  2,062 of  2,062 study items found in association
#  74%  2,062 of  2,771 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#      514 GO terms are associated with  2,062 of  2,771 study items
#   METHOD fdr_bh:
#      312 GO terms found significant (< 0.15=alpha) (155 enriched + 157 purified): statsmodels fdr_bh
#    1,918 study items associated with significant GO IDs (enriched)
#      429 study items associated with significant GO IDs (purified)
# done
# DONE!
#     298 items WROTE: TRIP13__kinetocluster_enrich.tsv
# 298
# DONE

# %%
#now lets look at a completely unknown network: sexual reproduction
#lets start with 3 queries of known proteins

# %%
#search Hap2 SPo11 Gex1
#mapping Hap2's uniprot ID to its OMA entry and querying with the OMA HOG
#we can use a pretty broad search to get the 100 closest profiles since we're only considering one HOG at a time
hap2hogs = p.hog_query(hog_id=  grabHog('ARATH26614') ,  k=100)
#same for gex1
gexhogs = p.hog_query(hog_id= grabHog('ARATH38809'), k=100)
#and spo11
spohogs = p.hog_query(hog_id=  grabHog('ARATH19148') , k=100 )

# %%
print(len(spohogs))

from hogprof.utils.hashutils import hogid2fam , fam2hogid
spohogs.remove( str(hogid2fam(grabHog('ARATH19148')) ) )
#spohogs.remove(str(613129))
spohogs.remove(str(612406))

print(len(spohogs))
# Out:
# 100
# 98

# %%
entries = p.db_obj.iter_members_of_hog_id(fam2hogid(spohogs[0]))

print(next(entries))

from pyoma.browser.models import ProteinEntry
import timeout_decorator

@timeout_decorator.timeout(10, use_signals=True , timeout_exception=TimeoutError )
def return_members(result,db_obj):
    return db_obj.hog_members_from_hog_id( result, level = 'LUCA' )
print(fam2hogid(spohogs[0]))
members = return_members( fam2hogid(spohogs[0]) , p.db_obj)
print(ProteinEntry(p.db_obj, members[0] ))
# Out:
# <ProteinEntry(1271, KORCO01271)>
# HOG:0611355
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/_i_HogLevel/ID/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/_i_HogLevel/Level/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# <ProteinEntry(1271, KORCO01271)>

# %%
#reading in the sequence identifiers for all HOGs pulled down in a search from the HDF5 can take some time
goares = {}
#'hap':hap2hogs, 'gex':gexhogs,
searches = {  'spo11':spohogs }
for res in searches:
    
    enrich = goa.run_GOEA_onresults( searches[res], p.db_obj, study)
    goea_results_sig = [r for r in enrich[0] if r.p_fdr_bh < 0.05]
    study.wr_tsv(res + "_enrich.tsv", goea_results_sig)
# Out:
# compiling hogs
# mod13
# 0
# 611355
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01271
# 611114
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00159
# 604564
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00876
# 606429
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00301
# 409616
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# PLAF704318
# 605921
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# GRATM02427
# 606182
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01473
# 409561
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# PLAF700768
# 605549
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# HALMD01420
# 403933
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# PLAF704395
# 10
# 613129
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# HALSG00236
# 607778
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01358
# 610371
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01472
# 614338
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01507
# 415747
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# PLAF700191
# 613327
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# ACIC502166
# 607712
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01356
# 606935
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00162
# 614091
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01549
# 612613
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00987
# 20
# 608169
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00277
# 409968
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# PLAF702008
# 612291
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00243
# 609492
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00998
# 610384
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01452
# 607736
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01547
# 603659
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# THEPD00017
# 608502
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01334
# 604242
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
# ...
# done
# KORCO00121
# 608965
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01563
# 90
# 417318
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# POLPP02306
# 608612
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# METFA00802
# 612349
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01366
# 612299
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01333
# 613726
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01314
# 604323
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO00001
# 412950
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# EIMMA04201
# 603753
# started
# Cannot load SequenceSearch. Any future call to seq_search will fail!
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 879, in __init__
#     self.seq_idx = self.seq_idx()
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/link.py", line 397, in __call__
#     self.extfile = tables.open_file(filename, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 320, in open_file
#     return File(filename, mode, title, root_uep, filters, **kwargs)
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/file.py", line 784, in __init__
#     self._g_new(filename, mode, **params)
#   File "tables/hdf5extension.pyx", line 374, in tables.hdf5extension.File._g_new
#   File "/home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/tables/utils.py", line 157, in check_file_access
#     raise IOError("``%s`` does not exist" % (filename,))
# OSError: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "../../pyprofiler/pyoma/browser/db.py", line 87, in __init__
#     self.seq_search = SequenceSearch(self)
#   File "../../pyprofiler/pyoma/browser/db.py", line 884, in __init__
#     raise DBConsistencyError("Suffix index for protein sequences is not available: "+str(e))
# pyprofiler.pyoma.browser.db.DBConsistencyError: Suffix index for protein sequences is not available: ``/home/cactuskid13/mntpt/OMA/jun/OmaServer.h5.idx`` does not exist
# done
# KORCO01573
# done
# running GO enrichment study
#
# Run GOEA Gene Ontology Analysis: current study set of 43893 IDs ...
# 100% 40,538 of 40,538 study items found in association
#  92% 40,538 of 43,893 study items found in population(9897212)
# Calculating 27,917 uncorrected p-values using fisher_scipy_stats
#   27,917 GO terms are associated with 9,897,196 of 9,897,212 population items
#    2,248 GO terms are associated with 40,538 of 43,893 study items
#   METHOD fdr_bh:
#    5,019 GO terms found significant (< 0.15=alpha) (997 enriched + 4022 purified): statsmodels fdr_bh
#   40,249 study items associated with significant GO IDs (enriched)
#   17,463 study items associated with significant GO IDs (purified)
# done
# DONE!
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    4230 items WROTE: spo11_enrich.tsv

# %%
for res in goares:
    print(len(goea_results_sig))

# %%
#And now let's try the same thing with a bigger list of candidate genes
#load reproduction pathway hogs. These were downloaded from the SGD database as tsv files by selecting salient go terms.
#I added a few non yeast entries and stuff from literature manually
hogdf = pd.DataFrame.from_csv('./repro_hogs.csv')
print(hogdf)
hogdf['HOG'] = hogdf['1'].map( grabHog )
hogdf = hogdf[ ~hogdf.HOG.isna() ]
hashes = p.pull_hashes( [h for h in hogdf.HOG if len(h)>0] )
hogdf['hashsig'] = hogdf.HOG.map(hashes)
hogdf = hogdf[ ~hogdf.hashsig.isnull() ]

hogdf = hogdf.drop_duplicates('3')
names = dict(zip( hogdf.HOG, hogdf['3']))
# Out:
# /home/cactuskid13/miniconda3/envs/pyprofiler3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   after removing the cwd from sys.path.
#                0           1                     2      3  \
# 0.0   S000001692     YKL209C         S. cerevisiae   STE6
# 1.0   S000002248     YDL090C         S. cerevisiae   RAM1
# 2.0   S000006326     YPR122W         S. cerevisiae   AXL1
# 0.0   S000000951     YER149C         S. cerevisiae   PEA2
# 1.0   S000003944     YLL021W         S. cerevisiae   SPA2
# 2.0   S000005215     YNL271C         S. cerevisiae   BNI1
# 0.0   S000000818     YER016W         S. cerevisiae   BIM1
# 1.0   S000004715     YMR109W         S. cerevisiae   MYO5
# 2.0   S000004811     YMR198W         S. cerevisiae   CIK1
# 3.0   S000005900     YOR373W         S. cerevisiae   NUD1
# 4.0   S000006190     YPL269W         S. cerevisiae   KAR9
# 5.0   S000006345     YPR141C         S. cerevisiae   KAR3
# 0.0   S000000534     YCL029C         S. cerevisiae   BIK1
# 1.0   S000000560     YCL055W         S. cerevisiae   KAR4
# 2.0   S000001115     YHR073W         S. cerevisiae   OSH3
# 3.0   S000001299     YIL037C         S. cerevisiae   PRM2
# 4.0   S000003556     YJL019W         S. cerevisiae   MPS3
# 5.0   S000003571     YJL034W         S. cerevisiae   KAR2
# 6.0   S000003609     YJL073W         S. cerevisiae   JEM1
# 7.0   S000004669     YMR065W         S. cerevisiae   KAR5
# 8.0   S000004811     YMR198W         S. cerevisiae   CIK1
# 9.0   S000004845     YMR232W         S. cerevisiae   FUS2
# 10.0  S000005132     YNL188W         S. cerevisiae   KAR1
# 11.0  S000006113     YPL192C         S. cerevisiae   PRM3
# 12.0  S000006190     YPL269W         S. cerevisiae   KAR9
# 13.0  S000006345     YPR141C         S. cerevisiae   KAR3
# 0.0   S000000045     YAL047C         S. cerevisiae  SPC72
# 1.0   S000000112     YBL016W         S. cerevisiae   FUS3
# 2.0   S000000999     YHL007C         S. cerevisiae  STE20
# 3.0   S000001661     YKL178C         S. cerevisiae   STE3
# ...          ...         ...                   ...    ...
# NaN   S000006211     YPR007C         S. cerevisiae   REC8
# NaN   LEPOC06130      W5M6Y3         S. cerevisiae  SPO11
# NaN   ARATH26614      F4JP36  Arabidopsis thaliana   HAP2
# NaN   DANRE26148  BMBL_DANRE           Danio rerio   KAR5
# NaN   ARATH38809  A0A1P8B9F7  Arabidopsis thaliana   KAR5
# NaN   S000000897     YER095W         S. cerevisiae  RAD51
# NaN   S000000981     YER179W         S. cerevisiae   DMC1
# NaN   S000001014     YHL022C         S. cerevisiae  SPO11
# NaN   S000001334     YIL072W         S. cerevisiae   HOP1
# NaN   S000001891     YFL003C         S. cerevisiae   MSH4
# NaN   S000002313     YDL154W         S. cerevisiae   MSH5
# NaN   S000002504     YDR097C         S. cerevisiae   MSH6
# NaN   S000003001     YGL033W         S. cerevisiae   HOP2
# NaN   S000003151     YGL183C         S. cerevisiae   MND1
# NaN   S000005450     YOL090W         S. cerevisiae   MSH2
# NaN   S000006211     YPR007C         S. cerevisiae   REC8
# NaN   S000000534     YCL029C         S. cerevisiae   BIK1
# NaN   S000000560     YCL055W         S. cerevisiae   KAR4
# NaN   S000001115     YHR073W         S. cerevisiae   OSH3
# NaN   S000001299     YIL037C         S. cerevisiae   PRM2
# NaN   S000003556     YJL019W         S. cerevisiae   MPS3
# NaN   S000003571     YJL034W         S. cerevisiae   KAR2
# NaN   S000003609     YJL073W         S. cerevisiae   JEM1
# NaN   S000004669     YMR065W         S. cerevisiae   KAR5
# NaN   S000004811     YMR198W         S. cerevisiae   CIK1
# NaN   S000004845     YMR232W         S. cerevisiae   FUS2
# NaN   S000005132     YNL188W         S. cerevisiae   KAR1
# NaN   S000006113     YPL192C         S. cerevisiae   PRM3
# NaN   S000006190     YPL269W         S. cerevisiae   KAR9
# NaN   S000006345     YPR141C         S. cerevisiae   KAR3
#
#                                                       4  \
# 0.0                                             STErile
# 1.0                 RAS protein and A-factor Maturation
# 2.0                                       AXiaL budding
# 0.0                                 PEAnut shmoo mutant
# 1.0                                Spindle Pole Antigen
# 2.0                                   Bud Neck Involved
# 0.0                             BInding to Microtubules
# 1.0                                              MYOsin
# 2.0                Chromosome Instability and Karyogamy
# 3.0                                                 NaN
# 4.0                                           KARyogamy
# 5.0                                           KARyogamy
# 0.0                          BIlateral Karyogamy defect
# 1.0                                           KARyogamy
# 2.0                   OxySterol binding protein Homolog
# 3.0                Pheromone-Regulated Membrane protein
# 4.0                                   MonoPolar Spindle
# 5.0                                           KARyogamy
# 6.0                DnaJ-like protein of the ER Membrane
# 7.0                                           KARyogamy
# 8.0                Chromosome Instability and Karyogamy
# 9.0                                         cell FUSion
# 10.0                                          KARyogamy
# 11.0               Pheromone-Regulated Membrane protein
# 12.0                                          KARyogamy
# 13.0                                          KARyogamy
# 0.0                              Spindle Pole Component
# 1.0                                         cell FUSion
# 2.0                                             STErile
# 3.0                                             STErile
# ...                                                 ...
# NaN                                       RECombination
# NaN   SPO11 meiotic protein covalently bound to DSB ...
# NaN                                 HAP2 gamete fusogen
# NaN                                      Kar5 karyogamy
# NaN                                      Kar5 karyogamy
# NaN                                 RADiation sensitive
# NaN                              Disrupted Meiotic cDNA
# NaN                                         SPOrulation
# NaN                                     HOmolog Pairing
# NaN                                        MutS Homolog
# NaN                                        MutS Homolog
# NaN                                        MutS Homolog
# NaN                                  HOmologous Pairing
# NaN                           Meiotic Nuclear Divisions
# NaN                                        MutS Homolog
# NaN                                       RECombination
# NaN                          BIlateral Karyogamy defect
# NaN                                           KARyogamy
# NaN                   OxySterol binding protein Homolog
# NaN                Pheromone-Regulated Membrane protein
# NaN                                   MonoPolar Spindle
# NaN                                           KARyogamy
# NaN                DnaJ-like protein of the ER Membrane
# NaN                                           KARyogamy
# NaN                Chromosome Instability and Karyogamy
# NaN                                         cell FUSion
# NaN                                           KARyogamy
# NaN                Pheromone-Regulated Membrane protein
# NaN                                           KARyogamy
# NaN                                           KARyogamy
#
#                                            path      OMAID  \
# 0.0   ./yeastmating/results_signal_strength.tsv  6844990.0
# 1.0   ./yeastmating/results_signal_strength.tsv  6842368.0
# 2.0   ./yeastmating/results_signal_strength.tsv  6847757.0
# 0.0        ./yeastmating/results_polarisome.tsv  6843538.0
# 1.0        ./yeastmating/results_polarisome.tsv  6845359.0
# 2.0        ./yeastmating/results_polarisome.tsv  6846426.0
# 0.0      ./yeastmating/results_polarization.tsv  6843379.0
# 1.0      ./yeastmating/results_polarization.tsv  6846120.0
# 2.0      ./yeastmating/results_polarization.tsv  6846221.0
# 3.0      ./yeastmating/results_polarization.tsv  6847331.0
# 4.0      ./yeastmating/results_polarization.tsv  6847365.0
# 5.0      ./yeastmating/results_polarization.tsv  6847777.0
# 0.0                ./yeastmating/resultskar.tsv  6842075.0
# 1.0                ./yeastmating/resultskar.tsv  6842049.0
# 2.0                ./yeastmating/resultskar.tsv  6844425.0
# 3.0                ./yeastmating/resultskar.tsv  6843159.0
# 4.0                ./yeastmating/resultskar.tsv  6844793.0
# 5.0                ./yeastmating/resultskar.tsv  6844781.0
# 6.0                ./yeastmating/resultskar.tsv  6844742.0
# 7.0                ./yeastmating/resultskar.tsv  6846074.0
# 8.0                ./yeastmating/resultskar.tsv  6846221.0
# 9.0                ./yeastmating/resultskar.tsv  6846256.0
# 10.0               ./yeastmating/resultskar.tsv  6846507.0
# 11.0               ./yeastmating/resultskar.tsv  6847443.0
# 12.0               ./yeastmating/resultskar.tsv  6847365.0
# 13.0               ./yeastmating/resultskar.tsv  6847777.0
# 0.0      ./yeastmating/results_cell_sensing.tsv  6841520.0
# 1.0      ./yeastmating/results_cell_sensing.tsv  6841703.0
# 2.0      ./yeastmating/results_cell_sensing.tsv  6844332.0
# 3.0      ./yeastmating/results_cell_sensing.tsv  6845020.0
# ...                                         ...        ...
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
#
#                                 HOG
# 0.0                     HOG:0259166
# 1.0                  HOG:0405589.7a
# 2.0                     HOG:0219055
# 0.0                     HOG:0217913
# 1.0                     HOG:0220110
# 2.0                  HOG:0260593.1c
# 0.0                  HOG:0408681.3d
# 1.0   HOG:0422600.10fey.2574b.1738a
# 2.0                   HOG:0218435.1
# 3.0                     HOG:0218021
# 4.0                     HOG:0218343
# 5.0               HOG:0422600.10jry
# 0.0                     HOG:0219830
# 1.0                   HOG:0408350.2
# 2.0                     HOG:0259916
# 3.0                     HOG:0218591
# 4.0                     HOG:0217984
# 5.0            HOG:0404837.10ab.59d
# 6.0                     HOG:0398864
# 7.0                     HOG:0219280
# 8.0                   HOG:0218435.1
# 9.0                     HOG:0218583
# 10.0                    HOG:0218691
# 11.0                    HOG:0217526
# 12.0                    HOG:0218343
# 13.0              HOG:0422600.10jry
# 0.0                     HOG:0218807
# 1.0              HOG:0401069.3r.26a
# 2.0                     HOG:0219392
# 3.0                     HOG:0256520
# ...                             ...
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
# NaN                             NaN
#
# [162 rows x 8 columns]

# %%
hogdf['sigsum'] = hogdf.hashsig.map(lambda x : np.sum(x.digest()))
hogdf = hogdf[hogdf.sigsum>0]
print(hogdf)
# Out:
#                0        1                     2      3  \
# 0.0   S000001692  YKL209C         S. cerevisiae   STE6
# 1.0   S000002248  YDL090C         S. cerevisiae   RAM1
# 2.0   S000006326  YPR122W         S. cerevisiae   AXL1
# 1.0   S000003944  YLL021W         S. cerevisiae   SPA2
# 2.0   S000005215  YNL271C         S. cerevisiae   BNI1
# 0.0   S000000818  YER016W         S. cerevisiae   BIM1
# 1.0   S000004715  YMR109W         S. cerevisiae   MYO5
# 5.0   S000006345  YPR141C         S. cerevisiae   KAR3
# 0.0   S000000534  YCL029C         S. cerevisiae   BIK1
# 1.0   S000000560  YCL055W         S. cerevisiae   KAR4
# 2.0   S000001115  YHR073W         S. cerevisiae   OSH3
# 5.0   S000003571  YJL034W         S. cerevisiae   KAR2
# 7.0   S000004669  YMR065W         S. cerevisiae   KAR5
# 1.0   S000000112  YBL016W         S. cerevisiae   FUS3
# 3.0   S000001661  YKL178C         S. cerevisiae   STE3
# 6.0   S000004354  YLR362W         S. cerevisiae  STE11
# 1.0   S000005853  YOR326W         S. cerevisiae   MYO2
# 0.0   S000000039  YAL041W         S. cerevisiae  CDC24
# 1.0   S000003384  YGR152C         S. cerevisiae   RSR1
# 3.0   S000004219  YLR229C         S. cerevisiae  CDC42
# 0.0   S000000375  YBR171W         S. cerevisiae  SEC66
# 1.0   S000002284  YDL126C         S. cerevisiae  CDC48
# 3.0   S000005601  YOR075W         S. cerevisiae   UFE1
# 4.0   S000005780  YOR254C         S. cerevisiae  SEC63
# 0.0   S000001047  YHR005C         S. cerevisiae   GPA1
# 4.0   S000003846  YJR086W         S. cerevisiae  STE18
# 6.0   S000005738  YOR212W         S. cerevisiae   STE4
# 0.0   S000000007  YAL009W         S. cerevisiae   SPO7
# 1.0   S000000016  YAL018C         S. cerevisiae   LDS1
# 2.0   S000000154  YBL058W         S. cerevisiae   SHP1
# ...          ...      ...                   ...    ...
# 37.0  S000005251  YNL307C         S. cerevisiae   MCK1
# 40.0  S000005716  YOR190W         S. cerevisiae   SPR1
# 43.0  S000005840  YOR313C         S. cerevisiae   SPS4
# 1.0   S000003764  YJR004C         S. cerevisiae   SAG1
# 2.0   S000005327  YNR044W         S. cerevisiae   AGA1
# 0.0   S000000244  YBR040W         S. cerevisiae   FIG1
# 2.0   S000004467  YML008C         S. cerevisiae   ERG6
# 4.0   S000005223  YNL279W         S. cerevisiae   PRM1
# NaN   S000000662  YCR066W         S. cerevisiae  RAD18
# NaN   S000000897  YER095W         S. cerevisiae  RAD51
# NaN   S000000981  YER179W         S. cerevisiae   DMC1
# NaN   S000001886  YFL008W         S. cerevisiae   SMC1
# NaN   S000001891  YFL003C         S. cerevisiae   MSH4
# NaN   S000001927  YFR031C         S. cerevisiae   SMC2
# NaN   S000002313  YDL154W         S. cerevisiae   MSH5
# NaN   S000002504  YDR097C         S. cerevisiae   MSH6
# NaN   S000003001  YGL033W         S. cerevisiae   HOP2
# NaN   S000003151  YGL183C         S. cerevisiae   MND1
# NaN   S000003220  YGL251C         S. cerevisiae   HFM1
# NaN   S000003610  YJL074C         S. cerevisiae   SMC3
# NaN   S000004076  YLR086W         S. cerevisiae   SMC4
# NaN   S000004681  YMR076C         S. cerevisiae   PDS5
# NaN   S000004777  YMR167W         S. cerevisiae   MLH1
# NaN   S000005026  YNL082W         S. cerevisiae   PMS1
# NaN   S000005194  YNL250W         S. cerevisiae  RAD50
# NaN   S000005394  YOL034W         S. cerevisiae   SMC5
# NaN   S000005450  YOL090W         S. cerevisiae   MSH2
# NaN   S000005943  YPL022W         S. cerevisiae   RAD1
# NaN   S000006085  YPL164C         S. cerevisiae   MLH3
# NaN   ARATH26614   F4JP36  Arabidopsis thaliana   HAP2
#
#                                              4  \
# 0.0                                    STErile
# 1.0        RAS protein and A-factor Maturation
# 2.0                              AXiaL budding
# 1.0                       Spindle Pole Antigen
# 2.0                          Bud Neck Involved
# 0.0                    BInding to Microtubules
# 1.0                                     MYOsin
# 5.0                                  KARyogamy
# 0.0                 BIlateral Karyogamy defect
# 1.0                                  KARyogamy
# 2.0          OxySterol binding protein Homolog
# 5.0                                  KARyogamy
# 7.0                                  KARyogamy
# 1.0                                cell FUSion
# 3.0                                    STErile
# 6.0                                    STErile
# 1.0                                     MYOsin
# 0.0                        Cell Division Cycle
# 1.0                                RaS-Related
# 3.0                        Cell Division Cycle
# 0.0                                  SECretory
# 1.0                        Cell Division Cycle
# 3.0                 Unknown Function Essential
# 4.0                                  SECretory
# 0.0                    G Protein Alpha subunit
# 4.0                                    STErile
# 6.0                                    STErile
# 0.0                                SPOrulation
# 1.0              Lipid Droplets in Sporulation
# 2.0                Suppressor of High-copy PP1
# ...                                        ...
# 37.0  Meiosis and Centromere regulatory Kinase
# 40.0                     SPorulation Regulated
# 43.0            SPorulation Specific trancript
# 1.0                       Sexual AGglutination
# 2.0                               a-AGglutinin
# 0.0                        Factor-Induced Gene
# 2.0                    ERGosterol biosynthesis
# 4.0       Pheromone-Regulated Membrane protein
# NaN                        RADiation sensitive
# NaN                        RADiation sensitive
# NaN                     Disrupted Meiotic cDNA
# NaN               Stability of MiniChromosomes
# NaN                               MutS Homolog
# NaN      Structural Maintenance of Chromosomes
# NaN                               MutS Homolog
# NaN                               MutS Homolog
# NaN                         HOmologous Pairing
# NaN                  Meiotic Nuclear Divisions
# NaN                     Helicase Family Member
# NaN               Stability of MiniChromosomes
# NaN      Structural Maintenance of Chromosomes
# NaN         Precocious Dissociation of Sisters
# NaN                               MutL Homolog
# NaN                    PostMeiotic Segregation
# NaN                        RADiation sensitive
# NaN      Structural Maintenance of Chromosomes
# NaN                               MutS Homolog
# NaN                        RADiation sensitive
# NaN                               MutL Homolog
# NaN                        HAP2 gamete fusogen
#
#                                            path      OMAID  \
# 0.0   ./yeastmating/results_signal_strength.tsv  6844990.0
# 1.0   ./yeastmating/results_signal_strength.tsv  6842368.0
# 2.0   ./yeastmating/results_signal_strength.tsv  6847757.0
# 1.0        ./yeastmating/results_polarisome.tsv  6845359.0
# 2.0        ./yeastmating/results_polarisome.tsv  6846426.0
# 0.0      ./yeastmating/results_polarization.tsv  6843379.0
# 1.0      ./yeastmating/results_polarization.tsv  6846120.0
# 5.0      ./yeastmating/results_polarization.tsv  6847777.0
# 0.0                ./yeastmating/resultskar.tsv  6842075.0
# 1.0                ./yeastmating/resultskar.tsv  6842049.0
# 2.0                ./yeastmating/resultskar.tsv  6844425.0
# 5.0                ./yeastmating/resultskar.tsv  6844781.0
# 7.0                ./yeastmating/resultskar.tsv  6846074.0
# 1.0      ./yeastmating/results_cell_sensing.tsv  6841703.0
# 3.0      ./yeastmating/results_cell_sensing.tsv  6845020.0
# 6.0      ./yeastmating/results_cell_sensing.tsv  6845752.0
# 1.0       ./yeastmating/nuclear_congression.tsv  6847283.0
# 0.0          ./yeastmating/results_polarity.tsv  6841527.0
# 1.0          ./yeastmating/results_polarity.tsv  6844137.0
# 3.0          ./yeastmating/results_polarity.tsv  6845616.0
# 0.0     ./yeastmating/results_nuclearfusion.tsv  6841895.0
# 1.0     ./yeastmating/results_nuclearfusion.tsv  6842331.0
# 3.0     ./yeastmating/results_nuclearfusion.tsv  6847033.0
# 4.0     ./yeastmating/results_nuclearfusion.tsv  6847208.0
# 0.0         ./yeastmating/results_signaling.tsv  6844345.0
# 4.0         ./yeastmating/results_signaling.tsv  6844893.0
# 6.0         ./yeastmating/results_signaling.tsv  6847169.0
# 0.0                ./yeastmating/resultsSPO.tsv  6841567.0
# 1.0                ./yeastmating/resultsSPO.tsv  6841556.0
# 2.0                ./yeastmating/resultsSPO.tsv  6841660.0
# ...                                         ...        ...
# 37.0               ./yeastmating/resultsSPO.tsv  6846391.0
# 40.0               ./yeastmating/resultsSPO.tsv  6847145.0
# 43.0               ./yeastmating/resultsSPO.tsv  6847269.0
# 1.0     ./yeastmating/results_agglutination.tsv  6844813.0
# 2.0     ./yeastmating/results_agglutination.tsv  6846743.0
# 0.0            ./yeastmating/results_fusion.tsv  6841759.0
# 2.0            ./yeastmating/results_fusion.tsv  6845998.0
# 4.0            ./yeastmating/results_fusion.tsv  6846418.0
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
# NaN                                         NaN        NaN
#
#                                 HOG  \
# 0.0                     HOG:0259166
# 1.0                  HOG:0405589.7a
# 2.0                     HOG:0219055
# 1.0                     HOG:0220110
# 2.0                  HOG:0260593.1c
# 0.0                  HOG:0408681.3d
# 1.0   HOG:0422600.10fey.2574b.1738a
# 5.0               HOG:0422600.10jry
# 0.0                     HOG:0219830
# 1.0                  HOG:0408350.2b
# 2.0                     HOG:0259916
# 5.0            HOG:0404837.10ab.59d
# 7.0                     HOG:0219280
# 1.0              HOG:0401069.3r.26a
# 3.0                     HOG:0256520
# 6.0                     HOG:0401246
# 1.0                  HOG:0401396.1a
# 0.0                  HOG:0259374.1b
# 1.0            HOG:0410251.10m.164e
# 3.0           HOG:0410251.10dc.226b
# 0.0                     HOG:0256980
# 1.0                 HOG:0419289.10c
# 3.0                  HOG:0259186.1b
# 4.0                     HOG:0421997
# 0.0              HOG:0409582.6u.29h
# 4.0                     HOG:0219743
# 6.0         HOG:0422600.10bsi.2070b
# 0.0                     HOG:0256513
# 1.0                  HOG:0220154.1b
# 2.0                  HOG:0408836.3a
# ...                             ...
# 37.0        HOG:0422600.10dwk.2399b
# 40.0          HOG:0403826.4b.5b.12b
# 43.0                    HOG:0219017
# 1.0                  HOG:0218063.3m
# 2.0                  HOG:0218063.3h
# 0.0                     HOG:0219823
# 2.0          HOG:0419362.4a.12a.14b
# 4.0                     HOG:0260600
# NaN               HOG:0408660.4c.3d
# NaN                  HOG:0418834.8a
# NaN                  HOG:0418834.8b
# NaN               HOG:0422600.10exz
# NaN               HOG:0401907.3b.7a
# NaN               HOG:0422600.10byw
# NaN                 HOG:0405252.10i
# NaN                 HOG:0405252.10e
# NaN                  HOG:0219365.2b
# NaN                 HOG:0420121.10d
# NaN                     HOG:0258681
# NaN                  HOG:0612291.1b
# NaN               HOG:0422600.10fyw
# NaN               HOG:0422600.10bfy
# NaN                  HOG:0404112.2b
# NaN              HOG:0410852.3f.10a
# NaN                  HOG:0400134.3v
# NaN                     HOG:0418785
# NaN                 HOG:0405252.10l
# NaN                  HOG:0418686.2a
# NaN                  HOG:0410852.3e
# NaN              HOG:0406399.2a.10b
#
#                                                 hashsig   sigsum
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1802892
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  1741336
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  1926020
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  1798247
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  1731215
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1876264
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# 5.0   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1983071
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  1742908
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  1754083
# 5.0   <datasketch.weighted_minhash.WeightedMinHash o...  2339747
# 7.0   <datasketch.weighted_minhash.WeightedMinHash o...  1650312
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  2170775
# 3.0   <datasketch.weighted_minhash.WeightedMinHash o...  1979896
# 6.0   <datasketch.weighted_minhash.WeightedMinHash o...  1924212
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  1674334
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1702082
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  2523103
# 3.0   <datasketch.weighted_minhash.WeightedMinHash o...  2523103
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1855155
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  1967762
# 3.0   <datasketch.weighted_minhash.WeightedMinHash o...  1656513
# 4.0   <datasketch.weighted_minhash.WeightedMinHash o...  1663485
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  2104244
# 4.0   <datasketch.weighted_minhash.WeightedMinHash o...  1775738
# 6.0   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1792601
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  2295983
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  1834969
# ...                                                 ...      ...
# 37.0  <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# 40.0  <datasketch.weighted_minhash.WeightedMinHash o...  1897038
# 43.0  <datasketch.weighted_minhash.WeightedMinHash o...  1748563
# 1.0   <datasketch.weighted_minhash.WeightedMinHash o...  2726698
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  2726698
# 0.0   <datasketch.weighted_minhash.WeightedMinHash o...  1838620
# 2.0   <datasketch.weighted_minhash.WeightedMinHash o...  1881182
# 4.0   <datasketch.weighted_minhash.WeightedMinHash o...  1779822
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1663272
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1892039
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1892039
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1751105
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1989484
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1989484
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2182661
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1507785
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1690873
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1505740
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2666860
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1690529
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1744836
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  2061398
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1674285
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1989484
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1656698
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1744836
# NaN   <datasketch.weighted_minhash.WeightedMinHash o...  1518262
#
# [75 rows x 10 columns]

# %%
#lets take a look at the clustering of our queries to see if some are coevolving and we can already notice some organisation
jkern2 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(hogdf.hashsig) ] for i,h1 in enumerate(hogdf.hashsig)]
jkern2 = np.asarray(jkern2)
jkern2+=jkern2.T
np.fill_diagonal(jkern2 , 1 )

# %%
import seaborn as sns

# %%
with PdfPages('repro_hash.pdf') as pdf:
    g = sns.clustermap( jkern2 , xticklabels= hogdf['3'] , yticklabels= hogdf['3'] , figsize = (25,25) )
    pdf.savefig()

# %%
#now lets fill in our network with some putative interactors
res = { h: p.hog_query( hog_id=str(h) , k = 20 ) for h in hogdf.HOG}
Hogs = [ h for results in res.values() for h in results ] + list(res.keys())

# %%
profiles = profiles = p.pull_hashes( set(Hogs) )
profiles = { h: {'hashsig': profiles[h] , 'name': names[h]  } if h in names else {'hashsig': profiles[h] , 'name': ''  }   for h in profiles }
profiles = pd.DataFrame.from_dict( profiles , orient='index' )

print(profiles.name.unique())
print(len(profiles.name.unique()))

print(len(profiles))
# Out:
# ['' 'AGA1' 'SAG1' 'SPS4' 'AXL1' 'KAR5' 'RSC1' 'HOP2' 'PMD1' 'SPR3' 'SPO75'
#  'STE18' 'FIG1' 'BIK1' 'SPS2' 'SPS22' 'SPO73' 'SPA2' 'LDS1' 'SPO7' 'STE3'
#  'SEC66' 'SPO11' 'HFM1' 'STE6' 'UFE1' 'CDC24' 'OSH3' 'BNI1' 'PRM1' 'SPO22'
#  'RAD50' 'FUS3' 'STE11' 'MYO2' 'SPO14' 'MSH4' 'CDC10' 'SPR28' 'SPS19'
#  'SPR1' 'MLH1' 'KAR2' 'MSH6' 'MSH5' 'MSH2' 'RAM1' 'HAP2' 'MRE11' 'KAR4'
#  'RAD18' 'BIM1' 'SHP1' 'GPA1' 'CDC42' 'RSR1' 'MLH3' 'PMS1' 'RAD1' 'SMC5'
#  'RAD51' 'DMC1' 'CDC48' 'ERG6' 'MND1' 'SEC63' 'PDS5' 'STE4' 'SMC2' 'MCK1'
#  'SMC1' 'MYO5' 'SMC4' 'KAR3' 'EMI2' 'SMC3']
# 76
# 1012

# %%
#lets calculate a new jaccard kernel for all of our search results and queries 
#again we can divide our results into clusters and try to see if each has a functional signature using GO enrichment

jkern3 = [ [ h1.jaccard(h2) if i<j else 0 for j,h2 in enumerate(profiles.hashsig) ] for i,h1 in enumerate(profiles.hashsig)]
jkern3 = np.asarray(jkern3)

jkern3+=jkern3.T
np.fill_diagonal(jkern3 , 1 )

# %%
print(jkern3)
# Out:
# [[1.         0.81640625 0.68359375 ... 0.01367188 0.01953125 0.01171875]
#  [0.81640625 1.         0.68359375 ... 0.015625   0.01953125 0.01367188]
#  [0.68359375 0.68359375 1.         ... 0.0078125  0.015625   0.01367188]
#  ...
#  [0.01367188 0.015625   0.0078125  ... 1.         0.50585938 0.3984375 ]
#  [0.01953125 0.01953125 0.015625   ... 0.50585938 1.         0.47460938]
#  [0.01171875 0.01367188 0.01367188 ... 0.3984375  0.47460938 1.        ]]

# %%
cutoff = 0.995
import scipy

z = scipy.cluster.hierarchy.linkage(jkern3, method='average', metric='euclidean')
clusters = scipy.cluster.hierarchy.fcluster(z, t=cutoff, criterion='distance')
print(clusters)
print(len(np.unique(clusters)))
# Out:
# [ 70  70  70 ... 163 184 180]
# 215

# %%
import itertools

with PdfPages('repro_hash_augment.pdf') as pdf:

    #colors = [ c.hex_l for c in red.range_to( blue , len(set(clusters)) ) ]
    #colordict2 = dict( zip( list(set(clusters)) , list(colors)))
    #rowcolors = [ colordict2[c] for c in clusters]
    
    spacer = itertools.cycle([0,5 ,10])
    
    spacednamesy = [  '__' * next(spacer) + p if len(p)> 0 else '' for p in profiles.name ]
    spacednamesx = [  p +  '__' * next(spacer) if len(p)> 0 else '' for p in profiles.name ]

    g = sns.clustermap( jkern3 , xticklabels= spacednamesx, yticklabels= spacednamesy , rasterized = True  , figsize = (20,20)  )
    
    g.ax_row_dendrogram.axvline(cutoff)
    g.ax_col_dendrogram.axhline(cutoff)
    pdf.savefig()

    g.savefig('repro_hash_augment.eps' , format='eps')

    plt.show()

# %%
#and here we perform our enrichment of each cluster with a query in it
goares = {}
from pyprofiler.utils.hashutils import hogid2fam
dfs = []
for c in np.unique(clusters):
    sub = profiles.iloc[ np.where( clusters == c ) ]
    #if our cluster contains a query it makes sense to see if we found some interactors related to it
    if len(sub.name.unique()) >1 : 
        print(sub.name.unique())
        
        queries  = set(sub[ sub.index.map(lambda x : 'HOG' in x )].index )
        #remove the query from search results
        searchfams = [str(hogid2fam(h)) for h in queries ]
        searchres = sub[ sub.index.map(lambda x : 'HOG' not in x )]
        searchres  = searchres[~searchres.index.isin(searchfams)]
        #run a go enrichment study on the cluster
        goares[c] = goa.run_GOEA_onresults( searchres.index.map( hogid2fam ) , p.db_obj, study)
        namestr = ''.join([ n+'_' for n in sub.name if len(n)>0 ])
        #output the results
        goea_results_sig = [r for r in goares[c][0] if r.p_fdr_bh < 0.1]
        print(len(goea_results_sig))
        study.wr_tsv(namestr + "_reprocluster_enrich.tsv", goea_results_sig)
        try:
            res = pd.DataFrame.from_csv(namestr + "_reprocluster_enrich.tsv" , sep= '\t' , header = None)
            res['queries'] = ''.join( [ n + ' ' for  n in sub.name ])
            dfs.append( res)
        except:
            print('no res')
        print(len(goea_results_sig))

finaldf = pd.concat(dfs)
finaldf.to_csv('repro_augment_goenrich.csv')
print('DONE')
